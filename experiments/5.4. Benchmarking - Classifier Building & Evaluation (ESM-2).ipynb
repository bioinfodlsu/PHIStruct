# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_esm2_relaxed_r3.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_esm2.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_esm2.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.4. Benchmarking - Classifier Building & Evaluation (ESM-2).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a multilayer perceptron, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = ["ESM2"]

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_saprot_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-mlp-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="MLP",
        )
# Out:
# *** esm2, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16926, 1280)
# Test set shape: (2340, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8218    0.7477    0.7830       111
#   enterobacter     0.2958    0.3621    0.3256       116
#   enterococcus     0.8727    0.9412    0.9057        51
#    escherichia     0.8534    0.8673    0.8603      1040
#     klebsiella     0.8696    0.8243    0.8463       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8527    0.9322    0.8907       354
# staphylococcus     0.9317    0.9615    0.9464       156
#
#       accuracy                         0.8269      2340
#      macro avg     0.6872    0.7045    0.6947      2340
#   weighted avg     0.8144    0.8269    0.8199      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8367    0.7387    0.7847       111
#   enterobacter     0.3150    0.3448    0.3292       116
#   enterococcus     0.8727    0.9412    0.9057        51
#    escherichia     0.8592    0.8567    0.8580      1040
#     klebsiella     0.8756    0.8243    0.8492       461
#         others     0.0455    0.0392    0.0421        51
#    pseudomonas     0.8571    0.9322    0.8931       354
# staphylococcus     0.9375    0.9615    0.9494       156
#
#       accuracy                         0.8218      2340
#      macro avg     0.6999    0.7048    0.7014      2340
#   weighted avg     0.8219    0.8218    0.8212      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8367    0.7387    0.7847       111
#   enterobacter     0.3362    0.3362    0.3362       116
#   enterococcus     0.8727    0.9412    0.9057        51
#    escherichia     0.8650    0.8500    0.8574      1040
#     klebsiella     0.8814    0.8221    0.8507       461
#         others     0.0526    0.0784    0.0630        51
#    pseudomonas     0.8616    0.9322    0.8955       354
# staphylococcus     0.9375    0.9615    0.9494       156
#
#       accuracy                         0.8188      2340
#      macro avg     0.7055    0.7076    0.7053      2340
#   weighted avg     0.8274    0.8188    0.8224      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8454    0.7387    0.7885       111
#   enterobacter     0.3611    0.3362    0.3482       116
#   enterococcus     0.8727    0.9412    0.9057        51
#    escherichia     0.8711    0.8385    0.8545      1040
#     klebsiella     0.8900    0.8069    0.8464       461
#         others     0.0484    0.1176    0.0686        51
#    pseudomonas     0.8700    0.9266    0.8974       354
# staphylococcus     0.9375    0.9615    0.9494       156
#
#       accuracy                         0.8107      2340
#      macro avg     0.7120    0.7084    0.7073      2340
#   weighted avg     0.8347    0.8107    0.8215      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8438    0.7297    0.7826       111
#   enterobacter     0.3673    0.3103    0.3364       116
#   enterococcus     0.8889    0.9412    0.9143        51
#    escherichia     0.8768    0.8212    0.8481      1040
#     klebsiella     0.8910    0.7983    0.8421       461
#         others     0.0412    0.1373    0.0633        51
#    pseudomonas     0.8747    0.9266    0.8999       354
# staphylococcus     0.9375    0.9615    0.9494       156
#
#       accuracy                         0.8000      2340
#      macro avg     0.7151    0.7033    0.7045      2340
#   weighted avg     0.8386    0.8000    0.8174      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8602    0.7207    0.7843       111
#   enterobacter     0.3820    0.2931    0.3317       116
#   enterococcus     0.8889    0.9412    0.9143        51
#    escherichia     0.8786    0.8000    0.8374      1040
#     klebsiella     0.8973    0.7961    0.8437       461
#         others     0.0459    0.1961    0.0743        51
#    pseudomonas     0.8838    0.9237    0.9033       354
# staphylococcus     0.9375    0.9615    0.9494       156
#
#       accuracy                         0.7897      2340
#      macro avg     0.7218    0.7041    0.7048      2340
#   weighted avg     0.8436    0.7897    0.8136      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8889    0.7207    0.7960       111
#   enterobacter     0.4048    0.2931    0.3400       116
#   enterococcus     0.8889    0.9412    0.9143        51
#    escherichia     0.8847    0.7894    0.8343      1040
#     klebsiella     0.8985    0.7874    0.8393       461
#         others     0.0398    0.1961    0.0662        51
#    pseudomonas     0.8835    0.9209    0.9018       354
# staphylococcus     0.9375    0.9615    0.9494       156
#
#       accuracy                         0.7829      2340
#      macro avg     0.7283    0.7013    0.7052      2340
#   weighted avg     0.8488    0.7829    0.8119      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9080    0.7117    0.7980       111
#   enterobacter     0.4400    0.2845    0.3455       116
#   enterococcus     0.8868    0.9216    0.9038        51
#    escherichia     0.8924    0.7654    0.8240      1040
#     klebsiella     0.8982    0.7657    0.8267       461
#         others     0.0379    0.2353    0.0652        51
#    pseudomonas     0.8929    0.9181    0.9053       354
# staphylococcus     0.9371    0.9551    0.9460       156
#
#       accuracy                         0.7667      2340
#      macro avg     0.7367    0.6947    0.7018      2340
#   weighted avg     0.8562    0.7667    0.8052      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9176    0.7027    0.7959       111
#   enterobacter     0.4545    0.2586    0.3297       116
#   enterococcus     0.9020    0.9020    0.9020        51
#    escherichia     0.8974    0.7404    0.8114      1040
#     klebsiella     0.9072    0.7419    0.8162       461
#         others     0.0387    0.2941    0.0683        51
#    pseudomonas     0.8969    0.9096    0.9032       354
# staphylococcus     0.9487    0.9487    0.9487       156
#
#       accuracy                         0.7483      2340
#      macro avg     0.7454    0.6872    0.6969      2340
#   weighted avg     0.8631    0.7483    0.7966      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9157    0.6847    0.7835       111
#   enterobacter     0.5400    0.2328    0.3253       116
#   enterococcus     0.9318    0.8039    0.8632        51
#    escherichia     0.9068    0.6923    0.7852      1040
#     klebsiella     0.9228    0.6746    0.7794       461
#         others     0.0376    0.3922    0.0686        51
#    pseudomonas     0.9107    0.8927    0.9016       354
# staphylococcus     0.9608    0.9423    0.9515       156
#
#       accuracy                         0.7085      2340
#      macro avg     0.7658    0.6644    0.6823      2340
#   weighted avg     0.8780    0.7085    0.7759      2340
#
# ===================
# Finished
# ===================
# *** esm2, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14810, 1280)
# Test set shape: (2822, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3902    0.7339    0.5096       109
#   enterobacter     0.1694    0.1856    0.1771       167
#   enterococcus     0.5606    0.6167    0.5873        60
#    escherichia     0.7361    0.6287    0.6782      1344
#     klebsiella     0.6042    0.5707    0.5869       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.5706    0.8063    0.6682       351
# staphylococcus     0.7908    0.9012    0.8424       172
#
#       accuracy                         0.6201      2822
#      macro avg     0.4777    0.5554    0.5062      2822
#   weighted avg     0.6264    0.6201    0.6164      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3980    0.7339    0.5161       109
#   enterobacter     0.1686    0.1737    0.1711       167
#   enterococcus     0.5873    0.6167    0.6016        60
#    escherichia     0.7441    0.6101    0.6705      1344
#     klebsiella     0.6155    0.5671    0.5903       559
#         others     0.0238    0.0333    0.0278        60
#    pseudomonas     0.5755    0.8034    0.6706       351
# staphylococcus     0.7897    0.8953    0.8392       172
#
#       accuracy                         0.6099      2822
#      macro avg     0.4878    0.5542    0.5109      2822
#   weighted avg     0.6344    0.6099    0.6143      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4072    0.7248    0.5215       109
#   enterobacter     0.1875    0.1617    0.1736       167
#   enterococcus     0.6000    0.6000    0.6000        60
#    escherichia     0.7484    0.5930    0.6617      1344
#     klebsiella     0.6168    0.5528    0.5830       559
#         others     0.0217    0.0667    0.0328        60
#    pseudomonas     0.5782    0.8006    0.6714       351
# staphylococcus     0.8138    0.8895    0.8500       172
#
#       accuracy                         0.5974      2822
#      macro avg     0.4967    0.5486    0.5118      2822
#   weighted avg     0.6401    0.5974    0.6098      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4194    0.7156    0.5288       109
#   enterobacter     0.1970    0.1557    0.1739       167
#   enterococcus     0.6207    0.6000    0.6102        60
#    escherichia     0.7493    0.5759    0.6512      1344
#     klebsiella     0.6208    0.5331    0.5736       559
#         others     0.0221    0.1000    0.0363        60
#    pseudomonas     0.5870    0.7977    0.6763       351
# staphylococcus     0.8216    0.8837    0.8515       172
#
#       accuracy                         0.5847      2822
#      macro avg     0.5047    0.5452    0.5127      2822
#   weighted avg     0.6444    0.5847    0.6043      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4239    0.7156    0.5324       109
#   enterobacter     0.1966    0.1377    0.1620       167
#   enterococcus     0.6364    0.5833    0.6087        60
#    escherichia     0.7538    0.5558    0.6398      1344
#     klebsiella     0.6293    0.5224    0.5709       559
#         others     0.0272    0.1667    0.0467        60
#    pseudomonas     0.5940    0.7920    0.6789       351
# staphylococcus     0.8686    0.8837    0.8761       172
#
#       accuracy                         0.5723      2822
#      macro avg     0.5162    0.5447    0.5144      2822
#   weighted avg     0.6526    0.5723    0.5997      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4457    0.7156    0.5493       109
#   enterobacter     0.1980    0.1198    0.1493       167
#   enterococcus     0.6415    0.5667    0.6018        60
#    escherichia     0.7537    0.5350    0.6258      1344
#     klebsiella     0.6368    0.5081    0.5652       559
#         others     0.0278    0.2167    0.0492        60
#    pseudomonas     0.6115    0.7892    0.6891       351
# staphylococcus     0.8837    0.8837    0.8837       172
#
#       accuracy                         0.5588      2822
#      macro avg     0.5248    0.5418    0.5142      2822
#   weighted avg     0.6582    0.5588    0.5934      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4699    0.7156    0.5673       109
#   enterobacter     0.2299    0.1198    0.1575       167
#   enterococcus     0.6538    0.5667    0.6071        60
#    escherichia     0.7625    0.5112    0.6120      1344
#     klebsiella     0.6465    0.4973    0.5622       559
#         others     0.0274    0.2667    0.0498        60
#    pseudomonas     0.6189    0.7635    0.6837       351
# staphylococcus     0.8941    0.8837    0.8889       172
#
#       accuracy                         0.5432      2822
#      macro avg     0.5379    0.5406    0.5161      2822
#   weighted avg     0.6689    0.5432    0.5873      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4843    0.7064    0.5746       109
#   enterobacter     0.2533    0.1138    0.1570       167
#   enterococcus     0.6667    0.5667    0.6126        60
#    escherichia     0.7655    0.4881    0.5961      1344
#     klebsiella     0.6675    0.4848    0.5617       559
#         others     0.0260    0.3000    0.0479        60
#    pseudomonas     0.6386    0.7550    0.6919       351
# staphylococcus     0.8988    0.8779    0.8882       172
#
#       accuracy                         0.5283      2822
#      macro avg     0.5501    0.5366    0.5163      2822
#   weighted avg     0.6794    0.5283    0.5809      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5102    0.6881    0.5859       109
#   enterobacter     0.2576    0.1018    0.1459       167
#   enterococcus     0.6531    0.5333    0.5872        60
#    escherichia     0.7698    0.4554    0.5722      1344
#     klebsiella     0.6736    0.4615    0.5478       559
#         others     0.0244    0.3333    0.0455        60
#    pseudomonas     0.6499    0.7350    0.6898       351
# staphylococcus     0.9036    0.8721    0.8876       172
#
#       accuracy                         0.5039      2822
#      macro avg     0.5553    0.5226    0.5077      2822
#   weighted avg     0.6853    0.5039    0.5657      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5984    0.6697    0.6320       109
#   enterobacter     0.2692    0.0838    0.1279       167
#   enterococcus     0.6667    0.5000    0.5714        60
#    escherichia     0.7659    0.3943    0.5206      1344
#     klebsiella     0.7014    0.4329    0.5354       559
#         others     0.0223    0.3833    0.0421        60
#    pseudomonas     0.6802    0.7151    0.6972       351
# staphylococcus     0.9024    0.8605    0.8810       172
#
#       accuracy                         0.4646      2822
#      macro avg     0.5758    0.5050    0.5010      2822
#   weighted avg     0.6970    0.4646    0.5394      2822
#
# ===================
# Finished
# ===================
# *** esm2, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13097, 1280)
# Test set shape: (3153, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4670    0.7025    0.5611       121
#   enterobacter     0.1899    0.1735    0.1813       196
#   enterococcus     0.5000    0.7959    0.6142        49
#    escherichia     0.6593    0.7369    0.6960      1589
#     klebsiella     0.4522    0.3299    0.3815       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.7341    0.6559    0.6928       404
# staphylococcus     0.7905    0.7452    0.7672       157
#
#       accuracy                         0.6042      3153
#      macro avg     0.4741    0.5175    0.4868      3153
#   weighted avg     0.5875    0.6042    0.5912      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4941    0.6942    0.5773       121
#   enterobacter     0.1856    0.1582    0.1708       196
#   enterococcus     0.5278    0.7755    0.6281        49
#    escherichia     0.6597    0.7187    0.6880      1589
#     klebsiella     0.4631    0.3197    0.3783       588
#         others     0.0096    0.0204    0.0131        49
#    pseudomonas     0.7354    0.6535    0.6920       404
# staphylococcus     0.7917    0.7261    0.7575       157
#
#       accuracy                         0.5905      3153
#      macro avg     0.4834    0.5083    0.4881      3153
#   weighted avg     0.5913    0.5905    0.5864      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5217    0.6942    0.5957       121
#   enterobacter     0.1765    0.1378    0.1547       196
#   enterococcus     0.5429    0.7755    0.6387        49
#    escherichia     0.6600    0.7011    0.6799      1589
#     klebsiella     0.4707    0.3146    0.3772       588
#         others     0.0106    0.0408    0.0168        49
#    pseudomonas     0.7395    0.6535    0.6938       404
# staphylococcus     0.7887    0.7134    0.7492       157
#
#       accuracy                         0.5791      3153
#      macro avg     0.4888    0.5039    0.4882      3153
#   weighted avg     0.5940    0.5791    0.5818      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5526    0.6942    0.6154       121
#   enterobacter     0.1655    0.1173    0.1373       196
#   enterococcus     0.5606    0.7551    0.6435        49
#    escherichia     0.6638    0.6872    0.6753      1589
#     klebsiella     0.4726    0.3078    0.3728       588
#         others     0.0070    0.0408    0.0120        49
#    pseudomonas     0.7602    0.6436    0.6971       404
# staphylococcus     0.7943    0.7134    0.7517       157
#
#       accuracy                         0.5680      3153
#      macro avg     0.4971    0.4949    0.4881      3153
#   weighted avg     0.6000    0.5680    0.5789      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5764    0.6860    0.6264       121
#   enterobacter     0.1591    0.1071    0.1280       196
#   enterococcus     0.5625    0.7347    0.6372        49
#    escherichia     0.6677    0.6652    0.6665      1589
#     klebsiella     0.4743    0.2976    0.3657       588
#         others     0.0077    0.0612    0.0136        49
#    pseudomonas     0.7795    0.6386    0.7020       404
# staphylococcus     0.7986    0.7070    0.7500       157
#
#       accuracy                         0.5531      3153
#      macro avg     0.5032    0.4872    0.4862      3153
#   weighted avg     0.6055    0.5531    0.5735      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6074    0.6777    0.6406       121
#   enterobacter     0.1557    0.0969    0.1195       196
#   enterococcus     0.5714    0.7347    0.6429        49
#    escherichia     0.6724    0.6432    0.6574      1589
#     klebsiella     0.4774    0.2874    0.3588       588
#         others     0.0100    0.1020    0.0182        49
#    pseudomonas     0.7950    0.6337    0.7052       404
# staphylococcus     0.8029    0.7006    0.7483       157
#
#       accuracy                         0.5389      3153
#      macro avg     0.5115    0.4845    0.4864      3153
#   weighted avg     0.6118    0.5389    0.5682      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6406    0.6777    0.6586       121
#   enterobacter     0.1607    0.0918    0.1169       196
#   enterococcus     0.5932    0.7143    0.6481        49
#    escherichia     0.6680    0.6117    0.6386      1589
#     klebsiella     0.4970    0.2823    0.3601       588
#         others     0.0113    0.1429    0.0209        49
#    pseudomonas     0.8312    0.6337    0.7191       404
# staphylococcus     0.8029    0.7006    0.7483       157
#
#       accuracy                         0.5220      3153
#      macro avg     0.5256    0.4819    0.4888      3153
#   weighted avg     0.6198    0.5220    0.5613      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6480    0.6694    0.6585       121
#   enterobacter     0.1515    0.0765    0.1017       196
#   enterococcus     0.6140    0.7143    0.6604        49
#    escherichia     0.6691    0.5777    0.6201      1589
#     klebsiella     0.5080    0.2704    0.3529       588
#         others     0.0134    0.2041    0.0251        49
#    pseudomonas     0.8439    0.6287    0.7206       404
# staphylococcus     0.8029    0.7006    0.7483       157
#
#       accuracy                         0.5017      3153
#      macro avg     0.5313    0.4802    0.4859      3153
#   weighted avg     0.6241    0.5017    0.5501      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6607    0.6116    0.6352       121
#   enterobacter     0.1429    0.0612    0.0857       196
#   enterococcus     0.6939    0.6939    0.6939        49
#    escherichia     0.6731    0.5261    0.5906      1589
#     klebsiella     0.5166    0.2381    0.3260       588
#         others     0.0124    0.2449    0.0235        49
#    pseudomonas     0.8750    0.6238    0.7283       404
# staphylococcus     0.8015    0.6943    0.7440       157
#
#       accuracy                         0.4659      3153
#      macro avg     0.5470    0.4617    0.4784      3153
#   weighted avg     0.6328    0.4659    0.5297      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7292    0.5785    0.6452       121
#   enterobacter     0.1429    0.0408    0.0635       196
#   enterococcus     0.7500    0.6735    0.7097        49
#    escherichia     0.6924    0.4733    0.5622      1589
#     klebsiella     0.5642    0.2092    0.3052       588
#         others     0.0136    0.3469    0.0262        49
#    pseudomonas     0.8901    0.6015    0.7179       404
# staphylococcus     0.8045    0.6815    0.7379       157
#
#       accuracy                         0.4291      3153
#      macro avg     0.5734    0.4506    0.4710      3153
#   weighted avg     0.6570    0.4291    0.5091      3153
#
# ===================
# Finished
# ===================
# *** esm2, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11650, 1280)
# Test set shape: (3203, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2060    0.5393    0.2981        89
#   enterobacter     0.1541    0.1898    0.1701       216
#   enterococcus     0.4800    0.8780    0.6207        41
#    escherichia     0.7427    0.5351    0.6220      1796
#     klebsiella     0.4340    0.4364    0.4352       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.3493    0.7042    0.4670       311
# staphylococcus     0.7978    0.7802    0.7889       182
#
#       accuracy                         0.5236      3203
#      macro avg     0.3955    0.5079    0.4252      3203
#   weighted avg     0.5893    0.5236    0.5382      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2212    0.5393    0.3137        89
#   enterobacter     0.1589    0.1898    0.1730       216
#   enterococcus     0.5070    0.8780    0.6429        41
#    escherichia     0.7454    0.5167    0.6103      1796
#     klebsiella     0.4595    0.4194    0.4385       527
#         others     0.0270    0.0976    0.0423        41
#    pseudomonas     0.3591    0.7010    0.4749       311
# staphylococcus     0.8068    0.7802    0.7933       182
#
#       accuracy                         0.5114      3203
#      macro avg     0.4106    0.5152    0.4361      3203
#   weighted avg     0.5980    0.5114    0.5347      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2400    0.5393    0.3322        89
#   enterobacter     0.1646    0.1852    0.1743       216
#   enterococcus     0.5217    0.8780    0.6545        41
#    escherichia     0.7467    0.4989    0.5981      1796
#     klebsiella     0.4802    0.4137    0.4444       527
#         others     0.0148    0.0976    0.0257        41
#    pseudomonas     0.3682    0.7010    0.4828       311
# staphylococcus     0.8057    0.7747    0.7899       182
#
#       accuracy                         0.4998      3203
#      macro avg     0.4177    0.5110    0.4378      3203
#   weighted avg     0.6039    0.4998    0.5300      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2541    0.5281    0.3431        89
#   enterobacter     0.1639    0.1806    0.1718       216
#   enterococcus     0.5625    0.8780    0.6857        41
#    escherichia     0.7432    0.4738    0.5787      1796
#     klebsiella     0.5012    0.4061    0.4486       527
#         others     0.0126    0.1220    0.0229        41
#    pseudomonas     0.3774    0.6977    0.4898       311
# staphylococcus     0.8150    0.7747    0.7944       182
#
#       accuracy                         0.4839      3203
#      macro avg     0.4287    0.5076    0.4419      3203
#   weighted avg     0.6076    0.4839    0.5212      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2599    0.5169    0.3459        89
#   enterobacter     0.1630    0.1713    0.1670       216
#   enterococcus     0.5625    0.8780    0.6857        41
#    escherichia     0.7417    0.4460    0.5570      1796
#     klebsiella     0.5318    0.3966    0.4543       527
#         others     0.0166    0.2195    0.0308        41
#    pseudomonas     0.3934    0.6945    0.5023       311
# staphylococcus     0.8176    0.7637    0.7898       182
#
#       accuracy                         0.4661      3203
#      macro avg     0.4358    0.5108    0.4416      3203
#   weighted avg     0.6137    0.4661    0.5108      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2690    0.5169    0.3538        89
#   enterobacter     0.1628    0.1620    0.1624       216
#   enterococcus     0.5645    0.8537    0.6796        41
#    escherichia     0.7381    0.4237    0.5384      1796
#     klebsiella     0.5553    0.3909    0.4588       527
#         others     0.0181    0.2927    0.0340        41
#    pseudomonas     0.4031    0.6752    0.5048       311
# staphylococcus     0.8155    0.7527    0.7829       182
#
#       accuracy                         0.4502      3203
#      macro avg     0.4408    0.5085    0.4393      3203
#   weighted avg     0.6166    0.4502    0.5008      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2875    0.5169    0.3695        89
#   enterobacter     0.1683    0.1574    0.1627       216
#   enterococcus     0.5645    0.8537    0.6796        41
#    escherichia     0.7356    0.3981    0.5166      1796
#     klebsiella     0.5752    0.3700    0.4503       527
#         others     0.0173    0.3415    0.0329        41
#    pseudomonas     0.4182    0.6656    0.5136       311
# staphylococcus     0.8293    0.7473    0.7861       182
#
#       accuracy                         0.4315      3203
#      macro avg     0.4495    0.5063    0.4389      3203
#   weighted avg     0.6216    0.4315    0.4887      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2961    0.5056    0.3734        89
#   enterobacter     0.1667    0.1435    0.1542       216
#   enterococcus     0.6034    0.8537    0.7071        41
#    escherichia     0.7392    0.3708    0.4939      1796
#     klebsiella     0.6073    0.3491    0.4434       527
#         others     0.0155    0.3659    0.0298        41
#    pseudomonas     0.4292    0.6527    0.5179       311
# staphylococcus     0.8293    0.7473    0.7861       182
#
#       accuracy                         0.4106      3203
#      macro avg     0.4608    0.4986    0.4382      3203
#   weighted avg     0.6306    0.4106    0.4750      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3099    0.4944    0.3810        89
#   enterobacter     0.1366    0.1019    0.1167       216
#   enterococcus     0.6364    0.8537    0.7292        41
#    escherichia     0.7436    0.3391    0.4658      1796
#     klebsiella     0.6553    0.3283    0.4374       527
#         others     0.0155    0.4390    0.0300        41
#    pseudomonas     0.4523    0.6399    0.5300       311
# staphylococcus     0.8385    0.7418    0.7872       182
#
#       accuracy                         0.3856      3203
#      macro avg     0.4735    0.4922    0.4346      3203
#   weighted avg     0.6425    0.3856    0.4575      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3583    0.4831    0.4115        89
#   enterobacter     0.1520    0.0880    0.1114       216
#   enterococcus     0.7000    0.8537    0.7692        41
#    escherichia     0.7392    0.2762    0.4021      1796
#     klebsiella     0.6930    0.2998    0.4185       527
#         others     0.0136    0.4878    0.0264        41
#    pseudomonas     0.4882    0.5981    0.5376       311
# staphylococcus     0.8590    0.7363    0.7929       182
#
#       accuracy                         0.3406      3203
#      macro avg     0.5004    0.4779    0.4337      3203
#   weighted avg     0.6541    0.3406    0.4207      3203
#
# ===================
# Finished
# ===================
