# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_esm1b.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_esm1b_relaxed_r3.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_esm1b.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.3. Benchmarking - Classifier Building & Evaluation (ESM-1b).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a multilayer perceptron, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = ["ESM1B"]

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_saprot_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-mlp-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="MLP",
        )
# Out:
# *** esm1b, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16930, 1280)
# Test set shape: (2340, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7500    0.7838    0.7665       111
#   enterobacter     0.3356    0.4310    0.3774       116
#   enterococcus     0.7931    0.9020    0.8440        51
#    escherichia     0.8455    0.8577    0.8516      1040
#     klebsiella     0.8892    0.7831    0.8328       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8346    0.9407    0.8845       354
# staphylococcus     0.9490    0.9551    0.9521       156
#
#       accuracy                         0.8197      2340
#      macro avg     0.6746    0.7067    0.6886      2340
#   weighted avg     0.8100    0.8197    0.8133      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7544    0.7748    0.7644       111
#   enterobacter     0.3597    0.4310    0.3922       116
#   enterococcus     0.7931    0.9020    0.8440        51
#    escherichia     0.8521    0.8529    0.8525      1040
#     klebsiella     0.8922    0.7722    0.8279       461
#         others     0.0513    0.0392    0.0444        51
#    pseudomonas     0.8405    0.9379    0.8865       354
# staphylococcus     0.9548    0.9487    0.9518       156
#
#       accuracy                         0.8150      2340
#      macro avg     0.6873    0.7073    0.6955      2340
#   weighted avg     0.8173    0.8150    0.8146      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7679    0.7748    0.7713       111
#   enterobacter     0.3712    0.4224    0.3952       116
#   enterococcus     0.8070    0.9020    0.8519        51
#    escherichia     0.8597    0.8423    0.8509      1040
#     klebsiella     0.9003    0.7636    0.8263       461
#         others     0.0494    0.0784    0.0606        51
#    pseudomonas     0.8448    0.9379    0.8889       354
# staphylococcus     0.9548    0.9487    0.9518       156
#
#       accuracy                         0.8090      2340
#      macro avg     0.6944    0.7088    0.6996      2340
#   weighted avg     0.8244    0.8090    0.8150      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7818    0.7748    0.7783       111
#   enterobacter     0.3780    0.4138    0.3951       116
#   enterococcus     0.8070    0.9020    0.8519        51
#    escherichia     0.8641    0.8317    0.8476      1040
#     klebsiella     0.9115    0.7592    0.8284       461
#         others     0.0598    0.1373    0.0833        51
#    pseudomonas     0.8513    0.9379    0.8925       354
# staphylococcus     0.9610    0.9487    0.9548       156
#
#       accuracy                         0.8043      2340
#      macro avg     0.7018    0.7132    0.7040      2340
#   weighted avg     0.8312    0.8043    0.8155      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7963    0.7748    0.7854       111
#   enterobacter     0.3790    0.4052    0.3917       116
#   enterococcus     0.8214    0.9020    0.8598        51
#    escherichia     0.8655    0.8231    0.8438      1040
#     klebsiella     0.9204    0.7527    0.8282       461
#         others     0.0625    0.1765    0.0923        51
#    pseudomonas     0.8535    0.9379    0.8937       354
# staphylococcus     0.9673    0.9487    0.9579       156
#
#       accuracy                         0.7996      2340
#      macro avg     0.7082    0.7151    0.7066      2340
#   weighted avg     0.8354    0.7996    0.8146      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8190    0.7748    0.7963       111
#   enterobacter     0.4000    0.3966    0.3983       116
#   enterococcus     0.8214    0.9020    0.8598        51
#    escherichia     0.8673    0.8106    0.8380      1040
#     klebsiella     0.9268    0.7419    0.8241       461
#         others     0.0535    0.1961    0.0840        51
#    pseudomonas     0.8646    0.9379    0.8997       354
# staphylococcus     0.9737    0.9487    0.9610       156
#
#       accuracy                         0.7919      2340
#      macro avg     0.7158    0.7135    0.7077      2340
#   weighted avg     0.8415    0.7919    0.8131      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8333    0.7658    0.7981       111
#   enterobacter     0.4206    0.3879    0.4036       116
#   enterococcus     0.8214    0.9020    0.8598        51
#    escherichia     0.8657    0.7933    0.8279      1040
#     klebsiella     0.9252    0.7245    0.8127       461
#         others     0.0476    0.2157    0.0780        51
#    pseudomonas     0.8760    0.9379    0.9059       354
# staphylococcus     0.9735    0.9423    0.9577       156
#
#       accuracy                         0.7799      2340
#      macro avg     0.7204    0.7087    0.7055      2340
#   weighted avg     0.8438    0.7799    0.8072      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8571    0.7568    0.8038       111
#   enterobacter     0.4565    0.3621    0.4038       116
#   enterococcus     0.8214    0.9020    0.8598        51
#    escherichia     0.8727    0.7712    0.8188      1040
#     klebsiella     0.9362    0.7007    0.8015       461
#         others     0.0426    0.2549    0.0730        51
#    pseudomonas     0.8827    0.9350    0.9081       354
# staphylococcus     0.9800    0.9423    0.9608       156
#
#       accuracy                         0.7641      2340
#      macro avg     0.7312    0.7031    0.7037      2340
#   weighted avg     0.8533    0.7641    0.8017      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8750    0.7568    0.8116       111
#   enterobacter     0.4938    0.3448    0.4061       116
#   enterococcus     0.8519    0.9020    0.8762        51
#    escherichia     0.8792    0.7346    0.8004      1040
#     klebsiella     0.9419    0.6681    0.7817       461
#         others     0.0405    0.3137    0.0717        51
#    pseudomonas     0.8889    0.9266    0.9073       354
# staphylococcus     0.9866    0.9423    0.9639       156
#
#       accuracy                         0.7406      2340
#      macro avg     0.7447    0.6986    0.7024      2340
#   weighted avg     0.8620    0.7406    0.7906      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8830    0.7477    0.8098       111
#   enterobacter     0.4839    0.2586    0.3371       116
#   enterococcus     0.8519    0.9020    0.8762        51
#    escherichia     0.8856    0.6702    0.7630      1040
#     klebsiella     0.9639    0.6377    0.7676       461
#         others     0.0398    0.4118    0.0727        51
#    pseudomonas     0.9033    0.9237    0.9134       354
# staphylococcus     0.9866    0.9423    0.9639       156
#
#       accuracy                         0.7030      2340
#      macro avg     0.7498    0.6868    0.6880      2340
#   weighted avg     0.8713    0.7030    0.7686      2340
#
# ===================
# Finished
# ===================
# *** esm1b, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14810, 1280)
# Test set shape: (2822, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4481    0.7523    0.5616       109
#   enterobacter     0.1886    0.2575    0.2177       167
#   enterococcus     0.7692    0.6667    0.7143        60
#    escherichia     0.7404    0.6451    0.6895      1344
#     klebsiella     0.6281    0.5438    0.5829       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.5174    0.7607    0.6159       351
# staphylococcus     0.8564    0.9360    0.8944       172
#
#       accuracy                         0.6251      2822
#      macro avg     0.5185    0.5703    0.5346      2822
#   weighted avg     0.6384    0.6251    0.6247      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4607    0.7523    0.5714       109
#   enterobacter     0.1909    0.2515    0.2171       167
#   enterococcus     0.7843    0.6667    0.7207        60
#    escherichia     0.7441    0.6339    0.6846      1344
#     klebsiella     0.6473    0.5385    0.5879       559
#         others     0.0286    0.0333    0.0308        60
#    pseudomonas     0.5168    0.7436    0.6098       351
# staphylococcus     0.8564    0.9360    0.8944       172
#
#       accuracy                         0.6169      2822
#      macro avg     0.5286    0.5695    0.5396      2822
#   weighted avg     0.6455    0.6169    0.6238      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4765    0.7431    0.5806       109
#   enterobacter     0.1971    0.2455    0.2187       167
#   enterococcus     0.7843    0.6667    0.7207        60
#    escherichia     0.7478    0.6243    0.6805      1344
#     klebsiella     0.6556    0.5313    0.5870       559
#         others     0.0458    0.1000    0.0628        60
#    pseudomonas     0.5190    0.7379    0.6094       351
# staphylococcus     0.8564    0.9360    0.8944       172
#
#       accuracy                         0.6109      2822
#      macro avg     0.5353    0.5731    0.5443      2822
#   weighted avg     0.6505    0.6109    0.6227      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4938    0.7339    0.5904       109
#   enterobacter     0.2030    0.2395    0.2198       167
#   enterococcus     0.8000    0.6667    0.7273        60
#    escherichia     0.7525    0.6109    0.6743      1344
#     klebsiella     0.6621    0.5224    0.5840       559
#         others     0.0437    0.1500    0.0677        60
#    pseudomonas     0.5266    0.7322    0.6126       351
# staphylococcus     0.8610    0.9360    0.8969       172
#
#       accuracy                         0.6024      2822
#      macro avg     0.5429    0.5739    0.5466      2822
#   weighted avg     0.6566    0.6024    0.6204      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4938    0.7248    0.5874       109
#   enterobacter     0.2229    0.2335    0.2281       167
#   enterococcus     0.8000    0.6667    0.7273        60
#    escherichia     0.7528    0.5915    0.6625      1344
#     klebsiella     0.6810    0.5116    0.5843       559
#         others     0.0305    0.1500    0.0507        60
#    pseudomonas     0.5290    0.7265    0.6122       351
# staphylococcus     0.8750    0.9360    0.9045       172
#
#       accuracy                         0.5897      2822
#      macro avg     0.5481    0.5676    0.5446      2822
#   weighted avg     0.6625    0.5897    0.6153      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4938    0.7248    0.5874       109
#   enterobacter     0.2375    0.2275    0.2324       167
#   enterococcus     0.8000    0.6667    0.7273        60
#    escherichia     0.7662    0.5729    0.6556      1344
#     klebsiella     0.6946    0.5045    0.5845       559
#         others     0.0286    0.1833    0.0495        60
#    pseudomonas     0.5328    0.7179    0.6117       351
# staphylococcus     0.8750    0.9360    0.9045       172
#
#       accuracy                         0.5787      2822
#      macro avg     0.5536    0.5667    0.5441      2822
#   weighted avg     0.6728    0.5787    0.6122      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5032    0.7156    0.5909       109
#   enterobacter     0.2444    0.1976    0.2185       167
#   enterococcus     0.7959    0.6500    0.7156        60
#    escherichia     0.7813    0.5528    0.6475      1344
#     klebsiella     0.7135    0.4902    0.5811       559
#         others     0.0256    0.2167    0.0459        60
#    pseudomonas     0.5405    0.7037    0.6114       351
# staphylococcus     0.8750    0.9360    0.9045       172
#
#       accuracy                         0.5627      2822
#      macro avg     0.5599    0.5578    0.5394      2822
#   weighted avg     0.6854    0.5627    0.6066      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5133    0.7064    0.5946       109
#   enterobacter     0.2735    0.1916    0.2254       167
#   enterococcus     0.7917    0.6333    0.7037        60
#    escherichia     0.7879    0.5335    0.6362      1344
#     klebsiella     0.7200    0.4830    0.5782       559
#         others     0.0265    0.2667    0.0483        60
#    pseudomonas     0.5528    0.6866    0.6125       351
# staphylococcus     0.8798    0.9360    0.9070       172
#
#       accuracy                         0.5500      2822
#      macro avg     0.5682    0.5546    0.5382      2822
#   weighted avg     0.6937    0.5500    0.6013      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5396    0.6881    0.6048       109
#   enterobacter     0.3171    0.1557    0.2088       167
#   enterococcus     0.7917    0.6333    0.7037        60
#    escherichia     0.7928    0.5067    0.6182      1344
#     klebsiella     0.7299    0.4544    0.5601       559
#         others     0.0331    0.4167    0.0613        60
#    pseudomonas     0.5749    0.6667    0.6174       351
# staphylococcus     0.8798    0.9360    0.9070       172
#
#       accuracy                         0.5294      2822
#      macro avg     0.5823    0.5572    0.5352      2822
#   weighted avg     0.7044    0.5294    0.5895      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5726    0.6514    0.6094       109
#   enterobacter     0.2969    0.1138    0.1645       167
#   enterococcus     0.8085    0.6333    0.7103        60
#    escherichia     0.8063    0.4554    0.5820      1344
#     klebsiella     0.7461    0.4258    0.5421       559
#         others     0.0285    0.4500    0.0537        60
#    pseudomonas     0.5979    0.6524    0.6240       351
# staphylococcus     0.8889    0.9302    0.9091       172
#
#       accuracy                         0.4940      2822
#      macro avg     0.5932    0.5390    0.5244      2822
#   weighted avg     0.7178    0.4940    0.5671      2822
#
# ===================
# Finished
# ===================
# *** esm1b, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13093, 1280)
# Test set shape: (3153, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4167    0.7438    0.5341       121
#   enterobacter     0.1078    0.1122    0.1100       196
#   enterococcus     0.6667    0.6122    0.6383        49
#    escherichia     0.7041    0.7426    0.7228      1589
#     klebsiella     0.4421    0.3963    0.4179       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.6932    0.5817    0.6326       404
# staphylococcus     0.8493    0.7898    0.8185       157
#
#       accuracy                         0.6070      3153
#      macro avg     0.4850    0.4973    0.4843      3153
#   weighted avg     0.6014    0.6070    0.6013      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4300    0.7355    0.5427       121
#   enterobacter     0.1183    0.1122    0.1152       196
#   enterococcus     0.6818    0.6122    0.6452        49
#    escherichia     0.7154    0.7244    0.7198      1589
#     klebsiella     0.4497    0.3878    0.4164       588
#         others     0.0231    0.0612    0.0335        49
#    pseudomonas     0.7015    0.5644    0.6255       404
# staphylococcus     0.8552    0.7898    0.8212       157
#
#       accuracy                         0.5947      3153
#      macro avg     0.4969    0.4984    0.4899      3153
#   weighted avg     0.6117    0.5947    0.6000      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4335    0.7273    0.5432       121
#   enterobacter     0.1350    0.1122    0.1226       196
#   enterococcus     0.6977    0.6122    0.6522        49
#    escherichia     0.7231    0.7099    0.7164      1589
#     klebsiella     0.4577    0.3776    0.4138       588
#         others     0.0168    0.0816    0.0279        49
#    pseudomonas     0.7120    0.5569    0.6250       404
# staphylococcus     0.8552    0.7898    0.8212       157
#
#       accuracy                         0.5845      3153
#      macro avg     0.5039    0.4959    0.4903      3153
#   weighted avg     0.6197    0.5845    0.5982      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4444    0.7273    0.5517       121
#   enterobacter     0.1560    0.1122    0.1306       196
#   enterococcus     0.7143    0.6122    0.6593        49
#    escherichia     0.7312    0.6897    0.7098      1589
#     klebsiella     0.4728    0.3690    0.4145       588
#         others     0.0137    0.1020    0.0242        49
#    pseudomonas     0.7166    0.5446    0.6188       404
# staphylococcus     0.8601    0.7834    0.8200       157
#
#       accuracy                         0.5712      3153
#      macro avg     0.5136    0.4926    0.4911      3153
#   weighted avg     0.6294    0.5712    0.5951      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4526    0.7107    0.5531       121
#   enterobacter     0.1613    0.1020    0.1250       196
#   enterococcus     0.7500    0.6122    0.6742        49
#    escherichia     0.7379    0.6715    0.7031      1589
#     klebsiella     0.4930    0.3588    0.4154       588
#         others     0.0143    0.1429    0.0260        49
#    pseudomonas     0.7192    0.5198    0.6034       404
# staphylococcus     0.8601    0.7834    0.8200       157
#
#       accuracy                         0.5563      3153
#      macro avg     0.5236    0.4877    0.4900      3153
#   weighted avg     0.6381    0.5563    0.5898      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4725    0.7107    0.5677       121
#   enterobacter     0.1852    0.1020    0.1316       196
#   enterococcus     0.7500    0.6122    0.6742        49
#    escherichia     0.7462    0.6514    0.6956      1589
#     klebsiella     0.4975    0.3452    0.4076       588
#         others     0.0181    0.2245    0.0334        49
#    pseudomonas     0.7437    0.5099    0.6050       404
# staphylococcus     0.8662    0.7834    0.8227       157
#
#       accuracy                         0.5436      3153
#      macro avg     0.5349    0.4924    0.4922      3153
#   weighted avg     0.6489    0.5436    0.5860      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5059    0.7107    0.5911       121
#   enterobacter     0.2135    0.0969    0.1333       196
#   enterococcus     0.7500    0.6122    0.6742        49
#    escherichia     0.7502    0.6293    0.6845      1589
#     klebsiella     0.5051    0.3367    0.4041       588
#         others     0.0194    0.2857    0.0364        49
#    pseudomonas     0.7612    0.5050    0.6071       404
# staphylococcus     0.8786    0.7834    0.8283       157
#
#       accuracy                         0.5309      3153
#      macro avg     0.5480    0.4950    0.4949      3153
#   weighted avg     0.6582    0.5309    0.5814      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5247    0.7025    0.6007       121
#   enterobacter     0.2540    0.0816    0.1236       196
#   enterococcus     0.7838    0.5918    0.6744        49
#    escherichia     0.7553    0.6004    0.6690      1589
#     klebsiella     0.5192    0.3214    0.3971       588
#         others     0.0197    0.3469    0.0372        49
#    pseudomonas     0.7722    0.4950    0.6033       404
# staphylococcus     0.8786    0.7834    0.8283       157
#
#       accuracy                         0.5116      3153
#      macro avg     0.5634    0.4904    0.4917      3153
#   weighted avg     0.6686    0.5116    0.5715      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5804    0.6860    0.6288       121
#   enterobacter     0.3125    0.0765    0.1230       196
#   enterococcus     0.7838    0.5918    0.6744        49
#    escherichia     0.7529    0.5274    0.6203      1589
#     klebsiella     0.5343    0.3044    0.3879       588
#         others     0.0183    0.4082    0.0350        49
#    pseudomonas     0.8000    0.4851    0.6040       404
# staphylococcus     0.8913    0.7834    0.8339       157
#
#       accuracy                         0.4703      3153
#      macro avg     0.5842    0.4829    0.4884      3153
#   weighted avg     0.6801    0.4703    0.5466      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6480    0.6694    0.6585       121
#   enterobacter     0.3448    0.0510    0.0889       196
#   enterococcus     0.7879    0.5306    0.6341        49
#    escherichia     0.7503    0.4235    0.5414      1589
#     klebsiella     0.5540    0.2704    0.3634       588
#         others     0.0162    0.4694    0.0313        49
#    pseudomonas     0.8356    0.4653    0.5978       404
# staphylococcus     0.9111    0.7834    0.8425       157
#
#       accuracy                         0.4069      3153
#      macro avg     0.6060    0.4579    0.4697      3153
#   weighted avg     0.6927    0.4069    0.5003      3153
#
# ===================
# Finished
# ===================
# *** esm1b, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11648, 1280)
# Test set shape: (3203, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2810    0.6629    0.3946        89
#   enterobacter     0.1198    0.2130    0.1533       216
#   enterococcus     0.6481    0.8537    0.7368        41
#    escherichia     0.7477    0.5445    0.6302      1796
#     klebsiella     0.4459    0.3131    0.3679       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.3478    0.8006    0.4849       311
# staphylococcus     0.9255    0.8187    0.8688       182
#
#       accuracy                         0.5248      3203
#      macro avg     0.4395    0.5258    0.4546      3203
#   weighted avg     0.6032    0.5248    0.5411      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2775    0.6517    0.3893        89
#   enterobacter     0.1209    0.2037    0.1517       216
#   enterococcus     0.6481    0.8537    0.7368        41
#    escherichia     0.7556    0.5234    0.6184      1796
#     klebsiella     0.4535    0.3055    0.3651       527
#         others     0.0339    0.0976    0.0503        41
#    pseudomonas     0.3567    0.8006    0.4936       311
# staphylococcus     0.9255    0.8187    0.8688       182
#
#       accuracy                         0.5120      3203
#      macro avg     0.4465    0.5319    0.4593      3203
#   weighted avg     0.6101    0.5120    0.5352      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2850    0.6404    0.3945        89
#   enterobacter     0.1280    0.1991    0.1558       216
#   enterococcus     0.6415    0.8293    0.7234        41
#    escherichia     0.7582    0.4994    0.6022      1796
#     klebsiella     0.4801    0.2979    0.3677       527
#         others     0.0301    0.1951    0.0521        41
#    pseudomonas     0.3648    0.7942    0.5000       311
# staphylococcus     0.9255    0.8187    0.8688       182
#
#       accuracy                         0.4970      3203
#      macro avg     0.4517    0.5343    0.4581      3203
#   weighted avg     0.6173    0.4970    0.5275      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2984    0.6404    0.4071        89
#   enterobacter     0.1387    0.1991    0.1635       216
#   enterococcus     0.6538    0.8293    0.7312        41
#    escherichia     0.7634    0.4850    0.5931      1796
#     klebsiella     0.5016    0.2903    0.3678       527
#         others     0.0231    0.2195    0.0418        41
#    pseudomonas     0.3767    0.7910    0.5104       311
# staphylococcus     0.9255    0.8187    0.8688       182
#
#       accuracy                         0.4877      3203
#      macro avg     0.4602    0.5342    0.4605      3203
#   weighted avg     0.6261    0.4877    0.5242      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3098    0.6404    0.4176        89
#   enterobacter     0.1444    0.1852    0.1623       216
#   enterococcus     0.6538    0.8293    0.7312        41
#    escherichia     0.7606    0.4616    0.5745      1796
#     klebsiella     0.5052    0.2770    0.3578       527
#         others     0.0177    0.2195    0.0328        41
#    pseudomonas     0.3816    0.7878    0.5142       311
# staphylococcus     0.9255    0.8187    0.8688       182
#
#       accuracy                         0.4711      3203
#      macro avg     0.4623    0.5274    0.4574      3203
#   weighted avg     0.6262    0.4711    0.5126      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3234    0.6067    0.4219        89
#   enterobacter     0.1514    0.1759    0.1627       216
#   enterococcus     0.6471    0.8049    0.7174        41
#    escherichia     0.7678    0.4438    0.5625      1796
#     klebsiella     0.5201    0.2694    0.3550       527
#         others     0.0157    0.2439    0.0295        41
#    pseudomonas     0.3878    0.7781    0.5176       311
# staphylococcus     0.9255    0.8187    0.8688       182
#
#       accuracy                         0.4574      3203
#      macro avg     0.4673    0.5177    0.4544      3203
#   weighted avg     0.6340    0.4574    0.5057      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3228    0.5730    0.4130        89
#   enterobacter     0.1586    0.1667    0.1625       216
#   enterococcus     0.6531    0.7805    0.7111        41
#    escherichia     0.7708    0.4176    0.5417      1796
#     klebsiella     0.5447    0.2543    0.3467       527
#         others     0.0139    0.2683    0.0264        41
#    pseudomonas     0.4003    0.7685    0.5264       311
# staphylococcus     0.9313    0.8187    0.8713       182
#
#       accuracy                         0.4377      3203
#      macro avg     0.4744    0.5059    0.4499      3203
#   weighted avg     0.6418    0.4377    0.4933      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3289    0.5506    0.4118        89
#   enterobacter     0.1803    0.1528    0.1654       216
#   enterococcus     0.6809    0.7805    0.7273        41
#    escherichia     0.7730    0.3925    0.5207      1796
#     klebsiella     0.5919    0.2505    0.3520       527
#         others     0.0124    0.2927    0.0238        41
#    pseudomonas     0.4139    0.7492    0.5332       311
# staphylococcus     0.9371    0.8187    0.8739       182
#
#       accuracy                         0.4199      3203
#      macro avg     0.4898    0.4984    0.4510      3203
#   weighted avg     0.6545    0.4199    0.4835      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3672    0.5281    0.4332        89
#   enterobacter     0.1781    0.1204    0.1436       216
#   enterococcus     0.7442    0.7805    0.7619        41
#    escherichia     0.7795    0.3719    0.5036      1796
#     klebsiella     0.6354    0.2182    0.3249       527
#         others     0.0138    0.3902    0.0266        41
#    pseudomonas     0.4329    0.7363    0.5452       311
# staphylococcus     0.9430    0.8187    0.8765       182
#
#       accuracy                         0.4002      3203
#      macro avg     0.5117    0.4955    0.4519      3203
#   weighted avg     0.6691    0.4002    0.4704      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3894    0.4944    0.4356        89
#   enterobacter     0.2034    0.1111    0.1437       216
#   enterococcus     0.7381    0.7561    0.7470        41
#    escherichia     0.7942    0.3352    0.4714      1796
#     klebsiella     0.7045    0.1765    0.2822       527
#         others     0.0128    0.4390    0.0248        41
#    pseudomonas     0.4748    0.7267    0.5743       311
# staphylococcus     0.9548    0.8132    0.8783       182
#
#       accuracy                         0.3703      3203
#      macro avg     0.5340    0.4815    0.4447      3203
#   weighted avg     0.6957    0.3703    0.4481      3203
#
# ===================
# Finished
# ===================
