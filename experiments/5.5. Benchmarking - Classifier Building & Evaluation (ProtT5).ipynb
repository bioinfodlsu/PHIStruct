# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_prott5.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_prott5_relaxed_r3.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_prott5.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.5. Benchmarking - Classifier Building & Evaluation (ProtT5).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a multilayer perceptron, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = ["PROTT5"]

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_saprot_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-mlp-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="MLP-prot",
        )
# Out:
# *** prott5, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16928, 1024)
# Test set shape: (2340, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9082    0.8018    0.8517       111
#   enterobacter     0.2886    0.5000    0.3659       116
#   enterococcus     0.8364    0.9020    0.8679        51
#    escherichia     0.8804    0.8279    0.8533      1040
#     klebsiella     0.8687    0.8612    0.8649       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8641    0.9520    0.9059       354
# staphylococcus     0.9379    0.9679    0.9527       156
#
#       accuracy                         0.8286      2340
#      macro avg     0.6980    0.7266    0.7078      2340
#   weighted avg     0.8313    0.8286    0.8277      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9167    0.7928    0.8502       111
#   enterobacter     0.2857    0.4655    0.3541       116
#   enterococcus     0.8519    0.9020    0.8762        51
#    escherichia     0.8867    0.8202    0.8521      1040
#     klebsiella     0.8756    0.8547    0.8650       461
#         others     0.1026    0.0784    0.0889        51
#    pseudomonas     0.8638    0.9492    0.9044       354
# staphylococcus     0.9379    0.9679    0.9527       156
#
#       accuracy                         0.8231      2340
#      macro avg     0.7151    0.7288    0.7180      2340
#   weighted avg     0.8382    0.8231    0.8284      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9263    0.7928    0.8544       111
#   enterobacter     0.2896    0.4569    0.3545       116
#   enterococcus     0.8519    0.9020    0.8762        51
#    escherichia     0.8910    0.8096    0.8484      1040
#     klebsiella     0.8831    0.8525    0.8675       461
#         others     0.0833    0.1176    0.0976        51
#    pseudomonas     0.8705    0.9492    0.9081       354
# staphylococcus     0.9375    0.9615    0.9494       156
#
#       accuracy                         0.8179      2340
#      macro avg     0.7167    0.7303    0.7195      2340
#   weighted avg     0.8429    0.8179    0.8280      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9255    0.7838    0.8488       111
#   enterobacter     0.2959    0.4310    0.3509       116
#   enterococcus     0.8519    0.9020    0.8762        51
#    escherichia     0.8924    0.7971    0.8421      1040
#     klebsiella     0.8866    0.8482    0.8670       461
#         others     0.0631    0.1373    0.0864        51
#    pseudomonas     0.8747    0.9463    0.9091       354
# staphylococcus     0.9434    0.9615    0.9524       156
#
#       accuracy                         0.8098      2340
#      macro avg     0.7167    0.7259    0.7166      2340
#   weighted avg     0.8450    0.8098    0.8247      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9348    0.7748    0.8473       111
#   enterobacter     0.3057    0.4138    0.3516       116
#   enterococcus     0.8519    0.9020    0.8762        51
#    escherichia     0.8943    0.7894    0.8386      1040
#     klebsiella     0.8864    0.8460    0.8657       461
#         others     0.0500    0.1373    0.0733        51
#    pseudomonas     0.8789    0.9435    0.9101       354
# staphylococcus     0.9434    0.9615    0.9524       156
#
#       accuracy                         0.8043      2340
#      macro avg     0.7182    0.7210    0.7144      2340
#   weighted avg     0.8471    0.8043    0.8228      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9348    0.7748    0.8473       111
#   enterobacter     0.3103    0.3879    0.3448       116
#   enterococcus     0.8679    0.9020    0.8846        51
#    escherichia     0.8939    0.7779    0.8319      1040
#     klebsiella     0.8920    0.8416    0.8661       461
#         others     0.0465    0.1569    0.0717        51
#    pseudomonas     0.8813    0.9435    0.9113       354
# staphylococcus     0.9434    0.9615    0.9524       156
#
#       accuracy                         0.7974      2340
#      macro avg     0.7213    0.7183    0.7138      2340
#   weighted avg     0.8489    0.7974    0.8198      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9341    0.7658    0.8416       111
#   enterobacter     0.3237    0.3879    0.3529       116
#   enterococcus     0.8679    0.9020    0.8846        51
#    escherichia     0.8959    0.7692    0.8277      1040
#     klebsiella     0.8956    0.8373    0.8655       461
#         others     0.0500    0.1961    0.0797        51
#    pseudomonas     0.8930    0.9435    0.9176       354
# staphylococcus     0.9434    0.9615    0.9524       156
#
#       accuracy                         0.7932      2340
#      macro avg     0.7255    0.7204    0.7152      2340
#   weighted avg     0.8530    0.7932    0.8191      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9318    0.7387    0.8241       111
#   enterobacter     0.3385    0.3793    0.3577       116
#   enterococcus     0.8846    0.9020    0.8932        51
#    escherichia     0.8977    0.7596    0.8229      1040
#     klebsiella     0.9038    0.8351    0.8681       461
#         others     0.0551    0.2549    0.0906        51
#    pseudomonas     0.8973    0.9379    0.9171       354
# staphylococcus     0.9430    0.9551    0.9490       156
#
#       accuracy                         0.7868      2340
#      macro avg     0.7315    0.7203    0.7154      2340
#   weighted avg     0.8571    0.7868    0.8170      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9318    0.7387    0.8241       111
#   enterobacter     0.3761    0.3534    0.3644       116
#   enterococcus     0.8846    0.9020    0.8932        51
#    escherichia     0.9041    0.7433    0.8158      1040
#     klebsiella     0.9093    0.8265    0.8659       461
#         others     0.0473    0.2745    0.0807        51
#    pseudomonas     0.9091    0.9322    0.9205       354
# staphylococcus     0.9430    0.9551    0.9490       156
#
#       accuracy                         0.7761      2340
#      macro avg     0.7382    0.7157    0.7142      2340
#   weighted avg     0.8645    0.7761    0.8141      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9419    0.7297    0.8223       111
#   enterobacter     0.4130    0.3276    0.3654       116
#   enterococcus     0.8824    0.8824    0.8824        51
#    escherichia     0.9124    0.7212    0.8056      1040
#     klebsiella     0.9169    0.7896    0.8485       461
#         others     0.0427    0.3137    0.0751        51
#    pseudomonas     0.9167    0.9322    0.9244       354
# staphylococcus     0.9427    0.9487    0.9457       156
#
#       accuracy                         0.7573      2340
#      macro avg     0.7461    0.7056    0.7087      2340
#   weighted avg     0.8730    0.7573    0.8061      2340
#
# ===================
# Finished
# ===================
# *** prott5, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14804, 1024)
# Test set shape: (2822, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5726    0.6514    0.6094       109
#   enterobacter     0.1989    0.2096    0.2041       167
#   enterococcus     0.8125    0.6500    0.7222        60
#    escherichia     0.7645    0.7054    0.7337      1344
#     klebsiella     0.6011    0.6118    0.6064       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.5632    0.7493    0.6430       351
# staphylococcus     0.8434    0.9709    0.9027       172
#
#       accuracy                         0.6609      2822
#      macro avg     0.5445    0.5685    0.5527      2822
#   weighted avg     0.6558    0.6609    0.6555      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5833    0.6422    0.6114       109
#   enterobacter     0.2166    0.2036    0.2099       167
#   enterococcus     0.8478    0.6500    0.7358        60
#    escherichia     0.7664    0.6935    0.7281      1344
#     klebsiella     0.6064    0.6064    0.6064       559
#         others     0.0260    0.0333    0.0292        60
#    pseudomonas     0.5762    0.7436    0.6493       351
# staphylococcus     0.8505    0.9593    0.9016       172
#
#       accuracy                         0.6527      2822
#      macro avg     0.5592    0.5665    0.5590      2822
#   weighted avg     0.6626    0.6527    0.6549      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5847    0.6330    0.6079       109
#   enterobacter     0.2482    0.2036    0.2237       167
#   enterococcus     0.8478    0.6500    0.7358        60
#    escherichia     0.7686    0.6845    0.7241      1344
#     klebsiella     0.6199    0.6011    0.6104       559
#         others     0.0333    0.0833    0.0476        60
#    pseudomonas     0.5831    0.7293    0.6481       351
# staphylococcus     0.8497    0.9535    0.8986       172
#
#       accuracy                         0.6460      2822
#      macro avg     0.5669    0.5673    0.5620      2822
#   weighted avg     0.6692    0.6460    0.6545      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5897    0.6330    0.6106       109
#   enterobacter     0.2810    0.2036    0.2361       167
#   enterococcus     0.8667    0.6500    0.7429        60
#    escherichia     0.7751    0.6771    0.7228      1344
#     klebsiella     0.6324    0.5939    0.6125       559
#         others     0.0269    0.1000    0.0424        60
#    pseudomonas     0.5859    0.7094    0.6418       351
# staphylococcus     0.8542    0.9535    0.9011       172
#
#       accuracy                         0.6389      2822
#      macro avg     0.5765    0.5651    0.5638      2822
#   weighted avg     0.6778    0.6389    0.6546      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6053    0.6330    0.6188       109
#   enterobacter     0.3091    0.2036    0.2455       167
#   enterococcus     0.8864    0.6500    0.7500        60
#    escherichia     0.7781    0.6600    0.7142      1344
#     klebsiella     0.6450    0.5850    0.6135       559
#         others     0.0192    0.1000    0.0323        60
#    pseudomonas     0.6059    0.7009    0.6499       351
# staphylococcus     0.8624    0.9477    0.9030       172
#
#       accuracy                         0.6276      2822
#      macro avg     0.5889    0.5600    0.5659      2822
#   weighted avg     0.6872    0.6276    0.6526      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6449    0.6330    0.6389       109
#   enterobacter     0.3204    0.1976    0.2444       167
#   enterococcus     0.9024    0.6167    0.7327        60
#    escherichia     0.7846    0.6503    0.7111      1344
#     klebsiella     0.6545    0.5760    0.6127       559
#         others     0.0257    0.1667    0.0445        60
#    pseudomonas     0.6272    0.6952    0.6595       351
# staphylococcus     0.8717    0.9477    0.9081       172
#
#       accuracy                         0.6208      2822
#      macro avg     0.6039    0.5604    0.5690      2822
#   weighted avg     0.6980    0.6208    0.6531      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6436    0.5963    0.6190       109
#   enterobacter     0.3298    0.1856    0.2375       167
#   enterococcus     0.9487    0.6167    0.7475        60
#    escherichia     0.7876    0.6317    0.7011      1344
#     klebsiella     0.6618    0.5635    0.6087       559
#         others     0.0297    0.2333    0.0526        60
#    pseudomonas     0.6400    0.6838    0.6612       351
# staphylococcus     0.8717    0.9477    0.9081       172
#
#       accuracy                         0.6074      2822
#      macro avg     0.6141    0.5573    0.5670      2822
#   weighted avg     0.7041    0.6074    0.6470      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6633    0.5963    0.6280       109
#   enterobacter     0.3452    0.1737    0.2311       167
#   enterococcus     0.9487    0.6167    0.7475        60
#    escherichia     0.7903    0.6168    0.6929      1344
#     klebsiella     0.6644    0.5349    0.5927       559
#         others     0.0321    0.3000    0.0580        60
#    pseudomonas     0.6667    0.6724    0.6695       351
# staphylococcus     0.8717    0.9477    0.9081       172
#
#       accuracy                         0.5939      2822
#      macro avg     0.6228    0.5573    0.5660      2822
#   weighted avg     0.7109    0.5939    0.6411      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6882    0.5872    0.6337       109
#   enterobacter     0.4194    0.1557    0.2271       167
#   enterococcus     0.9487    0.6167    0.7475        60
#    escherichia     0.7964    0.5908    0.6783      1344
#     klebsiella     0.6773    0.4919    0.5699       559
#         others     0.0323    0.3833    0.0596        60
#    pseudomonas     0.6930    0.6496    0.6706       351
# staphylococcus     0.8750    0.9360    0.9045       172
#
#       accuracy                         0.5698      2822
#      macro avg     0.6413    0.5514    0.5614      2822
#   weighted avg     0.7252    0.5698    0.6296      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7011    0.5596    0.6224       109
#   enterobacter     0.4615    0.1078    0.1748       167
#   enterococcus     0.9459    0.5833    0.7216        60
#    escherichia     0.8043    0.5320    0.6404      1344
#     klebsiella     0.7000    0.4383    0.5391       559
#         others     0.0287    0.4500    0.0540        60
#    pseudomonas     0.7023    0.5983    0.6462       351
# staphylococcus     0.8729    0.9186    0.8952       172
#
#       accuracy                         0.5206      2822
#      macro avg     0.6521    0.5235    0.5367      2822
#   weighted avg     0.7374    0.5206    0.5976      2822
#
# ===================
# Finished
# ===================
# *** prott5, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13089, 1024)
# Test set shape: (3153, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4167    0.7851    0.5444       121
#   enterobacter     0.1897    0.1888    0.1893       196
#   enterococcus     0.5571    0.7959    0.6555        49
#    escherichia     0.7299    0.7552    0.7423      1589
#     klebsiella     0.5639    0.4354    0.4914       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.6815    0.6832    0.6823       404
# staphylococcus     0.8280    0.8280    0.8280       157
#
#       accuracy                         0.6448      3153
#      macro avg     0.4959    0.5589    0.5166      3153
#   weighted avg     0.6380    0.6448    0.6373      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4279    0.7851    0.5539       121
#   enterobacter     0.1977    0.1786    0.1877       196
#   enterococcus     0.5652    0.7959    0.6610        49
#    escherichia     0.7335    0.7432    0.7384      1589
#     klebsiella     0.5616    0.4184    0.4795       588
#         others     0.0256    0.0408    0.0315        49
#    pseudomonas     0.6866    0.6832    0.6849       404
# staphylococcus     0.8280    0.8280    0.8280       157
#
#       accuracy                         0.6356      3153
#      macro avg     0.5033    0.5592    0.5206      3153
#   weighted avg     0.6415    0.6356    0.6342      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4338    0.7851    0.5588       121
#   enterobacter     0.2000    0.1684    0.1828       196
#   enterococcus     0.5652    0.7959    0.6610        49
#    escherichia     0.7352    0.7269    0.7310      1589
#     klebsiella     0.5579    0.4014    0.4669       588
#         others     0.0195    0.0612    0.0296        49
#    pseudomonas     0.6935    0.6832    0.6883       404
# staphylococcus     0.8377    0.8217    0.8296       157
#
#       accuracy                         0.6235      3153
#      macro avg     0.5053    0.5555    0.5185      3153
#   weighted avg     0.6433    0.6235    0.6285      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4352    0.7769    0.5579       121
#   enterobacter     0.2200    0.1684    0.1908       196
#   enterococcus     0.5652    0.7959    0.6610        49
#    escherichia     0.7363    0.7099    0.7228      1589
#     klebsiella     0.5639    0.3827    0.4559       588
#         others     0.0165    0.0816    0.0275        49
#    pseudomonas     0.7041    0.6832    0.6935       404
# staphylococcus     0.8431    0.8217    0.8323       157
#
#       accuracy                         0.6115      3153
#      macro avg     0.5105    0.5525    0.5177      3153
#   weighted avg     0.6478    0.6115    0.6236      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4413    0.7769    0.5629       121
#   enterobacter     0.2336    0.1633    0.1922       196
#   enterococcus     0.5821    0.7959    0.6724        49
#    escherichia     0.7392    0.6885    0.7129      1589
#     klebsiella     0.5670    0.3741    0.4508       588
#         others     0.0240    0.1633    0.0419        49
#    pseudomonas     0.7109    0.6757    0.6929       404
# staphylococcus     0.8543    0.8217    0.8377       157
#
#       accuracy                         0.5991      3153
#      macro avg     0.5191    0.5574    0.5205      3153
#   weighted avg     0.6528    0.5991    0.6185      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4554    0.7603    0.5697       121
#   enterobacter     0.2458    0.1480    0.1847       196
#   enterococcus     0.6129    0.7755    0.6847        49
#    escherichia     0.7432    0.6683    0.7038      1589
#     klebsiella     0.5928    0.3639    0.4510       588
#         others     0.0198    0.1837    0.0357        49
#    pseudomonas     0.7207    0.6708    0.6949       404
# staphylococcus     0.8600    0.8217    0.8404       157
#
#       accuracy                         0.5848      3153
#      macro avg     0.5313    0.5490    0.5206      3153
#   weighted avg     0.6628    0.5848    0.6142      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4715    0.7521    0.5796       121
#   enterobacter     0.2524    0.1327    0.1739       196
#   enterococcus     0.6129    0.7755    0.6847        49
#    escherichia     0.7409    0.6388    0.6860      1589
#     klebsiella     0.6023    0.3554    0.4471       588
#         others     0.0212    0.2449    0.0390        49
#    pseudomonas     0.7335    0.6609    0.6953       404
# staphylococcus     0.8776    0.8217    0.8487       157
#
#       accuracy                         0.5668      3153
#      macro avg     0.5390    0.5477    0.5193      3153
#   weighted avg     0.6670    0.5668    0.6048      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4865    0.7438    0.5882       121
#   enterobacter     0.2637    0.1224    0.1672       196
#   enterococcus     0.6491    0.7551    0.6981        49
#    escherichia     0.7427    0.6067    0.6678      1589
#     klebsiella     0.6137    0.3350    0.4334       588
#         others     0.0228    0.3265    0.0426        49
#    pseudomonas     0.7373    0.6460    0.6887       404
# staphylococcus     0.8958    0.8217    0.8571       157
#
#       accuracy                         0.5449      3153
#      macro avg     0.5515    0.5447    0.5179      3153
#   weighted avg     0.6733    0.5449    0.5928      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5000    0.7190    0.5898       121
#   enterobacter     0.2439    0.1020    0.1439       196
#   enterococcus     0.6852    0.7551    0.7184        49
#    escherichia     0.7446    0.5632    0.6413      1589
#     klebsiella     0.6293    0.3146    0.4195       588
#         others     0.0233    0.4082    0.0442        49
#    pseudomonas     0.7435    0.6386    0.6871       404
# staphylococcus     0.8951    0.8153    0.8533       157
#
#       accuracy                         0.5170      3153
#      macro avg     0.5581    0.5395    0.5122      3153
#   weighted avg     0.6778    0.5170    0.5754      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5380    0.7025    0.6093       121
#   enterobacter     0.2462    0.0816    0.1226       196
#   enterococcus     0.7660    0.7347    0.7500        49
#    escherichia     0.7563    0.5135    0.6117      1589
#     klebsiella     0.6406    0.2789    0.3886       588
#         others     0.0223    0.4898    0.0426        49
#    pseudomonas     0.7583    0.6213    0.6830       404
# staphylococcus     0.9143    0.8153    0.8620       157
#
#       accuracy                         0.4821      3153
#      macro avg     0.5802    0.5297    0.5087      3153
#   weighted avg     0.6915    0.4821    0.5545      3153
#
# ===================
# Finished
# ===================
# *** prott5, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11648, 1024)
# Test set shape: (3203, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3457    0.6292    0.4462        89
#   enterobacter     0.1953    0.2685    0.2261       216
#   enterococcus     0.5738    0.8537    0.6863        41
#    escherichia     0.7474    0.6325    0.6852      1796
#     klebsiella     0.4509    0.4269    0.4386       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.4249    0.6913    0.5263       311
# staphylococcus     0.9051    0.7857    0.8412       182
#
#       accuracy                         0.5832      3203
#      macro avg     0.4554    0.5360    0.4812      3203
#   weighted avg     0.6161    0.5832    0.5917      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3590    0.6292    0.4571        89
#   enterobacter     0.2045    0.2546    0.2268       216
#   enterococcus     0.5932    0.8537    0.7000        41
#    escherichia     0.7490    0.6180    0.6772      1796
#     klebsiella     0.4625    0.4099    0.4346       527
#         others     0.0163    0.0488    0.0244        41
#    pseudomonas     0.4318    0.6817    0.5287       311
# staphylococcus     0.9167    0.7857    0.8462       182
#
#       accuracy                         0.5710      3203
#      macro avg     0.4666    0.5352    0.4869      3203
#   weighted avg     0.6217    0.5710    0.5879      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3819    0.6180    0.4721        89
#   enterobacter     0.2122    0.2407    0.2256       216
#   enterococcus     0.6140    0.8537    0.7143        41
#    escherichia     0.7533    0.6052    0.6712      1796
#     klebsiella     0.4652    0.3928    0.4259       527
#         others     0.0085    0.0488    0.0145        41
#    pseudomonas     0.4396    0.6785    0.5335       311
# staphylococcus     0.9226    0.7857    0.8487       182
#
#       accuracy                         0.5595      3203
#      macro avg     0.4747    0.5279    0.4882      3203
#   weighted avg     0.6269    0.5595    0.5841      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4015    0.6180    0.4867        89
#   enterobacter     0.2115    0.2037    0.2075       216
#   enterococcus     0.6250    0.8537    0.7216        41
#    escherichia     0.7559    0.5913    0.6635      1796
#     klebsiella     0.4690    0.3738    0.4161       527
#         others     0.0084    0.0732    0.0150        41
#    pseudomonas     0.4483    0.6688    0.5368       311
# staphylococcus     0.9226    0.7857    0.8487       182
#
#       accuracy                         0.5454      3203
#      macro avg     0.4803    0.5210    0.4870      3203
#   weighted avg     0.6305    0.5454    0.5778      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4167    0.6180    0.4977        89
#   enterobacter     0.2204    0.1898    0.2040       216
#   enterococcus     0.6481    0.8537    0.7368        41
#    escherichia     0.7642    0.5774    0.6578      1796
#     klebsiella     0.4695    0.3510    0.4017       527
#         others     0.0063    0.0732    0.0116        41
#    pseudomonas     0.4600    0.6656    0.5440       311
# staphylococcus     0.9226    0.7857    0.8487       182
#
#       accuracy                         0.5326      3203
#      macro avg     0.4885    0.5143    0.4878      3203
#   weighted avg     0.6377    0.5326    0.5731      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4219    0.6067    0.4977        89
#   enterobacter     0.2390    0.1759    0.2027       216
#   enterococcus     0.6604    0.8537    0.7447        41
#    escherichia     0.7713    0.5596    0.6486      1796
#     klebsiella     0.4738    0.3264    0.3865       527
#         others     0.0065    0.0976    0.0121        41
#    pseudomonas     0.4765    0.6527    0.5509       311
# staphylococcus     0.9408    0.7857    0.8563       182
#
#       accuracy                         0.5164      3203
#      macro avg     0.4988    0.5073    0.4874      3203
#   weighted avg     0.6465    0.5164    0.5666      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4320    0.6067    0.5047        89
#   enterobacter     0.2576    0.1574    0.1954       216
#   enterococcus     0.7000    0.8537    0.7692        41
#    escherichia     0.7835    0.5379    0.6378      1796
#     klebsiella     0.4809    0.3112    0.3779       527
#         others     0.0092    0.1707    0.0174        41
#    pseudomonas     0.4889    0.6399    0.5543       311
# staphylococcus     0.9408    0.7857    0.8563       182
#
#       accuracy                         0.5002      3203
#      macro avg     0.5116    0.5079    0.4891      3203
#   weighted avg     0.6578    0.5002    0.5596      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4390    0.6067    0.5094        89
#   enterobacter     0.2830    0.1389    0.1863       216
#   enterococcus     0.7447    0.8537    0.7955        41
#    escherichia     0.7916    0.5117    0.6216      1796
#     klebsiella     0.4953    0.3017    0.3750       527
#         others     0.0099    0.2195    0.0190        41
#    pseudomonas     0.5000    0.6206    0.5538       311
# staphylococcus     0.9470    0.7857    0.8589       182
#
#       accuracy                         0.4814      3203
#      macro avg     0.5263    0.5048    0.4899      3203
#   weighted avg     0.6686    0.4814    0.5500      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4609    0.5955    0.5196        89
#   enterobacter     0.3023    0.1204    0.1722       216
#   enterococcus     0.7955    0.8537    0.8235        41
#    escherichia     0.8005    0.4872    0.6057      1796
#     klebsiella     0.5000    0.2808    0.3597       527
#         others     0.0114    0.2927    0.0219        41
#    pseudomonas     0.5055    0.5916    0.5452       311
# staphylococcus     0.9533    0.7857    0.8614       182
#
#       accuracy                         0.4608      3203
#      macro avg     0.5412    0.5010    0.4887      3203
#   weighted avg     0.6779    0.4608    0.5376      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4904    0.5730    0.5285        89
#   enterobacter     0.2553    0.0556    0.0913       216
#   enterococcus     0.8537    0.8537    0.8537        41
#    escherichia     0.8048    0.4315    0.5618      1796
#     klebsiella     0.5079    0.2429    0.3286       527
#         others     0.0106    0.3415    0.0206        41
#    pseudomonas     0.5228    0.5531    0.5375       311
# staphylococcus     0.9592    0.7747    0.8571       182
#
#       accuracy                         0.4146      3203
#      macro avg     0.5506    0.4782    0.4724      3203
#   weighted avg     0.6820    0.4146    0.5020      3203
#
# ===================
# Finished
# ===================
