# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_saprot_mask_relaxed_r3.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. If you have run `3.3. Data Consolidation (SaProt with Low-Confidence Masking).ipynb`, then `data/inphared/consolidated` should have already been populated with the prerequisite files.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_mask_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.6. Benchmarking - Classifier Building & Evaluation (SaProt with Low-Confidence Masking).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a multilayer perceptron, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = list(constants.SAPROT_MASK_PLM.keys())

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_saprot_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-mlp-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            feature_columns=[f"s{i}" for i in range(1, 1281)],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="MLP",
        )
# Out:
# *** saprot_mask_relaxed_r3, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16934, 1280)
# Test set shape: (2340, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9574    0.8108    0.8780       111
#   enterobacter     0.3197    0.4052    0.3574       116
#   enterococcus     0.7931    0.9020    0.8440        51
#    escherichia     0.8759    0.8615    0.8686      1040
#     klebsiella     0.8703    0.8590    0.8646       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8374    0.9746    0.9008       354
# staphylococcus     0.9669    0.9359    0.9511       156
#
#       accuracy                         0.8402      2340
#      macro avg     0.7026    0.7186    0.7081      2340
#   weighted avg     0.8304    0.8402    0.8338      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9574    0.8108    0.8780       111
#   enterobacter     0.3333    0.3966    0.3622       116
#   enterococcus     0.7931    0.9020    0.8440        51
#    escherichia     0.8783    0.8538    0.8659      1040
#     klebsiella     0.8739    0.8568    0.8653       461
#         others     0.0385    0.0196    0.0260        51
#    pseudomonas     0.8415    0.9746    0.9031       354
# staphylococcus     0.9669    0.9359    0.9511       156
#
#       accuracy                         0.8363      2340
#      macro avg     0.7104    0.7188    0.7120      2340
#   weighted avg     0.8344    0.8363    0.8339      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9574    0.8108    0.8780       111
#   enterobacter     0.3511    0.3966    0.3725       116
#   enterococcus     0.7931    0.9020    0.8440        51
#    escherichia     0.8795    0.8423    0.8605      1040
#     klebsiella     0.8795    0.8547    0.8669       461
#         others     0.0357    0.0392    0.0374        51
#    pseudomonas     0.8456    0.9746    0.9055       354
# staphylococcus     0.9732    0.9295    0.9508       156
#
#       accuracy                         0.8308      2340
#      macro avg     0.7144    0.7187    0.7145      2340
#   weighted avg     0.8378    0.8308    0.8329      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9574    0.8108    0.8780       111
#   enterobacter     0.3659    0.3879    0.3766       116
#   enterococcus     0.8214    0.9020    0.8598        51
#    escherichia     0.8830    0.8346    0.8581      1040
#     klebsiella     0.8907    0.8482    0.8689       461
#         others     0.0330    0.0588    0.0423        51
#    pseudomonas     0.8477    0.9746    0.9067       354
# staphylococcus     0.9864    0.9295    0.9571       156
#
#       accuracy                         0.8261      2340
#      macro avg     0.7232    0.7183    0.7184      2340
#   weighted avg     0.8441    0.8261    0.8335      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9574    0.8108    0.8780       111
#   enterobacter     0.3805    0.3707    0.3755       116
#   enterococcus     0.8519    0.9020    0.8762        51
#    escherichia     0.8872    0.8240    0.8544      1040
#     klebsiella     0.8986    0.8460    0.8715       461
#         others     0.0382    0.0980    0.0549        51
#    pseudomonas     0.8554    0.9689    0.9086       354
# staphylococcus     0.9864    0.9295    0.9571       156
#
#       accuracy                         0.8201      2340
#      macro avg     0.7319    0.7187    0.7220      2340
#   weighted avg     0.8502    0.8201    0.8333      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9574    0.8108    0.8780       111
#   enterobacter     0.3861    0.3362    0.3594       116
#   enterococcus     0.8679    0.9020    0.8846        51
#    escherichia     0.8903    0.8115    0.8491      1040
#     klebsiella     0.9059    0.8351    0.8691       461
#         others     0.0289    0.0980    0.0446        51
#    pseudomonas     0.8571    0.9661    0.9084       354
# staphylococcus     0.9864    0.9295    0.9571       156
#
#       accuracy                         0.8103      2340
#      macro avg     0.7350    0.7112    0.7188      2340
#   weighted avg     0.8537    0.8103    0.8295      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9677    0.8108    0.8824       111
#   enterobacter     0.3913    0.3103    0.3462       116
#   enterococcus     0.8846    0.9020    0.8932        51
#    escherichia     0.8963    0.7981    0.8444      1040
#     klebsiella     0.9091    0.8243    0.8646       461
#         others     0.0279    0.1176    0.0451        51
#    pseudomonas     0.8589    0.9633    0.9081       354
# staphylococcus     0.9864    0.9295    0.9571       156
#
#       accuracy                         0.8009      2340
#      macro avg     0.7403    0.7070    0.7176      2340
#   weighted avg     0.8584    0.8009    0.8263      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9674    0.8018    0.8768       111
#   enterobacter     0.4024    0.2845    0.3333       116
#   enterococcus     0.9020    0.9020    0.9020        51
#    escherichia     0.9002    0.7808    0.8363      1040
#     klebsiella     0.9120    0.8091    0.8575       461
#         others     0.0305    0.1569    0.0511        51
#    pseudomonas     0.8586    0.9605    0.9067       354
# staphylococcus     0.9863    0.9231    0.9536       156
#
#       accuracy                         0.7885      2340
#      macro avg     0.7449    0.7023    0.7147      2340
#   weighted avg     0.8616    0.7885    0.8202      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9670    0.7928    0.8713       111
#   enterobacter     0.4697    0.2672    0.3407       116
#   enterococcus     0.9020    0.9020    0.9020        51
#    escherichia     0.9017    0.7500    0.8189      1040
#     klebsiella     0.9175    0.7961    0.8525       461
#         others     0.0300    0.1961    0.0521        51
#    pseudomonas     0.8737    0.9576    0.9137       354
# staphylococcus     0.9863    0.9231    0.9536       156
#
#       accuracy                         0.7714      2340
#      macro avg     0.7560    0.6981    0.7131      2340
#   weighted avg     0.8689    0.7714    0.8127      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9773    0.7748    0.8643       111
#   enterobacter     0.6087    0.2414    0.3457       116
#   enterococcus     0.9000    0.8824    0.8911        51
#    escherichia     0.8988    0.7087    0.7925      1040
#     klebsiella     0.9284    0.7874    0.8521       461
#         others     0.0310    0.2549    0.0552        51
#    pseudomonas     0.8842    0.9492    0.9155       354
# staphylococcus     0.9862    0.9167    0.9502       156
#
#       accuracy                         0.7483      2340
#      macro avg     0.7768    0.6894    0.7083      2340
#   weighted avg     0.8787    0.7483    0.8007      2340
#
# ===================
# Finished
# ===================
# *** saprot_mask_relaxed_r3, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14812, 1280)
# Test set shape: (2822, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4909    0.7431    0.5912       109
#   enterobacter     0.2021    0.2275    0.2141       167
#   enterococcus     0.5476    0.7667    0.6389        60
#    escherichia     0.7520    0.6905    0.7199      1344
#     klebsiella     0.6995    0.5331    0.6051       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.4709    0.7379    0.5749       351
# staphylococcus     0.9314    0.9477    0.9395       172
#
#       accuracy                         0.6425      2822
#      macro avg     0.5118    0.5808    0.5355      2822
#   weighted avg     0.6546    0.6425    0.6406      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5031    0.7431    0.6000       109
#   enterobacter     0.2044    0.2216    0.2126       167
#   enterococcus     0.5488    0.7500    0.6338        60
#    escherichia     0.7525    0.6830    0.7161      1344
#     klebsiella     0.7081    0.5295    0.6059       559
#         others     0.0213    0.0167    0.0187        60
#    pseudomonas     0.4777    0.7322    0.5782       351
# staphylococcus     0.9314    0.9477    0.9395       172
#
#       accuracy                         0.6371      2822
#      macro avg     0.5184    0.5780    0.5381      2822
#   weighted avg     0.6585    0.6371    0.6399      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5094    0.7431    0.6045       109
#   enterobacter     0.2057    0.2156    0.2105       167
#   enterococcus     0.5488    0.7500    0.6338        60
#    escherichia     0.7565    0.6749    0.7133      1344
#     klebsiella     0.7101    0.5259    0.6043       559
#         others     0.0116    0.0167    0.0137        60
#    pseudomonas     0.4793    0.7265    0.5776       351
# staphylococcus     0.9314    0.9477    0.9395       172
#
#       accuracy                         0.6315      2822
#      macro avg     0.5191    0.5750    0.5372      2822
#   weighted avg     0.6611    0.6315    0.6381      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5000    0.7156    0.5887       109
#   enterobacter     0.2108    0.2096    0.2102       167
#   enterococcus     0.5500    0.7333    0.6286        60
#    escherichia     0.7585    0.6637    0.7079      1344
#     klebsiella     0.7132    0.5206    0.6019       559
#         others     0.0226    0.0500    0.0311        60
#    pseudomonas     0.4820    0.7265    0.5795       351
# staphylococcus     0.9368    0.9477    0.9422       172
#
#       accuracy                         0.6240      2822
#      macro avg     0.5217    0.5709    0.5363      2822
#   weighted avg     0.6635    0.6240    0.6351      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5132    0.7156    0.5977       109
#   enterobacter     0.2160    0.2096    0.2128       167
#   enterococcus     0.5500    0.7333    0.6286        60
#    escherichia     0.7589    0.6533    0.7021      1344
#     klebsiella     0.7211    0.5134    0.5998       559
#         others     0.0166    0.0500    0.0249        60
#    pseudomonas     0.4923    0.7265    0.5869       351
# staphylococcus     0.9368    0.9477    0.9422       172
#
#       accuracy                         0.6176      2822
#      macro avg     0.5256    0.5687    0.5369      2822
#   weighted avg     0.6672    0.6176    0.6332      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5270    0.7156    0.6070       109
#   enterobacter     0.2267    0.2036    0.2145       167
#   enterococcus     0.5641    0.7333    0.6377        60
#    escherichia     0.7588    0.6391    0.6939      1344
#     klebsiella     0.7270    0.5098    0.5994       559
#         others     0.0127    0.0500    0.0203        60
#    pseudomonas     0.4971    0.7265    0.5903       351
# staphylococcus     0.9422    0.9477    0.9449       172
#
#       accuracy                         0.6099      2822
#      macro avg     0.5320    0.5657    0.5385      2822
#   weighted avg     0.6707    0.6099    0.6303      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5493    0.7156    0.6215       109
#   enterobacter     0.2270    0.1916    0.2078       167
#   enterococcus     0.5641    0.7333    0.6377        60
#    escherichia     0.7625    0.6257    0.6874      1344
#     klebsiella     0.7337    0.5027    0.5966       559
#         others     0.0168    0.0833    0.0279        60
#    pseudomonas     0.5050    0.7265    0.5958       351
# staphylococcus     0.9477    0.9477    0.9477       172
#
#       accuracy                         0.6021      2822
#      macro avg     0.5382    0.5658    0.5403      2822
#   weighted avg     0.6760    0.6021    0.6279      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5630    0.6972    0.6230       109
#   enterobacter     0.2296    0.1856    0.2053       167
#   enterococcus     0.5658    0.7167    0.6324        60
#    escherichia     0.7653    0.6064    0.6766      1344
#     klebsiella     0.7406    0.4955    0.5938       559
#         others     0.0238    0.1500    0.0411        60
#    pseudomonas     0.5143    0.7151    0.5983       351
# staphylococcus     0.9474    0.9419    0.9446       172
#
#       accuracy                         0.5897      2822
#      macro avg     0.5437    0.5636    0.5394      2822
#   weighted avg     0.6808    0.5897    0.6224      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5906    0.6881    0.6356       109
#   enterobacter     0.2562    0.1856    0.2153       167
#   enterococcus     0.5915    0.7000    0.6412        60
#    escherichia     0.7635    0.5766    0.6571      1344
#     klebsiella     0.7549    0.4794    0.5864       559
#         others     0.0221    0.1833    0.0394        60
#    pseudomonas     0.5332    0.7094    0.6088       351
# staphylococcus     0.9583    0.9360    0.9471       172
#
#       accuracy                         0.5712      2822
#      macro avg     0.5588    0.5573    0.5414      2822
#   weighted avg     0.6889    0.5712    0.6143      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6000    0.6606    0.6288       109
#   enterobacter     0.3611    0.1557    0.2176       167
#   enterococcus     0.6061    0.6667    0.6349        60
#    escherichia     0.7684    0.5283    0.6261      1344
#     klebsiella     0.7692    0.4651    0.5797       559
#         others     0.0183    0.2167    0.0338        60
#    pseudomonas     0.5711    0.6980    0.6282       351
# staphylococcus     0.9756    0.9302    0.9524       172
#
#       accuracy                         0.5408      2822
#      macro avg     0.5837    0.5402    0.5377      2822
#   weighted avg     0.7066    0.5408    0.6006      2822
#
# ===================
# Finished
# ===================
# *** saprot_mask_relaxed_r3, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13103, 1280)
# Test set shape: (3153, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4973    0.7521    0.5987       121
#   enterobacter     0.1456    0.2704    0.1893       196
#   enterococcus     0.4824    0.8367    0.6119        49
#    escherichia     0.7604    0.6690    0.7118      1589
#     klebsiella     0.5349    0.4949    0.5141       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.7136    0.7401    0.7266       404
# staphylococcus     0.8063    0.8217    0.8139       157
#
#       accuracy                         0.6239      3153
#      macro avg     0.4925    0.5731    0.5208      3153
#   weighted avg     0.6502    0.6239    0.6325      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5084    0.7521    0.6067       121
#   enterobacter     0.1429    0.2500    0.1818       196
#   enterococcus     0.4819    0.8163    0.6061        49
#    escherichia     0.7606    0.6576    0.7054      1589
#     klebsiella     0.5483    0.4830    0.5136       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.7226    0.7351    0.7288       404
# staphylococcus     0.8165    0.8217    0.8190       157
#
#       accuracy                         0.6137      3153
#      macro avg     0.4976    0.5645    0.5202      3153
#   weighted avg     0.6547    0.6137    0.6294      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5263    0.7438    0.6164       121
#   enterobacter     0.1407    0.2347    0.1759       196
#   enterococcus     0.4878    0.8163    0.6107        49
#    escherichia     0.7617    0.6375    0.6941      1589
#     klebsiella     0.5511    0.4677    0.5060       588
#         others     0.0219    0.0816    0.0345        49
#    pseudomonas     0.7284    0.7302    0.7293       404
# staphylococcus     0.8269    0.8217    0.8243       157
#
#       accuracy                         0.6001      3153
#      macro avg     0.5056    0.5667    0.5239      3153
#   weighted avg     0.6580    0.6001    0.6233      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5357    0.7438    0.6228       121
#   enterobacter     0.1456    0.2296    0.1782       196
#   enterococcus     0.4878    0.8163    0.6107        49
#    escherichia     0.7660    0.6262    0.6891      1589
#     klebsiella     0.5539    0.4541    0.4991       588
#         others     0.0188    0.1020    0.0317        49
#    pseudomonas     0.7340    0.7104    0.7220       404
# staphylococcus     0.8269    0.8217    0.8243       157
#
#       accuracy                         0.5893      3153
#      macro avg     0.5086    0.5630    0.5222      3153
#   weighted avg     0.6620    0.5893    0.6189      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5357    0.7438    0.6228       121
#   enterobacter     0.1473    0.2194    0.1762       196
#   enterococcus     0.4938    0.8163    0.6154        49
#    escherichia     0.7654    0.6098    0.6788      1589
#     klebsiella     0.5556    0.4422    0.4924       588
#         others     0.0149    0.1020    0.0260        49
#    pseudomonas     0.7383    0.7054    0.7215       404
# staphylococcus     0.8269    0.8217    0.8243       157
#
#       accuracy                         0.5775      3153
#      macro avg     0.5097    0.5576    0.5197      3153
#   weighted avg     0.6627    0.5775    0.6122      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5432    0.7273    0.6219       121
#   enterobacter     0.1569    0.2194    0.1830       196
#   enterococcus     0.4938    0.8163    0.6154        49
#    escherichia     0.7678    0.5890    0.6667      1589
#     klebsiella     0.5654    0.4337    0.4909       588
#         others     0.0161    0.1429    0.0289        49
#    pseudomonas     0.7527    0.7005    0.7256       404
# staphylococcus     0.8377    0.8217    0.8296       157
#
#       accuracy                         0.5649      3153
#      macro avg     0.5167    0.5563    0.5202      3153
#   weighted avg     0.6691    0.5649    0.6071      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5724    0.7190    0.6374       121
#   enterobacter     0.1506    0.1990    0.1714       196
#   enterococcus     0.5063    0.8163    0.6250        49
#    escherichia     0.7703    0.5721    0.6566      1589
#     klebsiella     0.5659    0.4235    0.4844       588
#         others     0.0153    0.1633    0.0280        49
#    pseudomonas     0.7609    0.6931    0.7254       404
# staphylococcus     0.8431    0.8217    0.8323       157
#
#       accuracy                         0.5522      3153
#      macro avg     0.5231    0.5510    0.5201      3153
#   weighted avg     0.6727    0.5522    0.6009      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5839    0.7190    0.6444       121
#   enterobacter     0.1525    0.1837    0.1667       196
#   enterococcus     0.5479    0.8163    0.6557        49
#    escherichia     0.7761    0.5519    0.6451      1589
#     klebsiella     0.5786    0.4133    0.4821       588
#         others     0.0189    0.2449    0.0351        49
#    pseudomonas     0.7703    0.6807    0.7227       404
# staphylococcus     0.8431    0.8217    0.8323       157
#
#       accuracy                         0.5389      3153
#      macro avg     0.5339    0.5539    0.5230      3153
#   weighted avg     0.6804    0.5389    0.5949      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5959    0.7190    0.6517       121
#   enterobacter     0.1667    0.1735    0.1700       196
#   enterococcus     0.5634    0.8163    0.6667        49
#    escherichia     0.7766    0.5230    0.6250      1589
#     klebsiella     0.5863    0.3929    0.4705       588
#         others     0.0181    0.2857    0.0341        49
#    pseudomonas     0.7820    0.6658    0.7193       404
# staphylococcus     0.8477    0.8153    0.8312       157
#
#       accuracy                         0.5182      3153
#      macro avg     0.5421    0.5489    0.5210      3153
#   weighted avg     0.6854    0.5182    0.5828      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6176    0.6942    0.6537       121
#   enterobacter     0.1951    0.1633    0.1778       196
#   enterococcus     0.5797    0.8163    0.6780        49
#    escherichia     0.7806    0.4814    0.5956      1589
#     klebsiella     0.6208    0.3759    0.4682       588
#         others     0.0154    0.3061    0.0294        49
#    pseudomonas     0.7920    0.6411    0.7086       404
# staphylococcus     0.8467    0.8089    0.8274       157
#
#       accuracy                         0.4894      3153
#      macro avg     0.5560    0.5359    0.5173      3153
#   weighted avg     0.6979    0.4894    0.5666      3153
#
# ===================
# Finished
# ===================
# *** saprot_mask_relaxed_r3, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11662, 1280)
# Test set shape: (3203, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4742    0.5169    0.4946        89
#   enterobacter     0.1767    0.2315    0.2004       216
#   enterococcus     0.6290    0.9512    0.7573        41
#    escherichia     0.7786    0.5540    0.6474      1796
#     klebsiella     0.3835    0.5806    0.4619       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.4549    0.7621    0.5697       311
# staphylococcus     0.8720    0.7857    0.8266       182
#
#       accuracy                         0.5670      3203
#      macro avg     0.4711    0.5477    0.4947      3203
#   weighted avg     0.6265    0.5670    0.5782      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4787    0.5056    0.4918        89
#   enterobacter     0.1845    0.2315    0.2053       216
#   enterococcus     0.6500    0.9512    0.7723        41
#    escherichia     0.7849    0.5423    0.6414      1796
#     klebsiella     0.3910    0.5750    0.4654       527
#         others     0.0103    0.0244    0.0145        41
#    pseudomonas     0.4721    0.7621    0.5830       311
# staphylococcus     0.8712    0.7802    0.8232       182
#
#       accuracy                         0.5592      3203
#      macro avg     0.4803    0.5465    0.4996      3203
#   weighted avg     0.6340    0.5592    0.5772      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5056    0.5056    0.5056        89
#   enterobacter     0.1843    0.2176    0.1996       216
#   enterococcus     0.6500    0.9512    0.7723        41
#    escherichia     0.7880    0.5317    0.6350      1796
#     klebsiella     0.4019    0.5712    0.4718       527
#         others     0.0311    0.1463    0.0513        41
#    pseudomonas     0.4855    0.7556    0.5912       311
# staphylococcus     0.8758    0.7747    0.8222       182
#
#       accuracy                         0.5523      3203
#      macro avg     0.4903    0.5568    0.5061      3203
#   weighted avg     0.6400    0.5523    0.5758      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5116    0.4944    0.5029        89
#   enterobacter     0.1934    0.2176    0.2048       216
#   enterococcus     0.6610    0.9512    0.7800        41
#    escherichia     0.7874    0.5134    0.6215      1796
#     klebsiella     0.4115    0.5693    0.4777       527
#         others     0.0278    0.1951    0.0486        41
#    pseudomonas     0.4957    0.7460    0.5956       311
# staphylococcus     0.8742    0.7637    0.8152       182
#
#       accuracy                         0.5404      3203
#      macro avg     0.4953    0.5563    0.5058      3203
#   weighted avg     0.6431    0.5404    0.5696      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5176    0.4944    0.5057        89
#   enterobacter     0.1974    0.2083    0.2027       216
#   enterococcus     0.6842    0.9512    0.7959        41
#    escherichia     0.7882    0.4994    0.6115      1796
#     klebsiella     0.4188    0.5579    0.4784       527
#         others     0.0212    0.1951    0.0382        41
#    pseudomonas     0.5033    0.7395    0.5990       311
# staphylococcus     0.8797    0.7637    0.8176       182
#
#       accuracy                         0.5295      3203
#      macro avg     0.5013    0.5512    0.5061      3203
#   weighted avg     0.6465    0.5295    0.5646      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5301    0.4944    0.5116        89
#   enterobacter     0.2074    0.2083    0.2079       216
#   enterococcus     0.6842    0.9512    0.7959        41
#    escherichia     0.7910    0.4805    0.5979      1796
#     klebsiella     0.4208    0.5446    0.4748       527
#         others     0.0213    0.2439    0.0391        41
#    pseudomonas     0.5067    0.7267    0.5971       311
# staphylococcus     0.8790    0.7582    0.8142       182
#
#       accuracy                         0.5158      3203
#      macro avg     0.5051    0.5510    0.5048      3203
#   weighted avg     0.6497    0.5158    0.5565      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5316    0.4719    0.5000        89
#   enterobacter     0.2174    0.2083    0.2128       216
#   enterococcus     0.6964    0.9512    0.8041        41
#    escherichia     0.7954    0.4610    0.5837      1796
#     klebsiella     0.4319    0.5351    0.4780       527
#         others     0.0190    0.2683    0.0355        41
#    pseudomonas     0.5173    0.7203    0.6022       311
# staphylococcus     0.8782    0.7527    0.8107       182
#
#       accuracy                         0.5020      3203
#      macro avg     0.5109    0.5461    0.5034      3203
#   weighted avg     0.6558    0.5020    0.5495      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5395    0.4607    0.4970        89
#   enterobacter     0.2240    0.1898    0.2055       216
#   enterococcus     0.7308    0.9268    0.8172        41
#    escherichia     0.7980    0.4354    0.5634      1796
#     klebsiella     0.4423    0.5161    0.4764       527
#         others     0.0194    0.3415    0.0367        41
#    pseudomonas     0.5274    0.7106    0.6055       311
# staphylococcus     0.8782    0.7527    0.8107       182
#
#       accuracy                         0.4827      3203
#      macro avg     0.5199    0.5417    0.5015      3203
#   weighted avg     0.6610    0.4827    0.5377      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5479    0.4494    0.4938        89
#   enterobacter     0.2037    0.1528    0.1746       216
#   enterococcus     0.7600    0.9268    0.8352        41
#    escherichia     0.7996    0.4065    0.5389      1796
#     klebsiella     0.4756    0.4991    0.4870       527
#         others     0.0167    0.3659    0.0319        41
#    pseudomonas     0.5480    0.6977    0.6139       311
# staphylococcus     0.8782    0.7527    0.8107       182
#
#       accuracy                         0.4599      3203
#      macro avg     0.5287    0.5314    0.4982      3203
#   weighted avg     0.6686    0.4599    0.5246      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5588    0.4270    0.4841        89
#   enterobacter     0.2197    0.1343    0.1667       216
#   enterococcus     0.7872    0.9024    0.8409        41
#    escherichia     0.8017    0.3580    0.4950      1796
#     klebsiella     0.5231    0.4725    0.4965       527
#         others     0.0181    0.5122    0.0349        41
#    pseudomonas     0.5734    0.6656    0.6161       311
# staphylococcus     0.8774    0.7473    0.8071       182
#
#       accuracy                         0.4246      3203
#      macro avg     0.5449    0.5274    0.4927      3203
#   weighted avg     0.6818    0.4246    0.5008      3203
#
# ===================
# Finished
# ===================
