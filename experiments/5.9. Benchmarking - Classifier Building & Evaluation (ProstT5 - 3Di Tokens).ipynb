# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_prostt5_3di_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. If you have run `3.6. Data Consolidation (ProstT5 - 3Di Tokens).ipynb`, then `data/inphared/consolidated` should have already been populated with the prerequisite files.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_prostt5_3di_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.9. Benchmarking - Classifier Building & Evaluation (ProstT5 - 3Di Tokens).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a multilayer perceptron, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = list(constants.PROSTT5_3Di_PLM.keys())

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_prostt5_3di_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-mlp-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            feature_columns=[f"s{i}" for i in range(1, 1025)],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="MLP-prot",
            batch_size=256,
            learning_rate=1e-3,
            dropout=0.2,
        )
# Out:
# *** prostt5_3di_relaxed_r3, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16942, 1024)
# Test set shape: (2340, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8941    0.6847    0.7755       111
#   enterobacter     0.2312    0.3966    0.2921       116
#   enterococcus     0.8491    0.8824    0.8654        51
#    escherichia     0.8167    0.8356    0.8260      1040
#     klebsiella     0.8329    0.7679    0.7991       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8683    0.8757    0.8720       354
# staphylococcus     0.9108    0.9167    0.9137       156
#
#       accuracy                         0.7876      2340
#      macro avg     0.6754    0.6699    0.6680      2340
#   weighted avg     0.7916    0.7876    0.7875      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8941    0.6847    0.7755       111
#   enterobacter     0.2316    0.3793    0.2876       116
#   enterococcus     0.8491    0.8824    0.8654        51
#    escherichia     0.8287    0.8231    0.8259      1040
#     klebsiella     0.8374    0.7484    0.7904       461
#         others     0.0172    0.0196    0.0183        51
#    pseudomonas     0.8750    0.8701    0.8725       354
# staphylococcus     0.9108    0.9167    0.9137       156
#
#       accuracy                         0.7769      2340
#      macro avg     0.6805    0.6655    0.6687      2340
#   weighted avg     0.7991    0.7769    0.7860      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9036    0.6757    0.7732       111
#   enterobacter     0.2444    0.3793    0.2973       116
#   enterococcus     0.8491    0.8824    0.8654        51
#    escherichia     0.8340    0.8019    0.8176      1040
#     klebsiella     0.8471    0.7332    0.7860       461
#         others     0.0246    0.0588    0.0347        51
#    pseudomonas     0.8851    0.8701    0.8775       354
# staphylococcus     0.9161    0.9103    0.9132       156
#
#       accuracy                         0.7645      2340
#      macro avg     0.6880    0.6639    0.6706      2340
#   weighted avg     0.8065    0.7645    0.7829      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9146    0.6757    0.7772       111
#   enterobacter     0.2544    0.3707    0.3018       116
#   enterococcus     0.8491    0.8824    0.8654        51
#    escherichia     0.8395    0.7846    0.8111      1040
#     klebsiella     0.8616    0.7158    0.7820       461
#         others     0.0273    0.0980    0.0427        51
#    pseudomonas     0.8953    0.8701    0.8825       354
# staphylococcus     0.9221    0.9103    0.9161       156
#
#       accuracy                         0.7538      2340
#      macro avg     0.6955    0.6634    0.6724      2340
#   weighted avg     0.8149    0.7538    0.7808      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9136    0.6667    0.7708       111
#   enterobacter     0.2800    0.3621    0.3158       116
#   enterococcus     0.8431    0.8431    0.8431        51
#    escherichia     0.8442    0.7712    0.8060      1040
#     klebsiella     0.8689    0.6898    0.7690       461
#         others     0.0241    0.1176    0.0400        51
#    pseudomonas     0.8968    0.8588    0.8773       354
# staphylococcus     0.9221    0.9103    0.9161       156
#
#       accuracy                         0.7397      2340
#      macro avg     0.6991    0.6524    0.6673      2340
#   weighted avg     0.8196    0.7397    0.7750      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9359    0.6577    0.7725       111
#   enterobacter     0.3037    0.3534    0.3267       116
#   enterococcus     0.8431    0.8431    0.8431        51
#    escherichia     0.8510    0.7471    0.7957      1040
#     klebsiella     0.8669    0.6638    0.7518       461
#         others     0.0186    0.1176    0.0322        51
#    pseudomonas     0.9015    0.8531    0.8766       354
# staphylococcus     0.9281    0.9103    0.9191       156
#
#       accuracy                         0.7222      2340
#      macro avg     0.7061    0.6433    0.6647      2340
#   weighted avg     0.8255    0.7222    0.7676      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9351    0.6486    0.7660       111
#   enterobacter     0.3276    0.3276    0.3276       116
#   enterococcus     0.8431    0.8431    0.8431        51
#    escherichia     0.8639    0.7327    0.7929      1040
#     klebsiella     0.8817    0.6464    0.7459       461
#         others     0.0178    0.1373    0.0315        51
#    pseudomonas     0.9063    0.8475    0.8759       354
# staphylococcus     0.9276    0.9038    0.9156       156
#
#       accuracy                         0.7098      2340
#      macro avg     0.7129    0.6359    0.6623      2340
#   weighted avg     0.8360    0.7098    0.7646      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9351    0.6486    0.7660       111
#   enterobacter     0.3529    0.3103    0.3303       116
#   enterococcus     0.8542    0.8039    0.8283        51
#    escherichia     0.8689    0.7135    0.7835      1040
#     klebsiella     0.8861    0.6074    0.7207       461
#         others     0.0214    0.1961    0.0385        51
#    pseudomonas     0.9080    0.8362    0.8706       354
# staphylococcus     0.9463    0.9038    0.9246       156
#
#       accuracy                         0.6915      2340
#      macro avg     0.7216    0.6275    0.6578      2340
#   weighted avg     0.8421    0.6915    0.7552      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9351    0.6486    0.7660       111
#   enterobacter     0.3827    0.2672    0.3147       116
#   enterococcus     0.8542    0.8039    0.8283        51
#    escherichia     0.8838    0.6798    0.7685      1040
#     klebsiella     0.9014    0.5748    0.7020       461
#         others     0.0241    0.2745    0.0444        51
#    pseudomonas     0.9238    0.8220    0.8700       354
# staphylococcus     0.9448    0.8782    0.9103       156
#
#       accuracy                         0.6658      2340
#      macro avg     0.7312    0.6187    0.6505      2340
#   weighted avg     0.8556    0.6658    0.7431      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9412    0.5766    0.7151       111
#   enterobacter     0.4464    0.2155    0.2907       116
#   enterococcus     0.8889    0.7843    0.8333        51
#    escherichia     0.8926    0.6231    0.7339      1040
#     klebsiella     0.9176    0.5076    0.6536       461
#         others     0.0243    0.3529    0.0455        51
#    pseudomonas     0.9311    0.8023    0.8619       354
# staphylococcus     0.9514    0.8782    0.9133       156
#
#       accuracy                         0.6197      2340
#      macro avg     0.7492    0.5926    0.6309      2340
#   weighted avg     0.8684    0.6197    0.7137      2340
#
# ===================
# Finished
# ===================
# *** prostt5_3di_relaxed_r3, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14812, 1024)
# Test set shape: (2822, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4000    0.6606    0.4983       109
#   enterobacter     0.1923    0.1198    0.1476       167
#   enterococcus     0.6667    0.6333    0.6496        60
#    escherichia     0.7138    0.6793    0.6961      1344
#     klebsiella     0.6012    0.5474    0.5730       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.4852    0.6524    0.5565       351
# staphylococcus     0.6471    0.8314    0.7277       172
#
#       accuracy                         0.6099      2822
#      macro avg     0.4633    0.5155    0.4811      2822
#   weighted avg     0.5998    0.6099    0.6004      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4045    0.6606    0.5017       109
#   enterobacter     0.2062    0.1198    0.1515       167
#   enterococcus     0.6727    0.6167    0.6435        60
#    escherichia     0.7231    0.6704    0.6958      1344
#     klebsiella     0.6144    0.5331    0.5709       559
#         others     0.0619    0.1000    0.0764        60
#    pseudomonas     0.4978    0.6382    0.5593       351
# staphylococcus     0.6636    0.8256    0.7358       172
#
#       accuracy                         0.6024      2822
#      macro avg     0.4805    0.5205    0.4919      2822
#   weighted avg     0.6119    0.6024    0.6025      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4128    0.6514    0.5053       109
#   enterobacter     0.2174    0.1198    0.1544       167
#   enterococcus     0.6852    0.6167    0.6491        60
#    escherichia     0.7311    0.6637    0.6958      1344
#     klebsiella     0.6131    0.5188    0.5620       559
#         others     0.0476    0.1333    0.0702        60
#    pseudomonas     0.5069    0.6268    0.5605       351
# staphylococcus     0.6794    0.8256    0.7454       172
#
#       accuracy                         0.5953      2822
#      macro avg     0.4867    0.5195    0.4928      2822
#   weighted avg     0.6185    0.5953    0.6018      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4201    0.6514    0.5108       109
#   enterobacter     0.2469    0.1198    0.1613       167
#   enterococcus     0.6923    0.6000    0.6429        60
#    escherichia     0.7341    0.6510    0.6901      1344
#     klebsiella     0.6286    0.5116    0.5641       559
#         others     0.0367    0.1500    0.0590        60
#    pseudomonas     0.5154    0.6182    0.5622       351
# staphylococcus     0.6860    0.8256    0.7493       172
#
#       accuracy                         0.5868      2822
#      macro avg     0.4950    0.5160    0.4925      2822
#   weighted avg     0.6264    0.5868    0.6002      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4303    0.6514    0.5182       109
#   enterobacter     0.2500    0.1138    0.1564       167
#   enterococcus     0.7059    0.6000    0.6486        60
#    escherichia     0.7426    0.6376    0.6861      1344
#     klebsiella     0.6295    0.5045    0.5601       559
#         others     0.0279    0.1500    0.0470        60
#    pseudomonas     0.5312    0.6068    0.5665       351
# staphylococcus     0.6912    0.8198    0.7500       172
#
#       accuracy                         0.5769      2822
#      macro avg     0.5011    0.5105    0.4916      2822
#   weighted avg     0.6336    0.5769    0.5980      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4437    0.6514    0.5279       109
#   enterobacter     0.2698    0.1018    0.1478       167
#   enterococcus     0.7059    0.6000    0.6486        60
#    escherichia     0.7473    0.6205    0.6780      1344
#     klebsiella     0.6334    0.4884    0.5515       559
#         others     0.0263    0.1833    0.0459        60
#    pseudomonas     0.5405    0.5897    0.5640       351
# staphylococcus     0.7035    0.8140    0.7547       172
#
#       accuracy                         0.5631      2822
#      macro avg     0.5088    0.5061    0.4898      2822
#   weighted avg     0.6402    0.5631    0.5922      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4459    0.6422    0.5263       109
#   enterobacter     0.2982    0.1018    0.1518       167
#   enterococcus     0.7083    0.5667    0.6296        60
#    escherichia     0.7565    0.6101    0.6755      1344
#     klebsiella     0.6529    0.4812    0.5541       559
#         others     0.0280    0.2333    0.0500        60
#    pseudomonas     0.5538    0.5869    0.5698       351
# staphylococcus     0.7240    0.8081    0.7637       172
#
#       accuracy                         0.5560      2822
#      macro avg     0.5209    0.5038    0.4901      2822
#   weighted avg     0.6531    0.5560    0.5926      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4459    0.6055    0.5136       109
#   enterobacter     0.3137    0.0958    0.1468       167
#   enterococcus     0.7234    0.5667    0.6355        60
#    escherichia     0.7656    0.5952    0.6697      1344
#     klebsiella     0.6624    0.4669    0.5477       559
#         others     0.0282    0.2833    0.0513        60
#    pseudomonas     0.5788    0.5755    0.5771       351
# staphylococcus     0.7405    0.7965    0.7675       172
#
#       accuracy                         0.5432      2822
#      macro avg     0.5323    0.4982    0.4887      2822
#   weighted avg     0.6647    0.5432    0.5892      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4583    0.6055    0.5217       109
#   enterobacter     0.3333    0.0898    0.1415       167
#   enterococcus     0.7391    0.5667    0.6415        60
#    escherichia     0.7833    0.5781    0.6652      1344
#     klebsiella     0.6765    0.4526    0.5423       559
#         others     0.0277    0.3333    0.0511        60
#    pseudomonas     0.5981    0.5470    0.5714       351
# staphylococcus     0.7684    0.7907    0.7794       172
#
#       accuracy                         0.5291      2822
#      macro avg     0.5481    0.4955    0.4893      2822
#   weighted avg     0.6820    0.5291    0.5861      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4672    0.5872    0.5203       109
#   enterobacter     0.3143    0.0659    0.1089       167
#   enterococcus     0.7805    0.5333    0.6337        60
#    escherichia     0.7991    0.5446    0.6478      1344
#     klebsiella     0.6959    0.4258    0.5283       559
#         others     0.0256    0.3833    0.0480        60
#    pseudomonas     0.6096    0.5071    0.5537       351
# staphylococcus     0.8323    0.7791    0.8048       172
#
#       accuracy                         0.5004      2822
#      macro avg     0.5656    0.4783    0.4807      2822
#   weighted avg     0.6988    0.5004    0.5721      2822
#
# ===================
# Finished
# ===================
# *** prostt5_3di_relaxed_r3, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13099, 1024)
# Test set shape: (3153, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4955    0.4545    0.4741       121
#   enterobacter     0.1393    0.1735    0.1545       196
#   enterococcus     0.5238    0.4490    0.4835        49
#    escherichia     0.6613    0.6476    0.6544      1589
#     klebsiella     0.4014    0.3946    0.3979       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.5639    0.6337    0.5967       404
# staphylococcus     0.6964    0.7452    0.7200       157
#
#       accuracy                         0.5534      3153
#      macro avg     0.4352    0.4373    0.4352      3153
#   weighted avg     0.5509    0.5534    0.5516      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5048    0.4380    0.4690       121
#   enterobacter     0.1410    0.1633    0.1513       196
#   enterococcus     0.5526    0.4286    0.4828        49
#    escherichia     0.6673    0.6337    0.6501      1589
#     klebsiella     0.3982    0.3793    0.3885       588
#         others     0.0179    0.0408    0.0248        49
#    pseudomonas     0.5773    0.6287    0.6019       404
# staphylococcus     0.7037    0.7261    0.7147       157
#
#       accuracy                         0.5411      3153
#      macro avg     0.4453    0.4298    0.4354      3153
#   weighted avg     0.5566    0.5411    0.5481      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5152    0.4215    0.4636       121
#   enterobacter     0.1553    0.1633    0.1592       196
#   enterococcus     0.5833    0.4286    0.4941        49
#    escherichia     0.6723    0.6249    0.6477      1589
#     klebsiella     0.3978    0.3673    0.3820       588
#         others     0.0195    0.0816    0.0315        49
#    pseudomonas     0.5845    0.6163    0.6000       404
# staphylococcus     0.7019    0.7197    0.7107       157
#
#       accuracy                         0.5325      3153
#      macro avg     0.4537    0.4279    0.4361      3153
#   weighted avg     0.5616    0.5325    0.5458      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5281    0.3884    0.4476       121
#   enterobacter     0.1676    0.1531    0.1600       196
#   enterococcus     0.6176    0.4286    0.5060        49
#    escherichia     0.6755    0.6117    0.6420      1589
#     klebsiella     0.3981    0.3588    0.3775       588
#         others     0.0193    0.1224    0.0333        49
#    pseudomonas     0.5923    0.6114    0.6017       404
# staphylococcus     0.7143    0.7006    0.7074       157
#
#       accuracy                         0.5214      3153
#      macro avg     0.4641    0.4219    0.4344      3153
#   weighted avg     0.5667    0.5214    0.5418      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5227    0.3802    0.4402       121
#   enterobacter     0.1796    0.1531    0.1653       196
#   enterococcus     0.7000    0.4286    0.5316        49
#    escherichia     0.6839    0.6004    0.6394      1589
#     klebsiella     0.4008    0.3503    0.3739       588
#         others     0.0197    0.1633    0.0352        49
#    pseudomonas     0.6049    0.6064    0.6057       404
# staphylococcus     0.7162    0.6752    0.6951       157
#
#       accuracy                         0.5125      3153
#      macro avg     0.4785    0.4197    0.4358      3153
#   weighted avg     0.5750    0.5125    0.5402      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5500    0.3636    0.4378       121
#   enterobacter     0.2041    0.1531    0.1749       196
#   enterococcus     0.7241    0.4286    0.5385        49
#    escherichia     0.6896    0.5815    0.6309      1589
#     klebsiella     0.3933    0.3197    0.3527       588
#         others     0.0182    0.2041    0.0334        49
#    pseudomonas     0.6202    0.5941    0.6068       404
# staphylococcus     0.7203    0.6561    0.6867       157
#
#       accuracy                         0.4948      3153
#      macro avg     0.4900    0.4126    0.4327      3153
#   weighted avg     0.5815    0.4948    0.5323      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5811    0.3554    0.4410       121
#   enterobacter     0.1860    0.1224    0.1477       196
#   enterococcus     0.7241    0.4286    0.5385        49
#    escherichia     0.6945    0.5651    0.6232      1589
#     klebsiella     0.3957    0.3095    0.3473       588
#         others     0.0199    0.2653    0.0370        49
#    pseudomonas     0.6347    0.5891    0.6110       404
# staphylococcus     0.7266    0.6433    0.6824       157
#
#       accuracy                         0.4821      3153
#      macro avg     0.4953    0.4098    0.4285      3153
#   weighted avg     0.5867    0.4821    0.5262      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6000    0.3471    0.4398       121
#   enterobacter     0.1810    0.0969    0.1262       196
#   enterococcus     0.7500    0.4286    0.5455        49
#    escherichia     0.7060    0.5456    0.6155      1589
#     klebsiella     0.4151    0.2993    0.3478       588
#         others     0.0225    0.3673    0.0424        49
#    pseudomonas     0.6454    0.5767    0.6092       404
# staphylococcus     0.7353    0.6369    0.6826       157
#
#       accuracy                         0.4681      3153
#      macro avg     0.5069    0.4123    0.4261      3153
#   weighted avg     0.5988    0.4681    0.5210      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6379    0.3058    0.4134       121
#   enterobacter     0.2024    0.0867    0.1214       196
#   enterococcus     0.7917    0.3878    0.5205        49
#    escherichia     0.7256    0.5192    0.6053      1589
#     klebsiella     0.4200    0.2857    0.3401       588
#         others     0.0194    0.3878    0.0370        49
#    pseudomonas     0.6549    0.5495    0.5976       404
# staphylococcus     0.7500    0.6306    0.6851       157
#
#       accuracy                         0.4459      3153
#      macro avg     0.5252    0.3941    0.4151      3153
#   weighted avg     0.6149    0.4459    0.5112      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6735    0.2727    0.3882       121
#   enterobacter     0.1875    0.0459    0.0738       196
#   enterococcus     0.8421    0.3265    0.4706        49
#    escherichia     0.7490    0.4827    0.5871      1589
#     klebsiella     0.4342    0.2636    0.3280       588
#         others     0.0177    0.4490    0.0341        49
#    pseudomonas     0.6881    0.5025    0.5808       404
# staphylococcus     0.7769    0.5987    0.6763       157
#
#       accuracy                         0.4120      3153
#      macro avg     0.5461    0.3677    0.3924      3153
#   weighted avg     0.6362    0.4120    0.4925      3153
#
# ===================
# Finished
# ===================
# *** prostt5_3di_relaxed_r3, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11654, 1024)
# Test set shape: (3203, 1024)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1589    0.5393    0.2455        89
#   enterobacter     0.1395    0.1667    0.1519       216
#   enterococcus     0.1735    0.4146    0.2446        41
#    escherichia     0.6995    0.4978    0.5817      1796
#     klebsiella     0.3528    0.4231    0.3848       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.3780    0.6174    0.4689       311
# staphylococcus     0.6693    0.4670    0.5502       182
#
#       accuracy                         0.4667      3203
#      macro avg     0.3214    0.3907    0.3284      3203
#   weighted avg     0.5411    0.4667    0.4864      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1604    0.5281    0.2461        89
#   enterobacter     0.1378    0.1620    0.1489       216
#   enterococcus     0.1613    0.3659    0.2239        41
#    escherichia     0.6985    0.4889    0.5752      1796
#     klebsiella     0.3549    0.4156    0.3829       527
#         others     0.0417    0.0732    0.0531        41
#    pseudomonas     0.3826    0.6077    0.4696       311
# staphylococcus     0.6911    0.4670    0.5574       182
#
#       accuracy                         0.4593      3203
#      macro avg     0.3285    0.3885    0.3321      3203
#   weighted avg     0.5428    0.4593    0.4832      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1655    0.5281    0.2520        89
#   enterobacter     0.1406    0.1620    0.1505       216
#   enterococcus     0.1648    0.3659    0.2273        41
#    escherichia     0.7021    0.4816    0.5713      1796
#     klebsiella     0.3621    0.4137    0.3862       527
#         others     0.0201    0.0732    0.0316        41
#    pseudomonas     0.3874    0.5916    0.4682       311
# staphylococcus     0.6942    0.4615    0.5545       182
#
#       accuracy                         0.4530      3203
#      macro avg     0.3296    0.3847    0.3302      3203
#   weighted avg     0.5468    0.4530    0.4813      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1697    0.5169    0.2556        89
#   enterobacter     0.1434    0.1620    0.1522       216
#   enterococcus     0.1395    0.2927    0.1890        41
#    escherichia     0.7062    0.4710    0.5651      1796
#     klebsiella     0.3638    0.4004    0.3812       527
#         others     0.0202    0.1220    0.0346        41
#    pseudomonas     0.3947    0.5788    0.4694       311
# staphylococcus     0.7000    0.4615    0.5563       182
#
#       accuracy                         0.4430      3203
#      macro avg     0.3297    0.3757    0.3254      3203
#   weighted avg     0.5504    0.4430    0.4770      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1751    0.5056    0.2601        89
#   enterobacter     0.1458    0.1620    0.1535       216
#   enterococcus     0.1481    0.2927    0.1967        41
#    escherichia     0.7078    0.4627    0.5596      1796
#     klebsiella     0.3657    0.3928    0.3788       527
#         others     0.0249    0.1951    0.0442        41
#    pseudomonas     0.3955    0.5659    0.4656       311
# staphylococcus     0.7059    0.4615    0.5581       182
#
#       accuracy                         0.4365      3203
#      macro avg     0.3336    0.3798    0.3271      3203
#   weighted avg     0.5525    0.4365    0.4737      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1728    0.4719    0.2530        89
#   enterobacter     0.1496    0.1620    0.1556       216
#   enterococcus     0.1392    0.2683    0.1833        41
#    escherichia     0.7092    0.4521    0.5522      1796
#     klebsiella     0.3659    0.3833    0.3744       527
#         others     0.0221    0.2195    0.0402        41
#    pseudomonas     0.4037    0.5595    0.4690       311
# staphylococcus     0.7411    0.4560    0.5646       182
#
#       accuracy                         0.4271      3203
#      macro avg     0.3380    0.3716    0.3240      3203
#   weighted avg     0.5561    0.4271    0.4692      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1850    0.4719    0.2658        89
#   enterobacter     0.1515    0.1620    0.1566       216
#   enterococcus     0.1447    0.2683    0.1880        41
#    escherichia     0.7089    0.4393    0.5425      1796
#     klebsiella     0.3633    0.3681    0.3657       527
#         others     0.0202    0.2439    0.0372        41
#    pseudomonas     0.4053    0.5434    0.4643       311
# staphylococcus     0.7523    0.4505    0.5636       182
#
#       accuracy                         0.4159      3203
#      macro avg     0.3414    0.3684    0.3230      3203
#   weighted avg     0.5568    0.4159    0.4623      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1934    0.4607    0.2724        89
#   enterobacter     0.1396    0.1435    0.1416       216
#   enterococcus     0.1571    0.2683    0.1982        41
#    escherichia     0.7154    0.4226    0.5313      1796
#     klebsiella     0.3645    0.3548    0.3596       527
#         others     0.0191    0.2927    0.0359        41
#    pseudomonas     0.4133    0.5209    0.4609       311
# staphylococcus     0.7810    0.4505    0.5714       182
#
#       accuracy                         0.4012      3203
#      macro avg     0.3479    0.3643    0.3214      3203
#   weighted avg     0.5626    0.4012    0.4544      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2181    0.4607    0.2960        89
#   enterobacter     0.1422    0.1435    0.1429       216
#   enterococcus     0.1250    0.1951    0.1524        41
#    escherichia     0.7216    0.4070    0.5205      1796
#     klebsiella     0.3621    0.3340    0.3475       527
#         others     0.0182    0.3415    0.0346        41
#    pseudomonas     0.4169    0.4920    0.4513       311
# staphylococcus     0.8367    0.4505    0.5857       182
#
#       accuracy                         0.3859      3203
#      macro avg     0.3551    0.3530    0.3164      3203
#   weighted avg     0.5697    0.3859    0.4464      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2643    0.4157    0.3231        89
#   enterobacter     0.1324    0.1250    0.1286       216
#   enterococcus     0.1250    0.1707    0.1443        41
#    escherichia     0.7264    0.3769    0.4963      1796
#     klebsiella     0.3626    0.3055    0.3316       527
#         others     0.0147    0.3659    0.0284        41
#    pseudomonas     0.4494    0.4566    0.4530       311
# staphylococcus     0.8617    0.4451    0.5870       182
#
#       accuracy                         0.3581      3203
#      macro avg     0.3671    0.3327    0.3115      3203
#   weighted avg     0.5776    0.3581    0.4301      3203
#
# ===================
# Finished
# ===================
