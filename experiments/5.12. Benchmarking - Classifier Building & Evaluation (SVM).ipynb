# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. If you have run `3.0. Data Consolidation (SaProt).ipynb`, then `data/inphared/consolidated` should have already been populated with the prerequisite files.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.12. Classifier Building & Evaluation (SVM).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a support vector machine, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = list(constants.SAPROT_PLM.keys())

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_saprot_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-svm-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            feature_columns=[f"s{i}" for i in range(1, 1281)],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="svm",
        )
# Out:
# *** saprot_relaxed_r3, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16942, 1280)
# Test set shape: (2340, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8000    0.8288    0.8142       111
#   enterobacter     0.2020    0.5259    0.2919       116
#   enterococcus     0.8333    0.8824    0.8571        51
#    escherichia     0.8876    0.6683    0.7625      1040
#     klebsiella     0.7390    0.8416    0.7870       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8084    0.9294    0.8647       354
# staphylococcus     0.9610    0.9487    0.9548       156
#
#       accuracy                         0.7513      2340
#      macro avg     0.6539    0.7031    0.6665      2340
#   weighted avg     0.7926    0.7513    0.7602      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8558    0.8018    0.8279       111
#   enterobacter     0.2328    0.4655    0.3103       116
#   enterococcus     0.8333    0.8824    0.8571        51
#    escherichia     0.8903    0.6558    0.7553      1040
#     klebsiella     0.7757    0.8178    0.7962       461
#         others     0.0340    0.0980    0.0505        51
#    pseudomonas     0.8262    0.9266    0.8735       354
# staphylococcus     0.9610    0.9487    0.9548       156
#
#       accuracy                         0.7385      2340
#      macro avg     0.6761    0.6996    0.6782      2340
#   weighted avg     0.8086    0.7385    0.7628      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8713    0.7928    0.8302       111
#   enterobacter     0.2611    0.4569    0.3323       116
#   enterococcus     0.8333    0.8824    0.8571        51
#    escherichia     0.9019    0.6279    0.7404      1040
#     klebsiella     0.8196    0.7983    0.8088       461
#         others     0.0335    0.1765    0.0563        51
#    pseudomonas     0.8394    0.9153    0.8757       354
# staphylococcus     0.9610    0.9487    0.9548       156
#
#       accuracy                         0.7214      2340
#      macro avg     0.6901    0.6998    0.6819      2340
#   weighted avg     0.8265    0.7214    0.7603      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8889    0.7928    0.8381       111
#   enterobacter     0.2917    0.4224    0.3451       116
#   enterococcus     0.8333    0.8824    0.8571        51
#    escherichia     0.9074    0.6029    0.7244      1040
#     klebsiella     0.8432    0.7701    0.8050       461
#         others     0.0395    0.2941    0.0696        51
#    pseudomonas     0.8579    0.9040    0.8803       354
# staphylococcus     0.9610    0.9487    0.9548       156
#
#       accuracy                         0.7038      2340
#      macro avg     0.7029    0.7022    0.6843      2340
#   weighted avg     0.8389    0.7038    0.7545      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9140    0.7658    0.8333       111
#   enterobacter     0.3286    0.3966    0.3594       116
#   enterococcus     0.8654    0.8824    0.8738        51
#    escherichia     0.9172    0.5856    0.7148      1040
#     klebsiella     0.8586    0.7505    0.8009       461
#         others     0.0380    0.3529    0.0686        51
#    pseudomonas     0.8722    0.8870    0.8796       354
# staphylococcus     0.9610    0.9487    0.9548       156
#
#       accuracy                         0.6885      2340
#      macro avg     0.7194    0.6962    0.6856      2340
#   weighted avg     0.8521    0.6885    0.7501      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9239    0.7658    0.8374       111
#   enterobacter     0.3559    0.3621    0.3590       116
#   enterococcus     0.8800    0.8627    0.8713        51
#    escherichia     0.9227    0.5394    0.6808      1040
#     klebsiella     0.8720    0.7093    0.7823       461
#         others     0.0390    0.4510    0.0718        51
#    pseudomonas     0.8839    0.8814    0.8826       354
# staphylococcus     0.9610    0.9487    0.9548       156
#
#       accuracy                         0.6590      2340
#      macro avg     0.7298    0.6900    0.6800      2340
#   weighted avg     0.8612    0.6590    0.7320      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9535    0.7387    0.8325       111
#   enterobacter     0.4043    0.3276    0.3619       116
#   enterococcus     0.8980    0.8627    0.8800        51
#    escherichia     0.9349    0.4971    0.6491      1040
#     klebsiella     0.8870    0.6638    0.7593       461
#         others     0.0388    0.5490    0.0725        51
#    pseudomonas     0.9029    0.8672    0.8847       354
# staphylococcus     0.9737    0.9487    0.9610       156
#
#       accuracy                         0.6282      2340
#      macro avg     0.7491    0.6819    0.6751      2340
#   weighted avg     0.8774    0.6282    0.7142      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9639    0.7207    0.8247       111
#   enterobacter     0.4493    0.2672    0.3351       116
#   enterococcus     0.8980    0.8627    0.8800        51
#    escherichia     0.9370    0.4433    0.6018      1040
#     klebsiella     0.9135    0.5727    0.7040       461
#         others     0.0362    0.6275    0.0685        51
#    pseudomonas     0.9136    0.8362    0.8732       354
# staphylococcus     0.9735    0.9423    0.9577       156
#
#       accuracy                         0.5791      2340
#      macro avg     0.7606    0.6591    0.6556      2340
#   weighted avg     0.8879    0.5791    0.6785      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9737    0.6667    0.7914       111
#   enterobacter     0.4583    0.1897    0.2683       116
#   enterococcus     0.9149    0.8431    0.8776        51
#    escherichia     0.9422    0.3606    0.5216      1040
#     klebsiella     0.9315    0.4425    0.6000       461
#         others     0.0338    0.7255    0.0646        51
#    pseudomonas     0.9186    0.7966    0.8533       354
# staphylococcus     0.9800    0.9423    0.9608       156
#
#       accuracy                         0.5060      2340
#      macro avg     0.7691    0.6209    0.6172      2340
#   weighted avg     0.8962    0.5060    0.6145      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9844    0.5676    0.7200       111
#   enterobacter     0.5294    0.0776    0.1353       116
#   enterococcus     0.9333    0.8235    0.8750        51
#    escherichia     0.9524    0.1731    0.2929      1040
#     klebsiella     0.9029    0.2017    0.3298       461
#         others     0.0251    0.7451    0.0485        51
#    pseudomonas     0.9151    0.6695    0.7732       354
# staphylococcus     0.9797    0.9295    0.9539       156
#
#       accuracy                         0.3449      2340
#      macro avg     0.7778    0.5234    0.5161      2340
#   weighted avg     0.8987    0.3449    0.4367      2340
#
# ===================
# Finished
# ===================
# *** saprot_relaxed_r3, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14822, 1280)
# Test set shape: (2822, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4536    0.7615    0.5685       109
#   enterobacter     0.1724    0.3593    0.2330       167
#   enterococcus     0.7538    0.8167    0.7840        60
#    escherichia     0.7709    0.5283    0.6269      1344
#     klebsiella     0.5568    0.6315    0.5918       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.5504    0.7778    0.6446       351
# staphylococcus     0.9143    0.9302    0.9222       172
#
#       accuracy                         0.5982      2822
#      macro avg     0.5215    0.6006    0.5464      2822
#   weighted avg     0.6454    0.5982    0.6046      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4759    0.7248    0.5745       109
#   enterobacter     0.1847    0.3473    0.2412       167
#   enterococcus     0.8276    0.8000    0.8136        60
#    escherichia     0.7729    0.5089    0.6137      1344
#     klebsiella     0.6096    0.6118    0.6107       559
#         others     0.0152    0.0500    0.0233        60
#    pseudomonas     0.5665    0.7521    0.6463       351
# staphylococcus     0.9143    0.9302    0.9222       172
#
#       accuracy                         0.5804      2822
#      macro avg     0.5458    0.5906    0.5557      2822
#   weighted avg     0.6623    0.5804    0.6041      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5338    0.7248    0.6148       109
#   enterobacter     0.1932    0.3054    0.2367       167
#   enterococcus     0.8679    0.7667    0.8142        60
#    escherichia     0.7836    0.4903    0.6032      1344
#     klebsiella     0.6613    0.5832    0.6198       559
#         others     0.0197    0.1333    0.0343        60
#    pseudomonas     0.5833    0.7379    0.6516       351
# staphylococcus     0.9128    0.9128    0.9128       172
#
#       accuracy                         0.5617      2822
#      macro avg     0.5694    0.5818    0.5609      2822
#   weighted avg     0.6833    0.5617    0.6025      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5693    0.7156    0.6341       109
#   enterobacter     0.1875    0.2515    0.2148       167
#   enterococcus     0.8824    0.7500    0.8108        60
#    escherichia     0.7901    0.4621    0.5831      1344
#     klebsiella     0.7029    0.5546    0.6200       559
#         others     0.0213    0.2167    0.0388        60
#    pseudomonas     0.5980    0.6952    0.6430       351
# staphylococcus     0.9333    0.8953    0.9139       172
#
#       accuracy                         0.5340      2822
#      macro avg     0.5856    0.5676    0.5573      2822
#   weighted avg     0.6991    0.5340    0.5915      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6303    0.6881    0.6579       109
#   enterobacter     0.2113    0.2455    0.2271       167
#   enterococcus     0.9167    0.7333    0.8148        60
#    escherichia     0.7932    0.4196    0.5489      1344
#     klebsiella     0.7355    0.5224    0.6109       559
#         others     0.0231    0.3167    0.0430        60
#    pseudomonas     0.6250    0.6553    0.6398       351
# staphylococcus     0.9506    0.8953    0.9222       172
#
#       accuracy                         0.5028      2822
#      macro avg     0.6107    0.5595    0.5581      2822
#   weighted avg     0.7160    0.5028    0.5753      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6697    0.6697    0.6697       109
#   enterobacter     0.2264    0.2156    0.2209       167
#   enterococcus     0.9348    0.7167    0.8113        60
#    escherichia     0.7950    0.3750    0.5096      1344
#     klebsiella     0.7890    0.4884    0.6033       559
#         others     0.0251    0.4333    0.0475        60
#    pseudomonas     0.6647    0.6325    0.6482       351
# staphylococcus     0.9625    0.8953    0.9277       172
#
#       accuracy                         0.4717      2822
#      macro avg     0.6334    0.5533    0.5548      2822
#   weighted avg     0.7359    0.4717    0.5566      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7526    0.6697    0.7087       109
#   enterobacter     0.2672    0.2096    0.2349       167
#   enterococcus     0.9756    0.6667    0.7921        60
#    escherichia     0.8075    0.3214    0.4598      1344
#     klebsiella     0.8084    0.4454    0.5744       559
#         others     0.0241    0.5000    0.0460        60
#    pseudomonas     0.6871    0.6068    0.6445       351
# staphylococcus     0.9745    0.8895    0.9301       172
#
#       accuracy                         0.4341      2822
#      macro avg     0.6621    0.5387    0.5488      2822
#   weighted avg     0.7557    0.4341    0.5287      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7976    0.6147    0.6943       109
#   enterobacter     0.3226    0.1796    0.2308       167
#   enterococcus     0.9744    0.6333    0.7677        60
#    escherichia     0.8163    0.2612    0.3957      1344
#     klebsiella     0.8396    0.4025    0.5441       559
#         others     0.0232    0.5667    0.0445        60
#    pseudomonas     0.7218    0.5840    0.6457       351
# staphylococcus     0.9808    0.8895    0.9329       172
#
#       accuracy                         0.3909      2822
#      macro avg     0.6845    0.5164    0.5320      2822
#   weighted avg     0.7757    0.3909    0.4912      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8696    0.5505    0.6742       109
#   enterobacter     0.3824    0.1557    0.2213       167
#   enterococcus     0.9697    0.5333    0.6882        60
#    escherichia     0.8368    0.1793    0.2953      1344
#     klebsiella     0.8670    0.3148    0.4619       559
#         others     0.0240    0.7000    0.0463        60
#    pseudomonas     0.7305    0.5328    0.6161       351
# staphylococcus     0.9803    0.8663    0.9198       172
#
#       accuracy                         0.3235      2822
#      macro avg     0.7075    0.4791    0.4904      2822
#   weighted avg     0.7982    0.3235    0.4196      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8929    0.4587    0.6061       109
#   enterobacter     0.6364    0.0419    0.0787       167
#   enterococcus     1.0000    0.4833    0.6517        60
#    escherichia     0.8359    0.0796    0.1454      1344
#     klebsiella     0.8986    0.2218    0.3558       559
#         others     0.0227    0.8000    0.0441        60
#    pseudomonas     0.7487    0.4245    0.5418       351
# staphylococcus     0.9792    0.8198    0.8924       172
#
#       accuracy                         0.2321      2822
#      macro avg     0.7518    0.4162    0.4145      2822
#   weighted avg     0.8228    0.2321    0.3044      2822
#
# ===================
# Finished
# ===================
# *** saprot_relaxed_r3, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13099, 1280)
# Test set shape: (3153, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4562    0.8182    0.5858       121
#   enterobacter     0.1614    0.3622    0.2233       196
#   enterococcus     0.6780    0.8163    0.7407        49
#    escherichia     0.7913    0.5727    0.6645      1589
#     klebsiella     0.4398    0.5153    0.4745       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.7045    0.7673    0.7346       404
# staphylococcus     0.8354    0.8408    0.8381       157
#
#       accuracy                         0.5915      3153
#      macro avg     0.5083    0.5866    0.5327      3153
#   weighted avg     0.6508    0.5915    0.6071      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5106    0.7934    0.6214       121
#   enterobacter     0.1685    0.3061    0.2174       196
#   enterococcus     0.7091    0.7959    0.7500        49
#    escherichia     0.7944    0.5689    0.6630      1589
#     klebsiella     0.4757    0.4830    0.4793       588
#         others     0.0258    0.1224    0.0426        49
#    pseudomonas     0.7150    0.7574    0.7356       404
# staphylococcus     0.8354    0.8408    0.8381       157
#
#       accuracy                         0.5794      3153
#      macro avg     0.5293    0.5835    0.5434      3153
#   weighted avg     0.6638    0.5794    0.6092      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5521    0.7438    0.6338       121
#   enterobacter     0.1673    0.2398    0.1971       196
#   enterococcus     0.7647    0.7959    0.7800        49
#    escherichia     0.8006    0.5406    0.6454      1589
#     klebsiella     0.5306    0.4575    0.4913       588
#         others     0.0156    0.1633    0.0285        49
#    pseudomonas     0.7328    0.7401    0.7365       404
# staphylococcus     0.8408    0.8408    0.8408       157
#
#       accuracy                         0.5528      3153
#      macro avg     0.5506    0.5652    0.5442      3153
#   weighted avg     0.6819    0.5528    0.6022      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5986    0.7025    0.6464       121
#   enterobacter     0.1741    0.2194    0.1941       196
#   enterococcus     0.7755    0.7755    0.7755        49
#    escherichia     0.8085    0.4808    0.6030      1589
#     klebsiella     0.5576    0.4201    0.4791       588
#         others     0.0166    0.2653    0.0313        49
#    pseudomonas     0.7532    0.7327    0.7428       404
# staphylococcus     0.8562    0.8344    0.8452       157
#
#       accuracy                         0.5128      3153
#      macro avg     0.5675    0.5538    0.5397      3153
#   weighted avg     0.6967    0.5128    0.5799      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6269    0.6942    0.6588       121
#   enterobacter     0.1699    0.1786    0.1741       196
#   enterococcus     0.8605    0.7551    0.8043        49
#    escherichia     0.8210    0.4273    0.5621      1589
#     klebsiella     0.5894    0.3980    0.4751       588
#         others     0.0198    0.4082    0.0377        49
#    pseudomonas     0.7650    0.7252    0.7446       404
# staphylococcus     0.8543    0.8217    0.8377       157
#
#       accuracy                         0.4792      3153
#      macro avg     0.5883    0.5510    0.5368      3153
#   weighted avg     0.7126    0.4792    0.5582      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6560    0.6777    0.6667       121
#   enterobacter     0.1747    0.1480    0.1602       196
#   enterococcus     0.9250    0.7551    0.8315        49
#    escherichia     0.8272    0.3795    0.5203      1589
#     klebsiella     0.6229    0.3707    0.4648       588
#         others     0.0180    0.4490    0.0346        49
#    pseudomonas     0.7757    0.7104    0.7416       404
# staphylococcus     0.8658    0.8217    0.8431       157
#
#       accuracy                         0.4462      3153
#      macro avg     0.6081    0.5390    0.5328      3153
#   weighted avg     0.7262    0.4462    0.5349      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7455    0.6777    0.7100       121
#   enterobacter     0.1951    0.1224    0.1505       196
#   enterococcus     0.9730    0.7347    0.8372        49
#    escherichia     0.8454    0.3304    0.4751      1589
#     klebsiella     0.6892    0.3469    0.4615       588
#         others     0.0177    0.5306    0.0342        49
#    pseudomonas     0.8034    0.6980    0.7470       404
# staphylococcus     0.8811    0.8025    0.8400       157
#
#       accuracy                         0.4139      3153
#      macro avg     0.6438    0.5304    0.5319      3153
#   weighted avg     0.7575    0.4139    0.5132      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8125    0.6446    0.7189       121
#   enterobacter     0.1970    0.0663    0.0992       196
#   enterococcus     0.9722    0.7143    0.8235        49
#    escherichia     0.8445    0.2769    0.4171      1589
#     klebsiella     0.7287    0.3197    0.4444       588
#         others     0.0181    0.6327    0.0353        49
#    pseudomonas     0.8179    0.6782    0.7415       404
# staphylococcus     0.9242    0.7771    0.8443       157
#
#       accuracy                         0.3746      3153
#      macro avg     0.6644    0.5137    0.5155      3153
#   weighted avg     0.7711    0.3746    0.4772      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8391    0.6033    0.7019       121
#   enterobacter     0.1739    0.0204    0.0365       196
#   enterococcus     0.9706    0.6735    0.7952        49
#    escherichia     0.8458    0.2140    0.3415      1589
#     klebsiella     0.7908    0.2636    0.3954       588
#         others     0.0172    0.6939    0.0335        49
#    pseudomonas     0.8301    0.6287    0.7155       404
# staphylococcus     0.9837    0.7707    0.8643       157
#
#       accuracy                         0.3216      3153
#      macro avg     0.6814    0.4835    0.4855      3153
#   weighted avg     0.7874    0.3216    0.4227      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9016    0.4545    0.6044       121
#   enterobacter     0.6667    0.0102    0.0201       196
#   enterococcus     1.0000    0.5918    0.7436        49
#    escherichia     0.8520    0.1340    0.2316      1589
#     klebsiella     0.8070    0.1565    0.2621       588
#         others     0.0160    0.7551    0.0313        49
#    pseudomonas     0.8783    0.5718    0.6927       404
# staphylococcus     0.9835    0.7580    0.8561       157
#
#       accuracy                         0.2467      3153
#      macro avg     0.7631    0.4290    0.4302      3153
#   weighted avg     0.8332    0.2467    0.3335      3153
#
# ===================
# Finished
# ===================
# *** saprot_relaxed_r3, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11662, 1280)
# Test set shape: (3203, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2266    0.6517    0.3362        89
#   enterobacter     0.1540    0.2824    0.1993       216
#   enterococcus     0.6786    0.9268    0.7835        41
#    escherichia     0.7839    0.5434    0.6419      1796
#     klebsiella     0.3821    0.4364    0.4074       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.4346    0.6624    0.5248       311
# staphylococcus     0.8506    0.8132    0.8315       182
#
#       accuracy                         0.5361      3203
#      macro avg     0.4388    0.5395    0.4656      3203
#   weighted avg     0.6183    0.5361    0.5580      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3107    0.6180    0.4135        89
#   enterobacter     0.1625    0.2407    0.1940       216
#   enterococcus     0.7308    0.9268    0.8172        41
#    escherichia     0.7903    0.5267    0.6321      1796
#     klebsiella     0.4103    0.4080    0.4091       527
#         others     0.0153    0.1220    0.0272        41
#    pseudomonas     0.4665    0.6495    0.5430       311
# staphylococcus     0.8506    0.8132    0.8315       182
#
#       accuracy                         0.5186      3203
#      macro avg     0.4671    0.5381    0.4835      3203
#   weighted avg     0.6334    0.5186    0.5571      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3741    0.6180    0.4661        89
#   enterobacter     0.1673    0.1898    0.1779       216
#   enterococcus     0.7755    0.9268    0.8444        41
#    escherichia     0.8018    0.5045    0.6193      1796
#     klebsiella     0.4706    0.3947    0.4293       527
#         others     0.0130    0.1951    0.0244        41
#    pseudomonas     0.4913    0.6334    0.5534       311
# staphylococcus     0.8506    0.8132    0.8315       182
#
#       accuracy                         0.4998      3203
#      macro avg     0.4930    0.5344    0.4933      3203
#   weighted avg     0.6548    0.4998    0.5549      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4262    0.5843    0.4929        89
#   enterobacter     0.1809    0.1574    0.1683       216
#   enterococcus     0.7872    0.9024    0.8409        41
#    escherichia     0.8074    0.4644    0.5896      1796
#     klebsiella     0.5269    0.3719    0.4360       527
#         others     0.0145    0.3171    0.0277        41
#    pseudomonas     0.5147    0.6174    0.5614       311
# staphylococcus     0.8605    0.8132    0.8362       182
#
#       accuracy                         0.4702      3203
#      macro avg     0.5148    0.5285    0.4941      3203
#   weighted avg     0.6726    0.4702    0.5405      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4679    0.5730    0.5152        89
#   enterobacter     0.1776    0.1250    0.1467       216
#   enterococcus     0.8140    0.8537    0.8333        41
#    escherichia     0.8341    0.4226    0.5610      1796
#     klebsiella     0.5667    0.3226    0.4111       527
#         others     0.0145    0.4146    0.0279        41
#    pseudomonas     0.5481    0.6045    0.5749       311
# staphylococcus     0.8647    0.8077    0.8352       182
#
#       accuracy                         0.4352      3203
#      macro avg     0.5359    0.5155    0.4882      3203
#   weighted avg     0.6989    0.4352    0.5207      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5158    0.5506    0.5326        89
#   enterobacter     0.2400    0.1111    0.1519       216
#   enterococcus     0.8140    0.8537    0.8333        41
#    escherichia     0.8582    0.3775    0.5244      1796
#     klebsiella     0.6157    0.2827    0.3875       527
#         others     0.0165    0.5854    0.0321        41
#    pseudomonas     0.5756    0.5756    0.5756       311
# staphylococcus     0.8690    0.8022    0.8343       182
#
#       accuracy                         0.4009      3203
#      macro avg     0.5631    0.5173    0.4840      3203
#   weighted avg     0.7289    0.4009    0.4972      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5366    0.4944    0.5146        89
#   enterobacter     0.2462    0.0741    0.1139       216
#   enterococcus     0.8500    0.8293    0.8395        41
#    escherichia     0.8633    0.3235    0.4706      1796
#     klebsiella     0.6300    0.2391    0.3466       527
#         others     0.0147    0.6098    0.0287        41
#    pseudomonas     0.6273    0.5466    0.5842       311
# staphylococcus     0.8690    0.8022    0.8343       182
#
#       accuracy                         0.3565      3203
#      macro avg     0.5796    0.4899    0.4666      3203
#   weighted avg     0.7406    0.3565    0.4581      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6897    0.4494    0.5442        89
#   enterobacter     0.2000    0.0278    0.0488       216
#   enterococcus     0.8684    0.8049    0.8354        41
#    escherichia     0.8745    0.2366    0.3725      1796
#     klebsiella     0.6513    0.1879    0.2916       527
#         others     0.0138    0.6829    0.0270        41
#    pseudomonas     0.6777    0.5273    0.5931       311
# staphylococcus     0.8735    0.7967    0.8333       182
#
#       accuracy                         0.2935      3203
#      macro avg     0.6061    0.4642    0.4433      3203
#   weighted avg     0.7569    0.2935    0.3912      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7500    0.3708    0.4962        89
#   enterobacter     0.6000    0.0139    0.0271       216
#   enterococcus     0.9167    0.8049    0.8571        41
#    escherichia     0.8907    0.1815    0.3016      1796
#     klebsiella     0.7059    0.1366    0.2289       527
#         others     0.0131    0.7317    0.0258        41
#    pseudomonas     0.7438    0.4855    0.5875       311
# staphylococcus     0.8944    0.7912    0.8397       182
#
#       accuracy                         0.2473      3203
#      macro avg     0.6893    0.4395    0.4205      3203
#   weighted avg     0.8118    0.2473    0.3384      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8966    0.2921    0.4407        89
#   enterobacter     0.5000    0.0046    0.0092       216
#   enterococcus     0.9655    0.6829    0.8000        41
#    escherichia     0.9091    0.1058    0.1895      1796
#     klebsiella     0.7391    0.0645    0.1187       527
#         others     0.0124    0.7805    0.0245        41
#    pseudomonas     0.7803    0.4341    0.5579       311
# staphylococcus     0.9787    0.7582    0.8545       182
#
#       accuracy                         0.1823      3203
#      macro avg     0.7227    0.3904    0.3744      3203
#   weighted avg     0.8339    0.1823    0.2519      3203
#
# ===================
# Finished
# ===================
