# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. If you have run `3.0. Data Consolidation (SaProt).ipynb`, then `data/inphared/consolidated` should have already been populated with the prerequisite files.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.11. Classifier Building & Evaluation (Random Forest).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a random forest, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = list(constants.SAPROT_PLM.keys())

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_saprot_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-rf-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            feature_columns=[f"s{i}" for i in range(1, 1281)],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="random-forest",
        )
# Out:
# *** saprot_relaxed_r3, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16942, 1280)
# Test set shape: (2340, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9326    0.7477    0.8300       111
#   enterobacter     0.4017    0.4052    0.4034       116
#   enterococcus     0.9000    0.8824    0.8911        51
#    escherichia     0.8688    0.8721    0.8704      1040
#     klebsiella     0.8258    0.8742    0.8493       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8409    0.9407    0.8880       354
# staphylococcus     0.9487    0.9487    0.9487       156
#
#       accuracy                         0.8402      2340
#      macro avg     0.7148    0.7089    0.7101      2340
#   weighted avg     0.8230    0.8402    0.8306      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9861    0.6396    0.7760       111
#   enterobacter     0.5325    0.3534    0.4249       116
#   enterococcus     0.9149    0.8431    0.8776        51
#    escherichia     0.9197    0.8144    0.8638      1040
#     klebsiella     0.8879    0.8243    0.8549       461
#         others     0.0845    0.4902    0.1441        51
#    pseudomonas     0.9222    0.9040    0.9130       354
# staphylococcus     0.9605    0.9359    0.9481       156
#
#       accuracy                         0.8004      2340
#      macro avg     0.7760    0.7256    0.7253      2340
#   weighted avg     0.8821    0.8004    0.8338      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.5856    0.7386       111
#   enterobacter     0.5614    0.2759    0.3699       116
#   enterococcus     0.9318    0.8039    0.8632        51
#    escherichia     0.9420    0.7490    0.8345      1040
#     klebsiella     0.9239    0.7636    0.8361       461
#         others     0.0709    0.7059    0.1288        51
#    pseudomonas     0.9709    0.8475    0.9050       354
# staphylococcus     0.9799    0.9359    0.9574       156
#
#       accuracy                         0.7483      2340
#      macro avg     0.7976    0.7084    0.7042      2340
#   weighted avg     0.9100    0.7483    0.8113      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.4865    0.6545       111
#   enterobacter     0.6170    0.2500    0.3558       116
#   enterococcus     0.9744    0.7451    0.8444        51
#    escherichia     0.9502    0.6788    0.7919      1040
#     klebsiella     0.9506    0.7093    0.8124       461
#         others     0.0671    0.9020    0.1248        51
#    pseudomonas     0.9930    0.7994    0.8858       354
# staphylococcus     0.9859    0.8974    0.9396       156
#
#       accuracy                         0.6936      2340
#      macro avg     0.8173    0.6836    0.6762      2340
#   weighted avg     0.9263    0.6936    0.7785      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.3964    0.5677       111
#   enterobacter     0.6667    0.2069    0.3158       116
#   enterococcus     1.0000    0.6667    0.8000        51
#    escherichia     0.9596    0.5942    0.7340      1040
#     klebsiella     0.9707    0.6464    0.7760       461
#         others     0.0557    0.9608    0.1053        51
#    pseudomonas     0.9962    0.7401    0.8493       354
# staphylococcus     0.9924    0.8397    0.9097       156
#
#       accuracy                         0.6239      2340
#      macro avg     0.8302    0.6314    0.6322      2340
#   weighted avg     0.9381    0.6239    0.7305      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.3243    0.4898       111
#   enterobacter     0.6296    0.1466    0.2378       116
#   enterococcus     1.0000    0.6471    0.7857        51
#    escherichia     0.9666    0.5010    0.6599      1040
#     klebsiella     0.9713    0.5141    0.6723       461
#         others     0.0456    0.9804    0.0872        51
#    pseudomonas     1.0000    0.6723    0.8041       354
# staphylococcus     1.0000    0.8141    0.8975       156
#
#       accuracy                         0.5380      2340
#      macro avg     0.8266    0.5750    0.5793      2340
#   weighted avg     0.9403    0.5380    0.6613      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.2613    0.4143       111
#   enterobacter     0.6923    0.0776    0.1395       116
#   enterococcus     1.0000    0.5686    0.7250        51
#    escherichia     0.9630    0.4010    0.5662      1040
#     klebsiella     0.9797    0.4187    0.5866       461
#         others     0.0385    0.9804    0.0740        51
#    pseudomonas     1.0000    0.6186    0.7644       354
# staphylococcus     1.0000    0.7692    0.8696       156
#
#       accuracy                         0.4556      2340
#      macro avg     0.8342    0.5119    0.5175      2340
#   weighted avg     0.9434    0.4556    0.5848      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.2162    0.3556       111
#   enterobacter     0.7143    0.0431    0.0813       116
#   enterococcus     1.0000    0.4314    0.6027        51
#    escherichia     0.9683    0.2933    0.4502      1040
#     klebsiella     0.9795    0.3102    0.4712       461
#         others     0.0333    1.0000    0.0645        51
#    pseudomonas     1.0000    0.5198    0.6840       354
# staphylococcus     1.0000    0.7115    0.8315       156
#
#       accuracy                         0.3611      2340
#      macro avg     0.8369    0.4407    0.4426      2340
#   weighted avg     0.9466    0.3611    0.4873      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.1261    0.2240       111
#   enterobacter     0.0000    0.0000    0.0000       116
#   enterococcus     1.0000    0.3725    0.5429        51
#    escherichia     0.9709    0.1923    0.3210      1040
#     klebsiella     0.9889    0.1931    0.3230       461
#         others     0.0287    1.0000    0.0559        51
#    pseudomonas     1.0000    0.3955    0.5668       354
# staphylococcus     1.0000    0.6154    0.7619       156
#
#       accuracy                         0.2603      2340
#      macro avg     0.7486    0.3619    0.3494      2340
#   weighted avg     0.9141    0.2603    0.3665      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0541    0.1026       111
#   enterobacter     0.0000    0.0000    0.0000       116
#   enterococcus     1.0000    0.1961    0.3279        51
#    escherichia     0.9556    0.0827    0.1522      1040
#     klebsiella     1.0000    0.0803    0.1486       461
#         others     0.0248    1.0000    0.0483        51
#    pseudomonas     1.0000    0.1949    0.3262       354
# staphylococcus     1.0000    0.4423    0.6133       156
#
#       accuracy                         0.1402      2340
#      macro avg     0.7475    0.2563    0.2149      2340
#   weighted avg     0.9094    0.1402    0.2002      2340
#
# ===================
# Finished
# ===================
# *** saprot_relaxed_r3, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14822, 1280)
# Test set shape: (2822, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4639    0.7064    0.5600       109
#   enterobacter     0.4100    0.2455    0.3071       167
#   enterococcus     0.9459    0.5833    0.7216        60
#    escherichia     0.7433    0.7024    0.7223      1344
#     klebsiella     0.6115    0.6476    0.6290       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.5216    0.6895    0.5939       351
# staphylococcus     0.8601    0.9651    0.9096       172
#
#       accuracy                         0.6616      2822
#      macro avg     0.5695    0.5675    0.5554      2822
#   weighted avg     0.6547    0.6616    0.6530      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6019    0.5963    0.5991       109
#   enterobacter     0.5227    0.1377    0.2180       167
#   enterococcus     0.9677    0.5000    0.6593        60
#    escherichia     0.8078    0.5379    0.6458      1344
#     klebsiella     0.7649    0.5528    0.6417       559
#         others     0.0405    0.5833    0.0758        60
#    pseudomonas     0.6358    0.5470    0.5881       351
# staphylococcus     0.9425    0.9535    0.9480       172
#
#       accuracy                         0.5461      2822
#      macro avg     0.6605    0.5511    0.5470      2822
#   weighted avg     0.7484    0.5461    0.6173      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5862    0.4679    0.5204       109
#   enterobacter     0.7727    0.1018    0.1799       167
#   enterococcus     0.9655    0.4667    0.6292        60
#    escherichia     0.8584    0.4241    0.5677      1344
#     klebsiella     0.8558    0.4776    0.6131       559
#         others     0.0361    0.8000    0.0692        60
#    pseudomonas     0.6987    0.4558    0.5517       351
# staphylococcus     0.9868    0.8663    0.9226       172
#
#       accuracy                         0.4571      2822
#      macro avg     0.7200    0.5075    0.5067      2822
#   weighted avg     0.8151    0.4571    0.5623      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5672    0.3486    0.4318       109
#   enterobacter     0.7778    0.0838    0.1514       167
#   enterococcus     0.9583    0.3833    0.5476        60
#    escherichia     0.9020    0.3289    0.4820      1344
#     klebsiella     0.9306    0.4079    0.5672       559
#         others     0.0328    0.9333    0.0633        60
#    pseudomonas     0.7945    0.3305    0.4668       351
# staphylococcus     1.0000    0.7151    0.8339       172
#
#       accuracy                         0.3685      2822
#      macro avg     0.7454    0.4414    0.4430      2822
#   weighted avg     0.8627    0.3685    0.4894      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9412    0.2936    0.4476       109
#   enterobacter     0.6667    0.0479    0.0894       167
#   enterococcus     0.9474    0.3000    0.4557        60
#    escherichia     0.9146    0.2232    0.3589      1344
#     klebsiella     0.9592    0.3363    0.4980       559
#         others     0.0289    0.9833    0.0561        60
#    pseudomonas     0.9167    0.2194    0.3540       351
# staphylococcus     1.0000    0.6221    0.7670       172
#
#       accuracy                         0.2796      2822
#      macro avg     0.7968    0.3782    0.3783      2822
#   weighted avg     0.8971    0.2796    0.3938      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.2569    0.4088       109
#   enterobacter     0.8333    0.0299    0.0578       167
#   enterococcus     1.0000    0.1667    0.2857        60
#    escherichia     0.9239    0.1354    0.2362      1344
#     klebsiella     0.9650    0.2469    0.3932       559
#         others     0.0262    1.0000    0.0511        60
#    pseudomonas     1.0000    0.1624    0.2794       351
# staphylococcus     1.0000    0.5349    0.6970       172
#
#       accuracy                         0.2027      2822
#      macro avg     0.8436    0.3166    0.3011      2822
#   weighted avg     0.9262    0.2027    0.2940      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.2202    0.3609       109
#   enterobacter     0.0000    0.0000    0.0000       167
#   enterococcus     1.0000    0.0667    0.1250        60
#    escherichia     0.8972    0.0714    0.1323      1344
#     klebsiella     0.9639    0.1431    0.2492       559
#         others     0.0238    1.0000    0.0466        60
#    pseudomonas     1.0000    0.1225    0.2183       351
# staphylococcus     1.0000    0.2616    0.4147       172
#
#       accuracy                         0.1247      2822
#      macro avg     0.7356    0.2357    0.1934      2822
#   weighted avg     0.8639    0.1247    0.1824      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.1376    0.2419       109
#   enterobacter     0.0000    0.0000    0.0000       167
#   enterococcus     1.0000    0.0167    0.0328        60
#    escherichia     0.8939    0.0439    0.0837      1344
#     klebsiella     0.9412    0.0572    0.1079       559
#         others     0.0226    1.0000    0.0442        60
#    pseudomonas     1.0000    0.0826    0.1526       351
# staphylococcus     1.0000    0.1337    0.2359       172
#
#       accuracy                         0.0776      2822
#      macro avg     0.7322    0.1840    0.1124      2822
#   weighted avg     0.8579    0.0776    0.1056      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0367    0.0708       109
#   enterobacter     0.0000    0.0000    0.0000       167
#   enterococcus     1.0000    0.0167    0.0328        60
#    escherichia     0.9000    0.0134    0.0264      1344
#     klebsiella     0.9375    0.0268    0.0522       559
#         others     0.0217    1.0000    0.0425        60
#    pseudomonas     1.0000    0.0285    0.0554       351
# staphylococcus     1.0000    0.0349    0.0674       172
#
#       accuracy                         0.0404      2822
#      macro avg     0.7324    0.1446    0.0434      2822
#   weighted avg     0.8600    0.0404    0.0382      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.0000    0.0000    0.0000       109
#   enterobacter     0.0000    0.0000    0.0000       167
#   enterococcus     0.0000    0.0000    0.0000        60
#    escherichia     0.8889    0.0060    0.0118      1344
#     klebsiella     1.0000    0.0072    0.0142       559
#         others     0.0214    1.0000    0.0418        60
#    pseudomonas     1.0000    0.0028    0.0057       351
# staphylococcus     0.0000    0.0000    0.0000       172
#
#       accuracy                         0.0259      2822
#      macro avg     0.3638    0.1270    0.0092      2822
#   weighted avg     0.7463    0.0259    0.0100      2822
#
# ===================
# Finished
# ===================
# *** saprot_relaxed_r3, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13099, 1280)
# Test set shape: (3153, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5361    0.7355    0.6202       121
#   enterobacter     0.1776    0.0969    0.1254       196
#   enterococcus     0.6066    0.7551    0.6727        49
#    escherichia     0.7178    0.7332    0.7254      1589
#     klebsiella     0.4839    0.4847    0.4843       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.6659    0.7203    0.6920       404
# staphylococcus     0.7118    0.7707    0.7401       157
#
#       accuracy                         0.6365      3153
#      macro avg     0.4875    0.5371    0.5075      3153
#   weighted avg     0.6138    0.6365    0.6235      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8421    0.5289    0.6497       121
#   enterobacter     0.2222    0.0510    0.0830       196
#   enterococcus     0.8293    0.6939    0.7556        49
#    escherichia     0.8264    0.5481    0.6591      1589
#     klebsiella     0.6049    0.3776    0.4649       588
#         others     0.0223    0.5102    0.0427        49
#    pseudomonas     0.7960    0.5891    0.6771       404
# staphylococcus     0.8000    0.7643    0.7818       157
#
#       accuracy                         0.5024      3153
#      macro avg     0.6179    0.5079    0.5142      3153
#   weighted avg     0.7305    0.5024    0.5870      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9796    0.3967    0.5647       121
#   enterobacter     0.2917    0.0357    0.0636       196
#   enterococcus     1.0000    0.5102    0.6757        49
#    escherichia     0.8842    0.3795    0.5310      1589
#     klebsiella     0.6886    0.3197    0.4367       588
#         others     0.0225    0.7959    0.0437        49
#    pseudomonas     0.8692    0.5099    0.6427       404
# staphylococcus     0.9286    0.7452    0.8269       157
#
#       accuracy                         0.3911      3153
#      macro avg     0.7080    0.4616    0.4731      3153
#   weighted avg     0.8032    0.3911    0.5094      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.2645    0.4183       121
#   enterobacter     0.4444    0.0204    0.0390       196
#   enterococcus     1.0000    0.3673    0.5373        49
#    escherichia     0.9151    0.2442    0.3855      1589
#     klebsiella     0.8287    0.2551    0.3901       588
#         others     0.0199    0.8980    0.0389        49
#    pseudomonas     0.9506    0.3812    0.5442       404
# staphylococcus     1.0000    0.7070    0.8284       157
#
#       accuracy                         0.2858      3153
#      macro avg     0.7698    0.3922    0.3977      3153
#   weighted avg     0.8692    0.2858    0.4054      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0909    0.1667       121
#   enterobacter     0.2500    0.0051    0.0100       196
#   enterococcus     1.0000    0.2857    0.4444        49
#    escherichia     0.9400    0.1479    0.2556      1589
#     klebsiella     0.9627    0.2194    0.3573       588
#         others     0.0186    0.9592    0.0365        49
#    pseudomonas     0.9821    0.2723    0.4264       404
# staphylococcus     1.0000    0.6306    0.7734       157
#
#       accuracy                         0.2049      3153
#      macro avg     0.7692    0.3264    0.3088      3153
#   weighted avg     0.8986    0.2049    0.3031      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0413    0.0794       121
#   enterobacter     1.0000    0.0051    0.0102       196
#   enterococcus     1.0000    0.0204    0.0400        49
#    escherichia     0.9366    0.0837    0.1537      1589
#     klebsiella     0.9583    0.1173    0.2091       588
#         others     0.0176    1.0000    0.0345        49
#    pseudomonas     1.0000    0.1955    0.3271       404
# staphylococcus     1.0000    0.4140    0.5856       157
#
#       accuracy                         0.1275      3153
#      macro avg     0.8641    0.2347    0.1799      3153
#   weighted avg     0.9450    0.1275    0.1923      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0165    0.0325       121
#   enterobacter     0.0000    0.0000    0.0000       196
#   enterococcus     1.0000    0.0204    0.0400        49
#    escherichia     0.9286    0.0409    0.0784      1589
#     klebsiella     0.9286    0.0442    0.0844       588
#         others     0.0165    1.0000    0.0326        49
#    pseudomonas     1.0000    0.1559    0.2698       404
# staphylococcus     1.0000    0.1783    0.3027       157
#
#       accuracy                         0.0742      3153
#      macro avg     0.7342    0.1820    0.1050      3153
#   weighted avg     0.8732    0.0742    0.1073      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.0000    0.0000    0.0000       121
#   enterobacter     0.0000    0.0000    0.0000       196
#   enterococcus     0.0000    0.0000    0.0000        49
#    escherichia     0.9118    0.0195    0.0382      1589
#     klebsiella     0.8333    0.0170    0.0333       588
#         others     0.0161    1.0000    0.0317        49
#    pseudomonas     1.0000    0.1287    0.2281       404
# staphylococcus     1.0000    0.0828    0.1529       157
#
#       accuracy                         0.0492      3153
#      macro avg     0.4702    0.1560    0.0605      3153
#   weighted avg     0.7931    0.0492    0.0628      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.0000    0.0000    0.0000       121
#   enterobacter     0.0000    0.0000    0.0000       196
#   enterococcus     0.0000    0.0000    0.0000        49
#    escherichia     0.8750    0.0088    0.0174      1589
#     klebsiella     0.8000    0.0136    0.0268       588
#         others     0.0158    1.0000    0.0312        49
#    pseudomonas     1.0000    0.0668    0.1253       404
# staphylococcus     1.0000    0.0446    0.0854       157
#
#       accuracy                         0.0333      3153
#      macro avg     0.4614    0.1417    0.0358      3153
#   weighted avg     0.7683    0.0333    0.0346      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.0000    0.0000    0.0000       121
#   enterobacter     0.0000    0.0000    0.0000       196
#   enterococcus     0.0000    0.0000    0.0000        49
#    escherichia     0.8000    0.0050    0.0100      1589
#     klebsiella     0.5000    0.0034    0.0068       588
#         others     0.0156    1.0000    0.0308        49
#    pseudomonas     1.0000    0.0074    0.0147       404
# staphylococcus     0.0000    0.0000    0.0000       157
#
#       accuracy                         0.0197      3153
#      macro avg     0.2895    0.1270    0.0078      3153
#   weighted avg     0.6248    0.0197    0.0087      3153
#
# ===================
# Finished
# ===================
# *** saprot_relaxed_r3, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11662, 1280)
# Test set shape: (3203, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.2558    0.4944    0.3372        89
#   enterobacter     0.1659    0.1574    0.1615       216
#   enterococcus     0.6410    0.6098    0.6250        41
#    escherichia     0.7273    0.6743    0.6998      1796
#     klebsiella     0.4447    0.4042    0.4235       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.4399    0.6592    0.5277       311
# staphylococcus     0.7119    0.6923    0.7019       182
#
#       accuracy                         0.5801      3203
#      macro avg     0.4233    0.4614    0.4346      3203
#   weighted avg     0.5907    0.5801    0.5814      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4746    0.3146    0.3784        89
#   enterobacter     0.1852    0.0694    0.1010       216
#   enterococcus     0.9167    0.5366    0.6769        41
#    escherichia     0.7755    0.4193    0.5443      1796
#     klebsiella     0.5489    0.2770    0.3682       527
#         others     0.0147    0.5122    0.0286        41
#    pseudomonas     0.6320    0.5080    0.5633       311
# staphylococcus     0.7698    0.5330    0.6299       182
#
#       accuracy                         0.3871      3203
#      macro avg     0.5397    0.3963    0.4113      3203
#   weighted avg     0.6678    0.3871    0.4826      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8148    0.2472    0.3793        89
#   enterobacter     0.4545    0.0463    0.0840       216
#   enterococcus     1.0000    0.4634    0.6333        41
#    escherichia     0.8619    0.2467    0.3835      1796
#     klebsiella     0.6667    0.1973    0.3045       527
#         others     0.0145    0.7805    0.0286        41
#    pseudomonas     0.7818    0.4148    0.5420       311
# staphylococcus     0.8700    0.4780    0.6170       182
#
#       accuracy                         0.2641      3203
#      macro avg     0.6830    0.3593    0.3715      3203
#   weighted avg     0.7846    0.2641    0.3775      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.9375    0.1685    0.2857        89
#   enterobacter     0.8571    0.0278    0.0538       216
#   enterococcus     1.0000    0.4146    0.5862        41
#    escherichia     0.9061    0.1559    0.2660      1796
#     klebsiella     0.7207    0.1518    0.2508       527
#         others     0.0145    0.9024    0.0286        41
#    pseudomonas     0.8699    0.3441    0.4931       311
# staphylococcus     0.9481    0.4011    0.5637       182
#
#       accuracy                         0.1920      3203
#      macro avg     0.7818    0.3208    0.3160      3203
#   weighted avg     0.8619    0.1920    0.2898      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.1011    0.1837        89
#   enterobacter     0.7500    0.0139    0.0273       216
#   enterococcus     1.0000    0.4146    0.5862        41
#    escherichia     0.9216    0.0785    0.1447      1796
#     klebsiella     0.7432    0.1044    0.1830       527
#         others     0.0139    0.9512    0.0274        41
#    pseudomonas     0.9485    0.2958    0.4510       311
# staphylococcus     1.0000    0.2527    0.4035       182
#
#       accuracy                         0.1255      3203
#      macro avg     0.7971    0.2765    0.2508      3203
#   weighted avg     0.8793    0.1255    0.1928      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0787    0.1458        89
#   enterobacter     0.6667    0.0093    0.0183       216
#   enterococcus     1.0000    0.0732    0.1364        41
#    escherichia     1.0000    0.0239    0.0468      1796
#     klebsiella     0.8000    0.0759    0.1386       527
#         others     0.0137    1.0000    0.0270        41
#    pseudomonas     0.9870    0.2444    0.3918       311
# staphylococcus     1.0000    0.1374    0.2415       182
#
#       accuracy                         0.0740      3203
#      macro avg     0.8084    0.2053    0.1433      3203
#   weighted avg     0.9307    0.0740    0.1082      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0449    0.0860        89
#   enterobacter     0.5000    0.0046    0.0092       216
#   enterococcus     1.0000    0.0732    0.1364        41
#    escherichia     1.0000    0.0100    0.0198      1796
#     klebsiella     0.8750    0.0398    0.0762       527
#         others     0.0132    1.0000    0.0261        41
#    pseudomonas     1.0000    0.1254    0.2229       311
# staphylococcus     1.0000    0.0989    0.1800       182
#
#       accuracy                         0.0453      3203
#      macro avg     0.7985    0.1746    0.0946      3203
#   weighted avg     0.9331    0.0453    0.0606      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     1.0000    0.0225    0.0440        89
#   enterobacter     1.0000    0.0046    0.0092       216
#   enterococcus     1.0000    0.0732    0.1364        41
#    escherichia     1.0000    0.0017    0.0033      1796
#     klebsiella     0.8000    0.0076    0.0150       527
#         others     0.0130    1.0000    0.0256        41
#    pseudomonas     1.0000    0.0257    0.0502       311
# staphylococcus     1.0000    0.0934    0.1709       182
#
#       accuracy                         0.0247      3203
#      macro avg     0.8516    0.1536    0.0568      3203
#   weighted avg     0.9545    0.0247    0.0228      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.0000    0.0000    0.0000        89
#   enterobacter     0.0000    0.0000    0.0000       216
#   enterococcus     1.0000    0.0488    0.0930        41
#    escherichia     0.0000    0.0000    0.0000      1796
#     klebsiella     1.0000    0.0019    0.0038       527
#         others     0.0129    1.0000    0.0254        41
#    pseudomonas     0.0000    0.0000    0.0000       311
# staphylococcus     1.0000    0.0714    0.1333       182
#
#       accuracy                         0.0178      3203
#      macro avg     0.3766    0.1403    0.0319      3203
#   weighted avg     0.2343    0.0178    0.0097      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.0000    0.0000    0.0000        89
#   enterobacter     0.0000    0.0000    0.0000       216
#   enterococcus     0.0000    0.0000    0.0000        41
#    escherichia     0.0000    0.0000    0.0000      1796
#     klebsiella     1.0000    0.0019    0.0038       527
#         others     0.0128    1.0000    0.0254        41
#    pseudomonas     0.0000    0.0000    0.0000       311
# staphylococcus     1.0000    0.0495    0.0942       182
#
#       accuracy                         0.0159      3203
#      macro avg     0.2516    0.1314    0.0154      3203
#   weighted avg     0.2215    0.0159    0.0063      3203
#
# ===================
# Finished
# ===================
