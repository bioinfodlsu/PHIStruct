# %% [markdown]
# # PHIStruct: Improving phage-host interaction prediction at low sequence similarity settings using structure-aware protein embeddings
#
# <b>Mark Edward M. Gonzales<sup>1, 2</sup>, Jennifer C. Ureta<sup>1, 2, 3</sup> & Anish M.S. Shrestha<sup>1, 2</sup></b>
#
# <sup>1</sup> Bioinformatics Lab, Advanced Research Institute for Informatics, Computing and Networking, De La Salle University, Manila 1004, Philippines <br>
# <sup>2</sup> Department of Software Technology, College of Computer Studies, De La Salle University, Manila 1004, Philippines <br>
# <sup>3</sup> Walter and Eliza Hall Institute of Medical Research, Melbourne, Victoria, 3052, Australia
#
# ✉️ gonzales.markedward@gmail.com, jennifer.ureta@gmail.com, anish.shrestha@dlsu.edu.ph

# %% [markdown]
# <hr>

# %% [markdown]
# # 💡 Prerequisites
#
# ### Option 1: Download the prerequisite files
# 1. Download `consolidated.tar.gz` from this [link](https://drive.google.com/file/d/1yQSXwlb37dm2ZLXGJHdIM5vmrzwPAwvI/view?usp=sharing), and unzip it. This should result in a folder named `consolidated`. <br> Technically, this notebook only needs `consolidated/rbp_embeddings_saprot_seq_mask_relaxed_r3.csv` and `consolidated/rbp_embeddings_saprot_relaxed_r3.csv`.
# 1. Create a folder named `inphared` inside `data`, and save the extracted `consolidated` folder inside `data/inphared`.
# 1. Download `fasta.tar.gz` from this [link](https://drive.google.com/file/d/1NMFR3JrrrCHLoCMQp2nia4dgtcXs5x05/view?usp=sharing), and unzip it. This should result in a folder named `fasta`. <br> Technically, this notebook only needs the `.clstr` files inside `fasta`.
# 1. Save the extracted `fasta` folder inside `data/inphared`.
#
# ### Option 2: Generate the prerequisite files yourself
# 1. If you have run `3.5. Data Consolidation (SaProt with Sequence Masking).ipynb`, then `data/inphared/consolidated` should have already been populated with the prerequisite files.
# 1. Consolidate the sequences of the proteins with predicted structures into a single FASTA file. <br>
#    For reproducibility, we provide our consolidated FASTA file [here](https://drive.google.com/file/d/1LTZte1f4lreQ5MXWeM-y2Mtp9z96pXS7/view?usp=sharing).
# 1. Generate the protein clusters by running CD-HIT on this FASTA file at a sequence similarity threshold of 100%, following the instructions [here](https://github.com/weizhongli/cdhit).
# 1. Rename the resulting `.clstr` file to `complete-struct-100.fasta.clstr` and the resulting FASTA file (containing only the representative sequences) to `complete-struct-100.fasta`.
# 1. Generate `complete-struct-80.fasta.clstr`, `complete-struct-60.fasta.clstr`, and `complete-struct-40.fasta.clstr` by running CD-HIT on `complete-struct-100.fasta` at sequence similarity thresholds of 80%, 60%, and 40%, respectively.
# 1. Create a folder named `fasta` inside `data/inphared`, and save the four `.clstr` files inside `data/inphared/fasta`.
#
# ### Resulting folder structure
#
# `experiments` (parent folder of this notebook) <br>
# ↳ `data` <br>
# &nbsp; &nbsp;↳ `inphared` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `consolidated` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `rbp_embeddings_saprot_seq_mask_relaxed_r3.csv` <br>
# &nbsp; &nbsp;&nbsp; &nbsp; ↳ `fasta` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-100.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-80.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-40.fasta.clstr` <br>
# &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp; ↳ `complete-struct-60.fasta.clstr` <br>
# ↳ `5.8. Benchmarking - Classifier Building & Evaluation (SaProt with Sequence Masking).ipynb` (this notebook) <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # 📁 Output files
#
# The output files (i.e., the results of evaluating the model's performance) &mdash; which are saved in `temp/results` &mdash; are already included when the repository was cloned. <br>

# %% [markdown]
# <hr>

# %% [markdown]
# # Part I: Preliminaries

# %% [markdown]
# Import the necessary libraries and modules.

# %%
import warnings

import pandas as pd
import sklearn

import ConstantsUtil
import ClassificationUtil

# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", 50)

pd.options.mode.chained_assignment = None

with warnings.catch_warnings():
    warnings.filterwarnings(
        "ignore", category=sklearn.exceptions.UndefinedMetricWarning
    )

# %%
constants = ConstantsUtil.ConstantsUtil()
util = ClassificationUtil.ClassificationUtil()

# %% [markdown]
# <hr>

# %% [markdown]
# # Part II: Classifier Building and Evaluation

# %% [markdown]
# Train a multilayer perceptron, and evaluate its performance at different train-versus-test similarity and confidence thresholds.

# %%
models = list(constants.SAPROT_SEQ_MASK_PLM.keys())

for similarity in range(100, 39, -20):
    for model in models:
        model = model.lower()
        df, df_all, protein_clusters = util.filter_proteins_based_on_struct_and_seq_sim(
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_{model}.csv",
            f"{constants.INPHARED}/{constants.CONSOLIDATED}/rbp_embeddings_saprot_relaxed_r3.csv",
            f"{constants.INPHARED}/{constants.FASTA}/complete-struct-{similarity}.fasta.clstr",
        )

        include_proteins_in_cluster = True
        if similarity == 100:
            include_proteins_in_cluster = False

        print(f"*** {model}, similarity = {similarity}% ***")
        util.classify(
            df,
            model + "-mlp-eskapee-smotetomek",
            similarity,
            genus=[
                "enterococcus",
                "staphylococcus",
                "klebsiella",
                "acinetobacter",
                "pseudomonas",
                "enterobacter",
                "escherichia",
            ],
            feature_columns=[f"s{i}" for i in range(1, 1281)],
            include_proteins_in_cluster=include_proteins_in_cluster,
            rbp_embeddings_all=df_all,
            protein_clusters=protein_clusters,
            undersample_others=True,
            oversample_technique="SMOTETomek",
            model="MLP",
        )
# Out:
# *** saprot_seq_mask_relaxed_r3, similarity = 100% ***
# Constructing training and test sets...
# Training set shape: (16940, 1280)
# Test set shape: (2340, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.6911    0.7658    0.7265       111
#   enterobacter     0.2500    0.3448    0.2899       116
#   enterococcus     0.6286    0.8627    0.7273        51
#    escherichia     0.8376    0.7885    0.8123      1040
#     klebsiella     0.7640    0.8004    0.7818       461
#         others     0.0000    0.0000    0.0000        51
#    pseudomonas     0.8115    0.8757    0.8424       354
# staphylococcus     0.9510    0.8718    0.9097       156
#
#       accuracy                         0.7709      2340
#      macro avg     0.6167    0.6637    0.6362      2340
#   weighted avg     0.7678    0.7709    0.7678      2340
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7119    0.7568    0.7336       111
#   enterobacter     0.2727    0.3362    0.3012       116
#   enterococcus     0.6377    0.8627    0.7333        51
#    escherichia     0.8396    0.7702    0.8034      1040
#     klebsiella     0.7828    0.7896    0.7862       461
#         others     0.0253    0.0392    0.0308        51
#    pseudomonas     0.8270    0.8644    0.8453       354
# staphylococcus     0.9577    0.8718    0.9128       156
#
#       accuracy                         0.7590      2340
#      macro avg     0.6318    0.6614    0.6433      2340
#   weighted avg     0.7781    0.7590    0.7671      2340
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7217    0.7477    0.7345       111
#   enterobacter     0.2984    0.3190    0.3083       116
#   enterococcus     0.6471    0.8627    0.7395        51
#    escherichia     0.8423    0.7548    0.7961      1040
#     klebsiella     0.7956    0.7852    0.7904       461
#         others     0.0274    0.0784    0.0406        51
#    pseudomonas     0.8384    0.8503    0.8443       354
# staphylococcus     0.9645    0.8718    0.9158       156
#
#       accuracy                         0.7487      2340
#      macro avg     0.6419    0.6588    0.6462      2340
#   weighted avg     0.7860    0.7487    0.7655      2340
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7257    0.7387    0.7321       111
#   enterobacter     0.2957    0.2931    0.2944       116
#   enterococcus     0.6769    0.8627    0.7586        51
#    escherichia     0.8524    0.7221    0.7819      1040
#     klebsiella     0.8041    0.7570    0.7799       461
#         others     0.0292    0.1373    0.0481        51
#    pseudomonas     0.8523    0.8475    0.8499       354
# staphylococcus     0.9714    0.8718    0.9189       156
#
#       accuracy                         0.7278      2340
#      macro avg     0.6510    0.6538    0.6455      2340
#   weighted avg     0.7954    0.7278    0.7579      2340
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7297    0.7297    0.7297       111
#   enterobacter     0.3039    0.2672    0.2844       116
#   enterococcus     0.6984    0.8627    0.7719        51
#    escherichia     0.8642    0.7038    0.7758      1040
#     klebsiella     0.8128    0.7440    0.7769       461
#         others     0.0323    0.1961    0.0554        51
#    pseudomonas     0.8613    0.8418    0.8514       354
# staphylococcus     0.9712    0.8654    0.9153       156
#
#       accuracy                         0.7154      2340
#      macro avg     0.6592    0.6514    0.6451      2340
#   weighted avg     0.8049    0.7154    0.7544      2340
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7383    0.7117    0.7248       111
#   enterobacter     0.3226    0.2586    0.2871       116
#   enterococcus     0.7097    0.8627    0.7788        51
#    escherichia     0.8645    0.6808    0.7617      1040
#     klebsiella     0.8243    0.7223    0.7699       461
#         others     0.0372    0.2745    0.0656        51
#    pseudomonas     0.8706    0.8362    0.8530       354
# staphylococcus     0.9712    0.8654    0.9153       156
#
#       accuracy                         0.7004      2340
#      macro avg     0.6673    0.6515    0.6445      2340
#   weighted avg     0.8103    0.7004    0.7473      2340
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7429    0.7027    0.7222       111
#   enterobacter     0.3415    0.2414    0.2828       116
#   enterococcus     0.7241    0.8235    0.7706        51
#    escherichia     0.8748    0.6519    0.7471      1040
#     klebsiella     0.8511    0.6941    0.7646       461
#         others     0.0444    0.4118    0.0802        51
#    pseudomonas     0.8886    0.8333    0.8601       354
# staphylococcus     0.9712    0.8654    0.9153       156
#
#       accuracy                         0.6825      2340
#      macro avg     0.6798    0.6530    0.6429      2340
#   weighted avg     0.8246    0.6825    0.7406      2340
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.7778    0.6937    0.7333       111
#   enterobacter     0.3611    0.2241    0.2766       116
#   enterococcus     0.7368    0.8235    0.7778        51
#    escherichia     0.8877    0.6154    0.7269      1040
#     klebsiella     0.8523    0.6508    0.7380       461
#         others     0.0418    0.4706    0.0768        51
#    pseudomonas     0.8930    0.8249    0.8576       354
# staphylococcus     0.9710    0.8590    0.9116       156
#
#       accuracy                         0.6560      2340
#      macro avg     0.6902    0.6452    0.6373      2340
#   weighted avg     0.8340    0.6560    0.7261      2340
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8065    0.6757    0.7353       111
#   enterobacter     0.3860    0.1897    0.2543       116
#   enterococcus     0.7636    0.8235    0.7925        51
#    escherichia     0.8964    0.5740    0.6999      1040
#     klebsiella     0.8654    0.6139    0.7183       461
#         others     0.0418    0.5686    0.0780        51
#    pseudomonas     0.9079    0.8079    0.8550       354
# staphylococcus     0.9776    0.8397    0.9034       156
#
#       accuracy                         0.6261      2340
#      macro avg     0.7057    0.6366    0.6296      2340
#   weighted avg     0.8464    0.6261    0.7086      2340
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.8276    0.6486    0.7273       111
#   enterobacter     0.4615    0.1552    0.2323       116
#   enterococcus     0.7778    0.8235    0.8000        51
#    escherichia     0.9069    0.5154    0.6573      1040
#     klebsiella     0.8922    0.5206    0.6575       461
#         others     0.0380    0.6471    0.0718        51
#    pseudomonas     0.9236    0.7853    0.8489       354
# staphylococcus     0.9771    0.8205    0.8920       156
#
#       accuracy                         0.5756      2340
#      macro avg     0.7256    0.6145    0.6109      2340
#   weighted avg     0.8636    0.5756    0.6746      2340
#
# ===================
# Finished
# ===================
# *** saprot_seq_mask_relaxed_r3, similarity = 80% ***
# Constructing training and test sets...
# Training set shape: (14824, 1280)
# Test set shape: (2822, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3724    0.6697    0.4787       109
#   enterobacter     0.1769    0.1557    0.1656       167
#   enterococcus     0.6346    0.5500    0.5893        60
#    escherichia     0.6521    0.7433    0.6947      1344
#     klebsiella     0.6188    0.4705    0.5346       559
#         others     0.0000    0.0000    0.0000        60
#    pseudomonas     0.5192    0.4615    0.4887       351
# staphylococcus     0.8038    0.7384    0.7697       172
#
#       accuracy                         0.5964      2822
#      macro avg     0.4722    0.4736    0.4652      2822
#   weighted avg     0.5851    0.5964    0.5853      2822
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3862    0.6697    0.4899       109
#   enterobacter     0.1920    0.1437    0.1644       167
#   enterococcus     0.6346    0.5500    0.5893        60
#    escherichia     0.6594    0.7188    0.6878      1344
#     klebsiella     0.6396    0.4508    0.5289       559
#         others     0.0345    0.0833    0.0488        60
#    pseudomonas     0.5253    0.4444    0.4815       351
# staphylococcus     0.8129    0.7326    0.7706       172
#
#       accuracy                         0.5794      2822
#      macro avg     0.4856    0.4742    0.4701      2822
#   weighted avg     0.5961    0.5794    0.5814      2822
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.3966    0.6514    0.4931       109
#   enterobacter     0.2056    0.1317    0.1606       167
#   enterococcus     0.6471    0.5500    0.5946        60
#    escherichia     0.6674    0.6927    0.6798      1344
#     klebsiella     0.6575    0.4293    0.5195       559
#         others     0.0312    0.1500    0.0517        60
#    pseudomonas     0.5226    0.4274    0.4702       351
# staphylococcus     0.8333    0.7267    0.7764       172
#
#       accuracy                         0.5602      2822
#      macro avg     0.4952    0.4699    0.4682      2822
#   weighted avg     0.6058    0.5602    0.5748      2822
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4176    0.6514    0.5090       109
#   enterobacter     0.2444    0.1317    0.1712       167
#   enterococcus     0.6600    0.5500    0.6000        60
#    escherichia     0.6724    0.6689    0.6706      1344
#     klebsiella     0.6647    0.4114    0.5083       559
#         others     0.0386    0.2667    0.0675        60
#    pseudomonas     0.5314    0.4103    0.4630       351
# staphylococcus     0.8472    0.7093    0.7722       172
#
#       accuracy                         0.5446      2822
#      macro avg     0.5096    0.4750    0.4702      2822
#   weighted avg     0.6151    0.5446    0.5687      2822
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4233    0.6330    0.5074       109
#   enterobacter     0.2817    0.1198    0.1681       167
#   enterococcus     0.6600    0.5500    0.6000        60
#    escherichia     0.6737    0.6391    0.6560      1344
#     klebsiella     0.6780    0.3918    0.4966       559
#         others     0.0328    0.3000    0.0591        60
#    pseudomonas     0.5375    0.3875    0.4503       351
# staphylococcus     0.8623    0.6919    0.7677       172
#
#       accuracy                         0.5220      2822
#      macro avg     0.5187    0.4641    0.4631      2822
#   weighted avg     0.6223    0.5220    0.5571      2822
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4268    0.6147    0.5038       109
#   enterobacter     0.3158    0.1078    0.1607       167
#   enterococcus     0.6735    0.5500    0.6055        60
#    escherichia     0.6794    0.6086    0.6421      1344
#     klebsiella     0.6887    0.3721    0.4832       559
#         others     0.0294    0.3333    0.0540        60
#    pseudomonas     0.5439    0.3704    0.4407       351
# staphylococcus     0.8722    0.6744    0.7607       172
#
#       accuracy                         0.4996      2822
#      macro avg     0.5287    0.4539    0.4563      2822
#   weighted avg     0.6309    0.4996    0.5457      2822
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4552    0.6055    0.5197       109
#   enterobacter     0.3542    0.1018    0.1581       167
#   enterococcus     0.6875    0.5500    0.6111        60
#    escherichia     0.6922    0.5856    0.6344      1344
#     klebsiella     0.7011    0.3524    0.4690       559
#         others     0.0304    0.4167    0.0566        60
#    pseudomonas     0.5587    0.3390    0.4220       351
# staphylococcus     0.8976    0.6628    0.7625       172
#
#       accuracy                         0.4812      2822
#      macro avg     0.5471    0.4517    0.4542      2822
#   weighted avg     0.6465    0.4812    0.5377      2822
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4815    0.5963    0.5328       109
#   enterobacter     0.3333    0.0659    0.1100       167
#   enterococcus     0.7021    0.5500    0.6168        60
#    escherichia     0.7026    0.5484    0.6160      1344
#     klebsiella     0.7302    0.3292    0.4538       559
#         others     0.0306    0.5000    0.0577        60
#    pseudomonas     0.5473    0.3134    0.3986       351
# staphylococcus     0.9120    0.6628    0.7677       172
#
#       accuracy                         0.4550      2822
#      macro avg     0.5549    0.4457    0.4442      2822
#   weighted avg     0.6568    0.4550    0.5210      2822
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4961    0.5780    0.5339       109
#   enterobacter     0.3182    0.0419    0.0741       167
#   enterococcus     0.7021    0.5500    0.6168        60
#    escherichia     0.7076    0.5060    0.5900      1344
#     klebsiella     0.7600    0.2719    0.4005       559
#         others     0.0281    0.5500    0.0534        60
#    pseudomonas     0.5385    0.2593    0.3500       351
# staphylococcus     0.9256    0.6512    0.7645       172
#
#       accuracy                         0.4150      2822
#      macro avg     0.5595    0.4260    0.4229      2822
#   weighted avg     0.6644    0.4150    0.4897      2822
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5179    0.5321    0.5249       109
#   enterobacter     0.2667    0.0240    0.0440       167
#   enterococcus     0.7674    0.5500    0.6408        60
#    escherichia     0.7229    0.4368    0.5445      1344
#     klebsiella     0.7933    0.2129    0.3357       559
#         others     0.0277    0.6667    0.0532        60
#    pseudomonas     0.5683    0.2251    0.3224       351
# staphylococcus     0.9533    0.5930    0.7312       172
#
#       accuracy                         0.3622      2822
#      macro avg     0.5772    0.4051    0.3996      2822
#   weighted avg     0.6829    0.3622    0.4481      2822
#
# ===================
# Finished
# ===================
# *** saprot_seq_mask_relaxed_r3, similarity = 60% ***
# Constructing training and test sets...
# Training set shape: (13099, 1280)
# Test set shape: (3153, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4479    0.7107    0.5495       121
#   enterobacter     0.1758    0.1480    0.1607       196
#   enterococcus     0.3966    0.4694    0.4299        49
#    escherichia     0.6734    0.6514    0.6622      1589
#     klebsiella     0.3830    0.4065    0.3944       588
#         others     0.0000    0.0000    0.0000        49
#    pseudomonas     0.5244    0.5842    0.5527       404
# staphylococcus     0.8740    0.7070    0.7817       157
#
#       accuracy                         0.5579      3153
#      macro avg     0.4344    0.4596    0.4414      3153
#   weighted avg     0.5558    0.5579    0.5548      3153
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4674    0.7107    0.5639       121
#   enterobacter     0.1722    0.1327    0.1499       196
#   enterococcus     0.3966    0.4694    0.4299        49
#    escherichia     0.6797    0.6344    0.6562      1589
#     klebsiella     0.3880    0.3946    0.3912       588
#         others     0.0167    0.0408    0.0237        49
#    pseudomonas     0.5335    0.5718    0.5520       404
# staphylococcus     0.8810    0.7070    0.7845       157
#
#       accuracy                         0.5452      3153
#      macro avg     0.4419    0.4577    0.4439      3153
#   weighted avg     0.5622    0.5452    0.5515      3153
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.4942    0.7025    0.5802       121
#   enterobacter     0.1866    0.1276    0.1515       196
#   enterococcus     0.4182    0.4694    0.4423        49
#    escherichia     0.6803    0.6161    0.6466      1589
#     klebsiella     0.3833    0.3741    0.3787       588
#         others     0.0170    0.0816    0.0282        49
#    pseudomonas     0.5357    0.5569    0.5461       404
# staphylococcus     0.8871    0.7006    0.7829       157
#
#       accuracy                         0.5300      3153
#      macro avg     0.4503    0.4536    0.4446      3153
#   weighted avg     0.5645    0.5300    0.5445      3153
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5120    0.7025    0.5923       121
#   enterobacter     0.1653    0.1020    0.1262       196
#   enterococcus     0.4510    0.4694    0.4600        49
#    escherichia     0.6868    0.5935    0.6367      1589
#     klebsiella     0.3831    0.3537    0.3678       588
#         others     0.0190    0.1429    0.0335        49
#    pseudomonas     0.5504    0.5545    0.5524       404
# staphylococcus     0.8943    0.7006    0.7857       157
#
#       accuracy                         0.5138      3153
#      macro avg     0.4577    0.4524    0.4443      3153
#   weighted avg     0.5698    0.5138    0.5376      3153
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5247    0.7025    0.6007       121
#   enterobacter     0.1574    0.0867    0.1118       196
#   enterococcus     0.4681    0.4490    0.4583        49
#    escherichia     0.6879    0.5645    0.6201      1589
#     klebsiella     0.3857    0.3384    0.3605       588
#         others     0.0255    0.2653    0.0465        49
#    pseudomonas     0.5596    0.5347    0.5468       404
# staphylococcus     0.9000    0.6879    0.7798       157
#
#       accuracy                         0.4938      3153
#      macro avg     0.4636    0.4536    0.4406      3153
#   weighted avg     0.5727    0.4938    0.5265      3153
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5325    0.6777    0.5964       121
#   enterobacter     0.1616    0.0816    0.1085       196
#   enterococcus     0.4681    0.4490    0.4583        49
#    escherichia     0.6964    0.5456    0.6119      1589
#     klebsiella     0.3954    0.3248    0.3567       588
#         others     0.0222    0.2857    0.0412        49
#    pseudomonas     0.5691    0.5297    0.5487       404
# staphylococcus     0.8992    0.6815    0.7754       157
#
#       accuracy                         0.4799      3153
#      macro avg     0.4681    0.4470    0.4371      3153
#   weighted avg     0.5805    0.4799    0.5212      3153
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5503    0.6777    0.6074       121
#   enterobacter     0.1410    0.0561    0.0803       196
#   enterococcus     0.5000    0.4082    0.4494        49
#    escherichia     0.7004    0.5179    0.5955      1589
#     klebsiella     0.4018    0.3095    0.3497       588
#         others     0.0265    0.4286    0.0500        49
#    pseudomonas     0.5897    0.5124    0.5483       404
# staphylococcus     0.9138    0.6752    0.7766       157
#
#       accuracy                         0.4605      3153
#      macro avg     0.4780    0.4482    0.4322      3153
#   weighted avg     0.5871    0.4605    0.5103      3153
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5548    0.6694    0.6067       121
#   enterobacter     0.1429    0.0510    0.0752       196
#   enterococcus     0.5000    0.4082    0.4494        49
#    escherichia     0.7053    0.4789    0.5705      1589
#     klebsiella     0.4213    0.2959    0.3477       588
#         others     0.0262    0.5102    0.0498        49
#    pseudomonas     0.6018    0.5050    0.5491       404
# staphylococcus     0.9182    0.6433    0.7566       157
#
#       accuracy                         0.4364      3153
#      macro avg     0.4838    0.4452    0.4256      3153
#   weighted avg     0.5952    0.4364    0.4961      3153
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5547    0.6281    0.5891       121
#   enterobacter     0.1607    0.0459    0.0714       196
#   enterococcus     0.5128    0.4082    0.4545        49
#    escherichia     0.7059    0.4261    0.5314      1589
#     klebsiella     0.4553    0.2772    0.3446       588
#         others     0.0234    0.5714    0.0449        49
#    pseudomonas     0.6412    0.4777    0.5475       404
# staphylococcus     0.9434    0.6369    0.7605       157
#
#       accuracy                         0.4015      3153
#      macro avg     0.4997    0.4339    0.4180      3153
#   weighted avg     0.6094    0.4015    0.4749      3153
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.5652    0.5372    0.5508       121
#   enterobacter     0.1463    0.0306    0.0506       196
#   enterococcus     0.5758    0.3878    0.4634        49
#    escherichia     0.7110    0.3468    0.4662      1589
#     klebsiella     0.4623    0.2296    0.3068       588
#         others     0.0207    0.6531    0.0401        49
#    pseudomonas     0.7061    0.4282    0.5331       404
# staphylococcus     0.9417    0.6178    0.7462       157
#
#       accuracy                         0.3419      3153
#      macro avg     0.5161    0.4039    0.3947      3153
#   weighted avg     0.6219    0.3419    0.4297      3153
#
# ===================
# Finished
# ===================
# *** saprot_seq_mask_relaxed_r3, similarity = 40% ***
# Constructing training and test sets...
# Training set shape: (11648, 1280)
# Test set shape: (3203, 1280)
# Training the model...
# Saving evaluation results...
# Confidence threshold k: 0.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1193    0.4719    0.1905        89
#   enterobacter     0.1487    0.1852    0.1649       216
#   enterococcus     0.2794    0.4634    0.3486        41
#    escherichia     0.6347    0.5050    0.5625      1796
#     klebsiella     0.3240    0.3947    0.3559       527
#         others     0.0000    0.0000    0.0000        41
#    pseudomonas     0.4227    0.4662    0.4434       311
# staphylococcus     0.7400    0.4066    0.5248       182
#
#       accuracy                         0.4480      3203
#      macro avg     0.3336    0.3616    0.3238      3203
#   weighted avg     0.5092    0.4480    0.4677      3203
#
# ===================
# Confidence threshold k: 10.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1221    0.4719    0.1940        89
#   enterobacter     0.1434    0.1713    0.1561       216
#   enterococcus     0.2879    0.4634    0.3551        41
#    escherichia     0.6424    0.4972    0.5606      1796
#     klebsiella     0.3300    0.3757    0.3514       527
#         others     0.0083    0.0244    0.0123        41
#    pseudomonas     0.4369    0.4566    0.4465       311
# staphylococcus     0.7374    0.4011    0.5196       182
#
#       accuracy                         0.4387      3203
#      macro avg     0.3385    0.3577    0.3245      3203
#   weighted avg     0.5157    0.4387    0.4656      3203
#
# ===================
# Confidence threshold k: 20.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1261    0.4719    0.1991        89
#   enterobacter     0.1481    0.1667    0.1569       216
#   enterococcus     0.3065    0.4634    0.3689        41
#    escherichia     0.6393    0.4677    0.5402      1796
#     klebsiella     0.3363    0.3605    0.3480       527
#         others     0.0105    0.0732    0.0183        41
#    pseudomonas     0.4455    0.4341    0.4397       311
# staphylococcus     0.7320    0.3901    0.5090       182
#
#       accuracy                         0.4171      3203
#      macro avg     0.3430    0.3534    0.3225      3203
#   weighted avg     0.5162    0.4171    0.4528      3203
#
# ===================
# Confidence threshold k: 30.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1273    0.4607    0.1995        89
#   enterobacter     0.1572    0.1667    0.1618       216
#   enterococcus     0.3167    0.4634    0.3762        41
#    escherichia     0.6419    0.4521    0.5305      1796
#     klebsiella     0.3402    0.3454    0.3427       527
#         others     0.0169    0.1707    0.0307        41
#    pseudomonas     0.4679    0.4212    0.4433       311
# staphylococcus     0.7320    0.3901    0.5090       182
#
#       accuracy                         0.4056      3203
#      macro avg     0.3500    0.3588    0.3242      3203
#   weighted avg     0.5213    0.4056    0.4475      3203
#
# ===================
# Confidence threshold k: 40.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1230    0.4270    0.1910        89
#   enterobacter     0.1500    0.1528    0.1514       216
#   enterococcus     0.3036    0.4146    0.3505        41
#    escherichia     0.6498    0.4360    0.5218      1796
#     klebsiella     0.3393    0.3264    0.3327       527
#         others     0.0148    0.1951    0.0275        41
#    pseudomonas     0.4813    0.4148    0.4456       311
# staphylococcus     0.7320    0.3901    0.5090       182
#
#       accuracy                         0.3906      3203
#      macro avg     0.3492    0.3446    0.3162      3203
#   weighted avg     0.5261    0.3906    0.4399      3203
#
# ===================
# Confidence threshold k: 50.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1237    0.4157    0.1907        89
#   enterobacter     0.1498    0.1435    0.1466       216
#   enterococcus     0.3269    0.4146    0.3656        41
#    escherichia     0.6558    0.4159    0.5090      1796
#     klebsiella     0.3431    0.3112    0.3264       527
#         others     0.0160    0.2683    0.0303        41
#    pseudomonas     0.5020    0.4019    0.4464       311
# staphylococcus     0.7634    0.3901    0.5164       182
#
#       accuracy                         0.3756      3203
#      macro avg     0.3601    0.3452    0.3164      3203
#   weighted avg     0.5342    0.3756    0.4321      3203
#
# ===================
# Confidence threshold k: 60.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1241    0.4045    0.1900        89
#   enterobacter     0.1421    0.1296    0.1356       216
#   enterococcus     0.3400    0.4146    0.3736        41
#    escherichia     0.6593    0.3976    0.4960      1796
#     klebsiella     0.3371    0.2808    0.3064       527
#         others     0.0147    0.2927    0.0279        41
#    pseudomonas     0.5127    0.3891    0.4424       311
# staphylococcus     0.7865    0.3846    0.5166       182
#
#       accuracy                         0.3578      3203
#      macro avg     0.3646    0.3367    0.3111      3203
#   weighted avg     0.5372    0.3578    0.4204      3203
#
# ===================
# Confidence threshold k: 70.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1281    0.4045    0.1946        89
#   enterobacter     0.1412    0.1157    0.1272       216
#   enterococcus     0.3778    0.4146    0.3953        41
#    escherichia     0.6630    0.3736    0.4779      1796
#     klebsiella     0.3401    0.2562    0.2922       527
#         others     0.0161    0.3902    0.0309        41
#    pseudomonas     0.5502    0.3698    0.4423       311
# staphylococcus     0.8023    0.3791    0.5149       182
#
#       accuracy                         0.3384      3203
#      macro avg     0.3774    0.3380    0.3094      3203
#   weighted avg     0.5449    0.3384    0.4077      3203
#
# ===================
# Confidence threshold k: 80.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1269    0.3820    0.1905        89
#   enterobacter     0.1384    0.1019    0.1173       216
#   enterococcus     0.3590    0.3415    0.3500        41
#    escherichia     0.6782    0.3380    0.4511      1796
#     klebsiella     0.3420    0.2239    0.2706       527
#         others     0.0180    0.5366    0.0348        41
#    pseudomonas     0.5691    0.3441    0.4289       311
# staphylococcus     0.7976    0.3681    0.5038       182
#
#       accuracy                         0.3094      3203
#      macro avg     0.3786    0.3295    0.2934      3203
#   weighted avg     0.5548    0.3094    0.3859      3203
#
# ===================
# Confidence threshold k: 90.0%
#                 precision    recall  f1-score   support
#
#  acinetobacter     0.1356    0.3596    0.1969        89
#   enterobacter     0.0885    0.0463    0.0608       216
#   enterococcus     0.3793    0.2683    0.3143        41
#    escherichia     0.6997    0.2829    0.4029      1796
#     klebsiella     0.3271    0.1651    0.2194       527
#         others     0.0143    0.5610    0.0279        41
#    pseudomonas     0.5960    0.2894    0.3896       311
# staphylococcus     0.8267    0.3407    0.4825       182
#
#       accuracy                         0.2569      3203
#      macro avg     0.3834    0.2891    0.2618      3203
#   weighted avg     0.5658    0.2569    0.3412      3203
#
# ===================
# Finished
# ===================
